# %%
import random
import copy
import logging
import sys

# from run_tests_201204 import *

import os
import sys
import importlib
from collections import defaultdict
sys.path.insert(0, '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc')
from tools_pattern import get_eucledean_dist
import compress_pickle
import my_plot
from my_plot import MyPlotData, my_box_plot
import seaborn as sns

script_n = 'plot_210603_grc_pcts'

data_script = 'batch_210603_grc_pcts'
db_path = '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc/dimensionality_sim2/' \
            f'{data_script}/'


scaled_noise = 0
core_noise = 0
n_mfs = 400
n_grcs = 2400


pattern_type = 'binary'
db = {}
model = 'global_random'
db[model] = compress_pickle.load(
    db_path+f'{data_script}_{model}_{pattern_type}_{n_grcs}_{n_mfs}_0.3_512_10.gz')


# avg_grc_dim_list = defaultdict(list)
# for ress in db['random']:
#     ress_tries = ress
#     for ress in ress_tries:
# #         print(ress)
#         for noise in ress:
#             res = ress[noise]
#             grc_dim = res['grc_dim']
#             avg_grc_dim_list[noise].append(grc_dim)

# avg_grc_dim = {}
# for noise in avg_grc_dim_list:
#     avg_grc_dim[noise] = sum(avg_grc_dim_list[noise])/len(avg_grc_dim_list[noise])

# %%
name_map = {
        'scaleup4': "Observed",
        'global_random': "Global Random",
        'random': "Global Random",
#         'naive_random_17': "Local Random",
        'naive_random4': "Local Random",
}

palette = {
    name_map['scaleup4']: sns.color_palette()[0],
    name_map['global_random']: sns.color_palette()[1],
    name_map['random']: sns.color_palette()[1],
    name_map['naive_random4']: sns.color_palette()[2],
#     name_map['naive_random_21']: sns.color_palette()[2],
}


mpd = MyPlotData()
ress_ref = db['global_random'][0][0]
resss_ref2 = db['global_random'][0]
for model_name in [
        'global_random',
#         'naive_random_17',
#         'naive_random4',
#         'random',
#         'scaleup4',
        ]:
    ress = db[model_name]
#     print(ress)
    ress_tries = ress[0]  # get the first element in tuple
#     ress = ress[0]  # get the first try
    for n_try, ress in enumerate(ress_tries):
#         print(resss_ref2[0])
#         print(resss_ref2.keys())
        if n_try >= len(resss_ref2):
            print(n_try)
            continue
        ress_ref2 = resss_ref2[n_try]
        for noise in ress:
    #         print(noise)
            res = ress[noise]
#             res_ref = ress_ref[noise]
            res_ref2 = ress_ref2[noise]
    #         hamming_distance_norm = res['hamming_distance']/res['num_grcs']
            mpd.add_data_point(
                model=name_map[model_name],
#                 noise=noise*100,
                grc_pcts=noise*100*2400/1400,
                grc_dim=res['grc_dim'],
                grc_dim_norm=res['grc_dim']/135,
#                 grc_dim_norm2=res['grc_dim']/avg_grc_dim[noise],
                grc_by_mf_dim=res['grc_dim']/res['mf_dim'],
#                 grc_by_mf_dim_ref=res['grc_dim']/res_ref['mf_dim'],
                num_grcs=res['num_grcs'],
                num_mfs=res['num_mfs'],
                voi=res['voi'],
                grc_pop_corr=res['grc_pop_corr'],
                grc_pop_corr_norm=res['grc_pop_corr']/res_ref2['grc_pop_corr'],
                binary_similarity=res['binary_similarity'],
                hamming_distance=res['hamming_distance'],
                normalized_mse=res['normalized_mse'],
                )

# importlib.reload(my_plot); my_plot.my_relplot(
#     mpd,
#     x='noise',
#     y='grc_dim',
#     hue='model',
#     context='paper',
#     palette=palette,
#     linewidth=1,
#     log_scale_y=True,
#     width=10,
# #     ylim=[0, None],
#     y_axis_label='Dim. Expansion ($x$)',
#     x_axis_label='MF Input Variation (%)',
#     title='noise',
#     save_filename=f'{script_n}_act_30.svg',
#     show=True,
#     )

# %%
importlib.reload(my_plot); my_plot.my_relplot(
    mpd,
    x='grc_pcts',
    y='grc_dim_norm',
    hue='model',
    context='paper',
    palette=palette,
    linewidth=1,
#     log_scale_y=True,
    width=10,
#     ylim=[0, None],
#     xlim=[0, 150],
    y_axis_label='Dim. Norm. ($x$)',
    x_axis_label='GrC count (%)',
#     title='noise',
    save_filename=f'{script_n}_act_30.svg',
    show=True,
    )
# Out:
# Height: 7.518796992481203, Aspect: 1.33

# %%
mpd.data
# Out:
# [{'model': 'Global Random',
#   'grc_pcts': 10.0,
#   'grc_dim': 65.74320992142735,
#   'grc_dim_norm': 0.5388787698477652,
#   'grc_by_mf_dim': 65.74320992142735,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.6826385519726372,
#   'grc_pop_corr': 0.024007800128589895,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33650453629032157,
#   'hamming_distance': 196.45,
#   'normalized_mse': 0.9135509672619049},
#  {'model': 'Global Random',
#   'grc_pcts': 20.0,
#   'grc_dim': 90.73010368110339,
#   'grc_dim_norm': 0.7436893744352736,
#   'grc_by_mf_dim': 90.73010368110339,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7779875814932646,
#   'grc_pop_corr': 0.017065456743698287,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.32109882305194787,
#   'hamming_distance': 213.1125,
#   'normalized_mse': 0.9910365513392859},
#  {'model': 'Global Random',
#   'grc_pcts': 30.0,
#   'grc_dim': 97.34580831034225,
#   'grc_dim_norm': 0.7979164615601824,
#   'grc_by_mf_dim': 97.34580831034225,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7412727976819766,
#   'grc_pop_corr': 0.014842136690686932,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.348945691747573,
#   'hamming_distance': 201.29722222222222,
#   'normalized_mse': 0.9360919932208995},
#  {'model': 'Global Random',
#   'grc_pcts': 40.0,
#   'grc_dim': 105.1106736633586,
#   'grc_dim_norm': 0.8615628988799885,
#   'grc_by_mf_dim': 105.1106736633586,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7946458632614772,
#   'grc_pop_corr': 0.013286702732955392,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3495848073899364,
#   'hamming_distance': 208.26458333333332,
#   'normalized_mse': 0.9684922960069444},
#  {'model': 'Global Random',
#   'grc_pcts': 50.0,
#   'grc_dim': 115.51878210055283,
#   'grc_dim_norm': 0.9468752631192855,
#   'grc_by_mf_dim': 115.51878210055283,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7647754638209419,
#   'grc_pop_corr': 0.012201989846910925,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3339423723118276,
#   'hamming_distance': 205.68833333333333,
#   'normalized_mse': 0.9565119667658731},
#  {'model': 'Global Random',
#   'grc_pcts': 60.0,
#   'grc_dim': 130.68337962969366,
#   'grc_dim_norm': 1.0711752428663415,
#   'grc_by_mf_dim': 130.68337962969366,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7619969071770363,
#   'grc_pop_corr': 0.011165283602545536,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33089632601351404,
#   'hamming_distance': 205.7736111111111,
#   'normalized_mse': 0.9569085338128308},
#  {'model': 'Global Random',
#   'grc_pcts': 70.0,
#   'grc_dim': 119.7422563699184,
#   'grc_dim_norm': 0.9814939046714622,
#   'grc_by_mf_dim': 119.7422563699184,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7173904058321088,
#   'grc_pop_corr': 0.01172055362892109,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33671025815217503,
#   'hamming_distance': 198.1261904761905,
#   'normalized_mse': 0.9213457518424037},
#  {'model': 'Global Random',
#   'grc_pcts': 80.0,
#   'grc_dim': 130.71557424182578,
#   'grc_dim_norm': 1.0714391331297195,
#   'grc_by_mf_dim': 130.71557424182578,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7457223292988384,
#   'grc_pop_corr': 0.011097939937726162,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33417071554770267,
#   'hamming_distance': 202.33020833333333,
#   'normalized_mse': 0.9408956860739088},
#  {'model': 'Global Random',
#   'grc_pcts': 90.0,
#   'grc_dim': 127.98209633919635,
#   'grc_dim_norm': 1.0490335765507897,
#   'grc_by_mf_dim': 127.98209633919635,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7463871960975441,
#   'grc_pop_corr': 0.01120775958823949,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3414013053797464,
#   'hamming_distance': 201.3972222222222,
#   'normalized_mse': 0.9365570229828042},
#  {'model': 'Global Random',
#   'grc_pcts': 100.0,
#   'grc_dim': 131.39920504896034,
#   'grc_dim_norm': 1.0770426643357405,
#   'grc_by_mf_dim': 131.39920504896034,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7576215375837587,
#   'grc_pop_corr': 0.011012297068636807,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33198820592286477,
#   'hamming_distance': 204.91583333333332,
#   'normalized_mse': 0.9529196118551588},
#  {'model': 'Global Random',
#   'grc_pcts': 110.00000000000003,
#   'grc_dim': 129.28493182629404,
#   'grc_dim_norm': 1.0597125559532299,
#   'grc_by_mf_dim': 129.28493182629404,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.761149003556163,
#   'grc_pop_corr': 0.01110417702415611,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33802599009900997,
#   'hamming_distance': 203.825,
#   'normalized_mse': 0.9478469122023809},
#  {'model': 'Global Random',
#   'grc_pcts': 120.0,
#   'grc_dim': 133.53847432909353,
#   'grc_dim_norm': 1.094577658435193,
#   'grc_by_mf_dim': 133.53847432909353,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7531789695199673,
#   'grc_pop_corr': 0.010890042912610335,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3405494245337994,
#   'hamming_distance': 202.42638888888888,
#   'normalized_mse': 0.9413429542824076},
#  {'model': 'Global Random',
#   'grc_pcts': 130.0,
#   'grc_dim': 133.93221706057122,
#   'grc_dim_norm': 1.0978050578735346,
#   'grc_by_mf_dim': 133.93221706057122,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7692668898541553,
#   'grc_pop_corr': 0.010865289407693709,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3386653509916494,
#   'hamming_distance': 206.27307692307693,
#   'normalized_mse': 0.9592311984890111},
#  {'model': 'Global Random',
#   'grc_pcts': 140.0,
#   'grc_dim': 131.80257530937402,
#   'grc_dim_norm': 1.0803489779456887,
#   'grc_by_mf_dim': 131.80257530937402,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7490002987166877,
#   'grc_pop_corr': 0.010959564073765277,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33846111181541594,
#   'hamming_distance': 202.63214285714287,
#   'normalized_mse': 0.9422997714710886},
#  {'model': 'Global Random',
#   'grc_pcts': 150.0,
#   'grc_dim': 139.08431863070956,
#   'grc_dim_norm': 1.1400353986123735,
#   'grc_by_mf_dim': 139.08431863070956,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7706514197997199,
#   'grc_pop_corr': 0.01062655350385753,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3360690935283692,
#   'hamming_distance': 205.81222222222223,
#   'normalized_mse': 0.9570880869708996},
#  {'model': 'Global Random',
#   'grc_pcts': 160.0,
#   'grc_dim': 137.2409135573589,
#   'grc_dim_norm': 1.1249255209619582,
#   'grc_by_mf_dim': 137.2409135573589,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7602778555245526,
#   'grc_pop_corr': 0.01070144441893725,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33671541132478666,
#   'hamming_distance': 203.95260416666667,
#   'normalized_mse': 0.9484403095548116},
#  {'model': 'Global Random',
#   'grc_pcts': 170.0,
#   'grc_dim': 135.7303981390893,
#   'grc_dim_norm': 1.1125442470417155,
#   'grc_by_mf_dim': 135.7303981390893,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7585384260227443,
#   'grc_pop_corr': 0.010765995881352679,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33814110693993515,
#   'hamming_distance': 203.68627450980392,
#   'normalized_mse': 0.9472017973856209},
#  {'model': 'Global Random',
#   'grc_pcts': 180.0,
#   'grc_dim': 136.97265171939952,
#   'grc_dim_norm': 1.122726653437701,
#   'grc_by_mf_dim': 136.97265171939952,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7577214473658795,
#   'grc_pop_corr': 0.010709107613658975,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33835407838983067,
#   'hamming_distance': 203.72083333333333,
#   'normalized_mse': 0.9473625062003969},
#  {'model': 'Global Random',
#   'grc_pcts': 190.0,
#   'grc_dim': 138.4314582376909,
#   'grc_dim_norm': 1.134684083915499,
#   'grc_by_mf_dim': 138.4314582376909,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7580623768019008,
#   'grc_pop_corr': 0.010644037128276558,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33626396711482565,
#   'hamming_distance': 203.97368421052633,
#   'normalized_mse': 0.9485383380325816},
#  {'model': 'Global Random',
#   'grc_pcts': 200.0,
#   'grc_dim': 139.03805563742245,
#   'grc_dim_norm': 1.1396561937493643,
#   'grc_by_mf_dim': 139.03805563742245,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7585617948175272,
#   'grc_pop_corr': 0.010615360506257538,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33711206896551693,
#   'hamming_distance': 203.85625,
#   'normalized_mse': 0.9479922340029763},
#  {'model': 'Global Random',
#   'grc_pcts': 10.0,
#   'grc_dim': 65.18012462354181,
#   'grc_dim_norm': 0.5342633165864084,
#   'grc_by_mf_dim': 65.18012462354181,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.6105345663241015,
#   'grc_pop_corr': 0.024429648100152968,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3284143518518533,
#   'hamming_distance': 186.13333333333333,
#   'normalized_mse': 0.8655753968253969},
#  {'model': 'Global Random',
#   'grc_pcts': 20.0,
#   'grc_dim': 90.7539206555113,
#   'grc_dim_norm': 0.7438845955369778,
#   'grc_by_mf_dim': 90.7539206555113,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7664958867000178,
#   'grc_pop_corr': 0.01697820983514539,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3269171463815788,
#   'hamming_distance': 208.49583333333334,
#   'normalized_mse': 0.9695676773313494},
#  {'model': 'Global Random',
#   'grc_pcts': 30.0,
#   'grc_dim': 107.00993357888098,
#   'grc_dim_norm': 0.8771306031055818,
#   'grc_by_mf_dim': 107.00993357888098,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7086747642079656,
#   'grc_pop_corr': 0.013924952976974428,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33086340206185644,
#   'hamming_distance': 198.9777777777778,
#   'normalized_mse': 0.9253058862433864},
#  {'model': 'Global Random',
#   'grc_pcts': 40.0,
#   'grc_dim': 109.31058495886656,
#   'grc_dim_norm': 0.8959884013021849,
#   'grc_by_mf_dim': 109.31058495886656,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7320475821611643,
#   'grc_pop_corr': 0.012955178492192305,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3357561383928577,
#   'hamming_distance': 198.91666666666666,
#   'normalized_mse': 0.925021701388889},
#  {'model': 'Global Random',
#   'grc_pcts': 50.0,
#   'grc_dim': 120.7879568641959,
#   'grc_dim_norm': 0.9900652201983271,
#   'grc_by_mf_dim': 120.7879568641959,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7526373380755662,
#   'grc_pop_corr': 0.011853797711986346,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33791185461956497,
#   'hamming_distance': 201.495,
#   'normalized_mse': 0.9370117187500002},
#  {'model': 'Global Random',
#   'grc_pcts': 60.0,
#   'grc_dim': 120.05848644626124,
#   'grc_dim_norm': 0.9840859544775512,
#   'grc_by_mf_dim': 120.05848644626124,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.733073640874387,
#   'grc_pop_corr': 0.011778241690741688,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3463634672619044,
#   'hamming_distance': 196.40555555555557,
#   'normalized_mse': 0.913344287367725},
#  {'model': 'Global Random',
#   'grc_pcts': 70.0,
#   'grc_dim': 130.44851507178487,
#   'grc_dim_norm': 1.0692501235392202,
#   'grc_by_mf_dim': 130.44851507178487,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.777356517041506,
#   'grc_pop_corr': 0.011127970273120283,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3372842396209393,
#   'hamming_distance': 205.02619047619046,
#   'normalized_mse': 0.9534328054138322},
#  {'model': 'Global Random',
#   'grc_pcts': 80.0,
#   'grc_dim': 125.58906493147462,
#   'grc_dim_norm': 1.029418565012087,
#   'grc_by_mf_dim': 125.58906493147462,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7533313243529232,
#   'grc_pop_corr': 0.011349836893063407,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34147581335616506,
#   'hamming_distance': 200.990625,
#   'normalized_mse': 0.9346662248883929},
#  {'model': 'Global Random',
#   'grc_pcts': 90.0,
#   'grc_dim': 130.6574626596738,
#   'grc_dim_norm': 1.0709628086858507,
#   'grc_by_mf_dim': 130.6574626596738,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7750321376893032,
#   'grc_pop_corr': 0.011068744643445434,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34134397644927666,
#   'hamming_distance': 205.0,
#   'normalized_mse': 0.953311011904762},
#  {'model': 'Global Random',
#   'grc_pcts': 100.0,
#   'grc_dim': 122.97049670824632,
#   'grc_dim_norm': 1.0079548910511993,
#   'grc_by_mf_dim': 122.97049670824632,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7531345040282769,
#   'grc_pop_corr': 0.011434967664165348,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3457621480082421,
#   'hamming_distance': 200.02,
#   'normalized_mse': 0.9301525297619049},
#  {'model': 'Global Random',
#   'grc_pcts': 110.00000000000003,
#   'grc_dim': 131.53196799729213,
#   'grc_dim_norm': 1.078130885223706,
#   'grc_by_mf_dim': 131.53196799729213,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7555141190805494,
#   'grc_pop_corr': 0.01099092399769609,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.346749961228288,
#   'hamming_distance': 200.11060606060607,
#   'normalized_mse': 0.9305738749098126},
#  {'model': 'Global Random',
#   'grc_pcts': 120.0,
#   'grc_dim': 144.08172061767044,
#   'grc_dim_norm': 1.1809977099809053,
#   'grc_by_mf_dim': 144.08172061767044,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7550634556340894,
#   'grc_pop_corr': 0.010407893363028248,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3391234799208143,
#   'hamming_distance': 201.2548611111111,
#   'normalized_mse': 0.9358950014467594},
#  {'model': 'Global Random',
#   'grc_pcts': 130.0,
#   'grc_dim': 136.87004445748283,
#   'grc_dim_norm': 1.1218856103072363,
#   'grc_by_mf_dim': 136.87004445748283,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.766351579029176,
#   'grc_pop_corr': 0.010726995925115721,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34060329861111116,
#   'hamming_distance': 203.65897435897435,
#   'normalized_mse': 0.9470748435592186},
#  {'model': 'Global Random',
#   'grc_pcts': 140.0,
#   'grc_dim': 138.85793013614344,
#   'grc_dim_norm': 1.1381797552142905,
#   'grc_by_mf_dim': 138.85793013614344,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7605085641364486,
#   'grc_pop_corr': 0.010630285352581413,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34045834338803094,
#   'hamming_distance': 202.41964285714286,
#   'normalized_mse': 0.9413115832270409},
#  {'model': 'Global Random',
#   'grc_pcts': 150.0,
#   'grc_dim': 136.50066816039947,
#   'grc_dim_norm': 1.1188579357409794,
#   'grc_by_mf_dim': 136.50066816039947,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7661087090431717,
#   'grc_pop_corr': 0.010734846432966487,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3421235420334506,
#   'hamming_distance': 202.38,
#   'normalized_mse': 0.9411272321428572},
#  {'model': 'Global Random',
#   'grc_pcts': 160.0,
#   'grc_dim': 135.71684592737,
#   'grc_dim_norm': 1.1124331633390985,
#   'grc_by_mf_dim': 135.71684592737,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7703225706027592,
#   'grc_pop_corr': 0.010765984616311241,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34141265368852436,
#   'hamming_distance': 203.46770833333332,
#   'normalized_mse': 0.9461853996155755},
#  {'model': 'Global Random',
#   'grc_pcts': 170.0,
#   'grc_dim': 143.69753613940946,
#   'grc_dim_norm': 1.1778486568804054,
#   'grc_by_mf_dim': 143.69753613940946,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7627438861449618,
#   'grc_pop_corr': 0.010416119325257232,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33518559272300436,
#   'hamming_distance': 203.26519607843136,
#   'normalized_mse': 0.9452436573587769},
#  {'model': 'Global Random',
#   'grc_pcts': 180.0,
#   'grc_dim': 139.97179778052774,
#   'grc_dim_norm': 1.1473098178731782,
#   'grc_by_mf_dim': 139.97179778052774,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7734797427860605,
#   'grc_pop_corr': 0.010574279634902572,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34265988372093015,
#   'hamming_distance': 204.03287037037038,
#   'normalized_mse': 0.948813571290785},
#  {'model': 'Global Random',
#   'grc_pcts': 190.0,
#   'grc_dim': 140.72247143027067,
#   'grc_dim_norm': 1.1534628805759892,
#   'grc_by_mf_dim': 140.72247143027067,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7663381971938064,
#   'grc_pop_corr': 0.01054164544586696,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34060481407122883,
#   'hamming_distance': 203.01929824561404,
#   'normalized_mse': 0.9441001592522975},
#  {'model': 'Global Random',
#   'grc_pcts': 200.0,
#   'grc_dim': 141.85053811766699,
#   'grc_dim_norm': 1.1627093288333359,
#   'grc_by_mf_dim': 141.85053811766699,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7670619129792646,
#   'grc_pop_corr': 0.010492424014757487,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3413570985099337,
#   'hamming_distance': 202.94291666666666,
#   'normalized_mse': 0.9437449621775794},
#  {'model': 'Global Random',
#   'grc_pcts': 10.0,
#   'grc_dim': 71.37583720681128,
#   'grc_dim_norm': 0.5850478459574695,
#   'grc_by_mf_dim': 71.37583720681128,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7774616027542367,
#   'grc_pop_corr': 0.022189933334564205,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.32261618589743657,
#   'hamming_distance': 214.65833333333333,
#   'normalized_mse': 0.9982251364087303},
#  {'model': 'Global Random',
#   'grc_pcts': 20.0,
#   'grc_dim': 91.93680680014445,
#   'grc_dim_norm': 0.7535803836077414,
#   'grc_by_mf_dim': 91.93680680014445,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.78685645625089,
#   'grc_pop_corr': 0.016837007347641448,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33887954905063283,
#   'hamming_distance': 209.975,
#   'normalized_mse': 0.9764462425595238},
#  {'model': 'Global Random',
#   'grc_pcts': 30.0,
#   'grc_dim': 108.45315545118684,
#   'grc_dim_norm': 0.8889602905834987,
#   'grc_by_mf_dim': 108.45315545118684,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7681122142646732,
#   'grc_pop_corr': 0.013802078493326956,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3242187500000012,
#   'hamming_distance': 208.1638888888889,
#   'normalized_mse': 0.9680240368716932},
#  {'model': 'Global Random',
#   'grc_pcts': 40.0,
#   'grc_dim': 113.8396494888054,
#   'grc_dim_norm': 0.933111881055782,
#   'grc_by_mf_dim': 113.8396494888054,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.8003594814688102,
#   'grc_pop_corr': 0.012634612959805915,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33927511867088583,
#   'hamming_distance': 213.55,
#   'normalized_mse': 0.9930710565476192},
#  {'model': 'Global Random',
#   'grc_pcts': 50.0,
#   'grc_dim': 119.04720808893865,
#   'grc_dim_norm': 0.9757967876142511,
#   'grc_by_mf_dim': 119.04720808893865,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.736113402929698,
#   'grc_pop_corr': 0.011979057145218523,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33337545955882353,
#   'hamming_distance': 202.71833333333333,
#   'normalized_mse': 0.9427005828373016},
#  {'model': 'Global Random',
#   'grc_pcts': 60.0,
#   'grc_dim': 127.48578976000091,
#   'grc_dim_norm': 1.044965489836073,
#   'grc_by_mf_dim': 127.48578976000091,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.769932660935098,
#   'grc_pop_corr': 0.011351591287915616,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3324406386462879,
#   'hamming_distance': 205.99722222222223,
#   'normalized_mse': 0.9579483920304235},
#  {'model': 'Global Random',
#   'grc_pcts': 70.0,
#   'grc_dim': 128.6204157485213,
#   'grc_dim_norm': 1.0542657028567322,
#   'grc_by_mf_dim': 128.6204157485213,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.748492340312984,
#   'grc_pop_corr': 0.01124428747225917,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34322656250000083,
#   'hamming_distance': 200.53571428571428,
#   'normalized_mse': 0.9325507546768709},
#  {'model': 'Global Random',
#   'grc_pcts': 80.0,
#   'grc_dim': 139.67891908623218,
#   'grc_dim_norm': 1.1449091728379688,
#   'grc_by_mf_dim': 139.67891908623218,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7813071662530078,
#   'grc_pop_corr': 0.010629937957223433,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3408581149193546,
#   'hamming_distance': 206.578125,
#   'normalized_mse': 0.9606497628348215},
#  {'model': 'Global Random',
#   'grc_pcts': 90.0,
#   'grc_dim': 137.2241117728923,
#   'grc_dim_norm': 1.12478780141715,
#   'grc_by_mf_dim': 137.2241117728923,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7642777488239407,
#   'grc_pop_corr': 0.010751828349733393,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34469126506024145,
#   'hamming_distance': 203.09814814814814,
#   'normalized_mse': 0.9444668347663141},
#  {'model': 'Global Random',
#   'grc_pcts': 100.0,
#   'grc_dim': 139.90999795470046,
#   'grc_dim_norm': 1.1468032619237742,
#   'grc_by_mf_dim': 139.90999795470046,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7734455580538258,
#   'grc_pop_corr': 0.010610413240424443,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3374177631578949,
#   'hamming_distance': 205.875,
#   'normalized_mse': 0.9573800223214286},
#  {'model': 'Global Random',
#   'grc_pcts': 110.00000000000003,
#   'grc_dim': 141.38950068850684,
#   'grc_dim_norm': 1.158930333512351,
#   'grc_by_mf_dim': 141.38950068850684,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7443279421260884,
#   'grc_pop_corr': 0.010538105308880797,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3350450799608356,
#   'hamming_distance': 202.7037878787879,
#   'normalized_mse': 0.942632942144661},
#  {'model': 'Global Random',
#   'grc_pcts': 120.0,
#   'grc_dim': 138.65942682385383,
#   'grc_dim_norm': 1.1365526788840479,
#   'grc_by_mf_dim': 138.65942682385383,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7568127266425726,
#   'grc_pop_corr': 0.010656457553330024,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33690268065268075,
#   'hamming_distance': 204.48402777777778,
#   'normalized_mse': 0.9509115875082673},
#  {'model': 'Global Random',
#   'grc_pcts': 130.0,
#   'grc_dim': 139.09919503438584,
#   'grc_dim_norm': 1.1401573363474249,
#   'grc_by_mf_dim': 139.09919503438584,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7668090374043075,
#   'grc_pop_corr': 0.010627785575057308,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33717706158663885,
#   'hamming_distance': 205.71730769230768,
#   'normalized_mse': 0.9566467061584251},
#  {'model': 'Global Random',
#   'grc_pcts': 140.0,
#   'grc_dim': 146.32492747495266,
#   'grc_dim_norm': 1.1993846514340383,
#   'grc_by_mf_dim': 146.32492747495266,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7669826416126981,
#   'grc_pop_corr': 0.010312042550549292,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3369897650193804,
#   'hamming_distance': 205.69583333333333,
#   'normalized_mse': 0.956546843998016},
#  {'model': 'Global Random',
#   'grc_pcts': 150.0,
#   'grc_dim': 145.05942637988332,
#   'grc_dim_norm': 1.189011691638388,
#   'grc_by_mf_dim': 145.05942637988332,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7617057651157202,
#   'grc_pop_corr': 0.010367065817018028,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33796946674311906,
#   'hamming_distance': 204.64944444444444,
#   'normalized_mse': 0.951680824239418},
#  {'model': 'Global Random',
#   'grc_pcts': 160.0,
#   'grc_dim': 142.39591023570927,
#   'grc_dim_norm': 1.1671795920959775,
#   'grc_by_mf_dim': 142.39591023570927,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7575863401522,
#   'grc_pop_corr': 0.010477989700810009,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33775184142114345,
#   'hamming_distance': 203.79375,
#   'normalized_mse': 0.9477015904017858},
#  {'model': 'Global Random',
#   'grc_pcts': 170.0,
#   'grc_dim': 145.07369994528634,
#   'grc_dim_norm': 1.1891286880761176,
#   'grc_by_mf_dim': 145.07369994528634,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7711197922209474,
#   'grc_pop_corr': 0.010367157348420262,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33609510977057006,
#   'hamming_distance': 206.65980392156862,
#   'normalized_mse': 0.9610295941293184},
#  {'model': 'Global Random',
#   'grc_pcts': 180.0,
#   'grc_dim': 144.12978061794564,
#   'grc_dim_norm': 1.1813916444093906,
#   'grc_by_mf_dim': 144.12978061794564,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.769624135319165,
#   'grc_pop_corr': 0.010404415290636258,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33820639970059874,
#   'hamming_distance': 205.72222222222223,
#   'normalized_mse': 0.9566695601851852},
#  {'model': 'Global Random',
#   'grc_pcts': 190.0,
#   'grc_dim': 147.77309096085176,
#   'grc_dim_norm': 1.211254843941408,
#   'grc_by_mf_dim': 147.77309096085176,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7646709866162809,
#   'grc_pop_corr': 0.010252658040027843,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3376492905890808,
#   'hamming_distance': 205.06798245614036,
#   'normalized_mse': 0.9536271505586885},
#  {'model': 'Global Random',
#   'grc_pcts': 200.0,
#   'grc_dim': 146.88554460031497,
#   'grc_dim_norm': 1.2039798737730736,
#   'grc_by_mf_dim': 146.88554460031497,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7662506776765956,
#   'grc_pop_corr': 0.010288378509802801,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3360383406929347,
#   'hamming_distance': 205.64083333333335,
#   'normalized_mse': 0.9562910776289685},
#  {'model': 'Global Random',
#   'grc_pcts': 10.0,
#   'grc_dim': 69.58300024063087,
#   'grc_dim_norm': 0.5703524609887776,
#   'grc_by_mf_dim': 69.58300024063087,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7092820377516782,
#   'grc_pop_corr': 0.02258341576831726,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3220932904411753,
#   'hamming_distance': 201.14166666666668,
#   'normalized_mse': 0.93536861359127},
#  {'model': 'Global Random',
#   'grc_pcts': 20.0,
#   'grc_dim': 85.21691862308828,
#   'grc_dim_norm': 0.6984993329761334,
#   'grc_by_mf_dim': 85.21691862308828,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7596285351191818,
#   'grc_pop_corr': 0.01782249754104089,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3620772688356143,
#   'hamming_distance': 200.66666666666666,
#   'normalized_mse': 0.9331597222222223},
#  {'model': 'Global Random',
#   'grc_pcts': 30.0,
#   'grc_dim': 110.93337679652039,
#   'grc_dim_norm': 0.9092899737419704,
#   'grc_by_mf_dim': 110.93337679652039,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7043722455092332,
#   'grc_pop_corr': 0.013535003254589735,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.32130899234693866,
#   'hamming_distance': 198.54722222222222,
#   'normalized_mse': 0.9233036747685187},
#  {'model': 'Global Random',
#   'grc_pcts': 40.0,
#   'grc_dim': 122.37348631979894,
#   'grc_dim_norm': 1.0030613632770404,
#   'grc_by_mf_dim': 122.37348631979894,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7614031037366278,
#   'grc_pop_corr': 0.012001907341922751,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3227066532258065,
#   'hamming_distance': 205.0625,
#   'normalized_mse': 0.9536016555059526},
#  {'model': 'Global Random',
#   'grc_pcts': 50.0,
#   'grc_dim': 123.23834219918231,
#   'grc_dim_norm': 1.010150345894937,
#   'grc_by_mf_dim': 123.23834219918231,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.701652529232917,
#   'grc_pop_corr': 0.011692025204775327,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3466430664062499,
#   'hamming_distance': 193.3,
#   'normalized_mse': 0.8989025297619049},
#  {'model': 'Global Random',
#   'grc_pcts': 60.0,
#   'grc_dim': 128.62619965524038,
#   'grc_dim_norm': 1.0543131119281999,
#   'grc_by_mf_dim': 128.62619965524038,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7464229810967997,
#   'grc_pop_corr': 0.011282350787916581,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3478524970095708,
#   'hamming_distance': 201.08194444444445,
#   'normalized_mse': 0.9350908874834657},
#  {'model': 'Global Random',
#   'grc_pcts': 70.0,
#   'grc_dim': 137.83510173258446,
#   'grc_dim_norm': 1.1297959158408561,
#   'grc_by_mf_dim': 137.83510173258446,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7397321816770512,
#   'grc_pop_corr': 0.010746834893730689,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3400607638888886,
#   'hamming_distance': 200.51309523809525,
#   'normalized_mse': 0.9324455693735829},
#  {'model': 'Global Random',
#   'grc_pcts': 80.0,
#   'grc_dim': 130.12201749233557,
#   'grc_dim_norm': 1.066573913871603,
#   'grc_by_mf_dim': 130.12201749233557,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.755146716579335,
#   'grc_pop_corr': 0.011122901599190113,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3307583512931033,
#   'hamming_distance': 204.61354166666666,
#   'normalized_mse': 0.9515138656374009},
#  {'model': 'Global Random',
#   'grc_pcts': 90.0,
#   'grc_dim': 148.14990492359436,
#   'grc_dim_norm': 1.2143434829802817,
#   'grc_by_mf_dim': 148.14990492359436,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7370918261567039,
#   'grc_pop_corr': 0.010224224773769032,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3436563997603836,
#   'hamming_distance': 198.5574074074074,
#   'normalized_mse': 0.9233510389109347},
#  {'model': 'Global Random',
#   'grc_pcts': 100.0,
#   'grc_dim': 141.7893844400527,
#   'grc_dim_norm': 1.1622080691807597,
#   'grc_by_mf_dim': 141.7893844400527,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.729487657275858,
#   'grc_pop_corr': 0.010517117998542236,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3424018252212389,
#   'hamming_distance': 198.25333333333333,
#   'normalized_mse': 0.9219370039682541},
#  {'model': 'Global Random',
#   'grc_pcts': 110.00000000000003,
#   'grc_dim': 141.13885857222704,
#   'grc_dim_norm': 1.1568758899362872,
#   'grc_by_mf_dim': 141.13885857222704,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.736467458255076,
#   'grc_pop_corr': 0.01053911425530127,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3419404117454075,
#   'hamming_distance': 198.925,
#   'normalized_mse': 0.9250604538690478},
#  {'model': 'Global Random',
#   'grc_pcts': 120.0,
#   'grc_dim': 140.80114383632147,
#   'grc_dim_norm': 1.1541077363632908,
#   'grc_by_mf_dim': 140.80114383632147,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7425595367887314,
#   'grc_pop_corr': 0.01056063042683009,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33617001488095244,
#   'hamming_distance': 201.34305555555557,
#   'normalized_mse': 0.9363051318617727},
#  {'model': 'Global Random',
#   'grc_pcts': 130.0,
#   'grc_dim': 147.03330980623824,
#   'grc_dim_norm': 1.2051910639855594,
#   'grc_by_mf_dim': 147.03330980623824,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7407307959963245,
#   'grc_pop_corr': 0.010281329264179543,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3383521950218819,
#   'hamming_distance': 199.9198717948718,
#   'normalized_mse': 0.9296869038079976},
#  {'model': 'Global Random',
#   'grc_pcts': 140.0,
#   'grc_dim': 146.8577995345971,
#   'grc_dim_norm': 1.2037524552016154,
#   'grc_by_mf_dim': 146.8577995345971,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7613498317938308,
#   'grc_pop_corr': 0.010286585597962304,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33882158925097244,
#   'hamming_distance': 203.64880952380952,
#   'normalized_mse': 0.9470275740504536},
#  {'model': 'Global Random',
#   'grc_pcts': 150.0,
#   'grc_dim': 145.7542545572687,
#   'grc_dim_norm': 1.1947070045677761,
#   'grc_by_mf_dim': 145.7542545572687,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7608645961125975,
#   'grc_pop_corr': 0.010338547616255024,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33968098958333304,
#   'hamming_distance': 203.13555555555556,
#   'normalized_mse': 0.9446407903439153},
#  {'model': 'Global Random',
#   'grc_pcts': 160.0,
#   'grc_dim': 146.32241556435932,
#   'grc_dim_norm': 1.1993640620029453,
#   'grc_by_mf_dim': 146.32241556435932,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7580281267575888,
#   'grc_pop_corr': 0.010311446066142009,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33867925794673476,
#   'hamming_distance': 203.10364583333333,
#   'normalized_mse': 0.944492400638641},
#  {'model': 'Global Random',
#   'grc_pcts': 170.0,
#   'grc_dim': 147.61790385125082,
#   'grc_dim_norm': 1.2099828184528756,
#   'grc_by_mf_dim': 147.61790385125082,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7522776184578732,
#   'grc_pop_corr': 0.010257355327177529,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3410503758237229,
#   'hamming_distance': 201.96519607843138,
#   'normalized_mse': 0.939198270454015},
#  {'model': 'Global Random',
#   'grc_pcts': 180.0,
#   'grc_dim': 148.47552768352128,
#   'grc_dim_norm': 1.2170125219960761,
#   'grc_by_mf_dim': 148.47552768352128,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.754236793745383,
#   'grc_pop_corr': 0.010221634018658898,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34036137326656374,
#   'hamming_distance': 202.05972222222223,
#   'normalized_mse': 0.9396378451554235},
#  {'model': 'Global Random',
#   'grc_pcts': 190.0,
#   'grc_dim': 148.97417236512706,
#   'grc_dim_norm': 1.221099773484648,
#   'grc_by_mf_dim': 148.97417236512706,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.755567843906362,
#   'grc_pop_corr': 0.010202841999419888,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33908245894160505,
#   'hamming_distance': 202.7921052631579,
#   'normalized_mse': 0.9430436442669174},
#  {'model': 'Global Random',
#   'grc_pcts': 200.0,
#   'grc_dim': 148.79966310548696,
#   'grc_dim_norm': 1.2196693697171062,
#   'grc_by_mf_dim': 148.79966310548696,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7519865674582016,
#   'grc_pop_corr': 0.010210138307427738,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34014926675977664,
#   'hamming_distance': 201.83375,
#   'normalized_mse': 0.9385870070684524},
#  {'model': 'Global Random',
#   'grc_pcts': 10.0,
#   'grc_dim': 65.76324432849441,
#   'grc_dim_norm': 0.5390429862991345,
#   'grc_by_mf_dim': 65.76324432849441,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7017082975187607,
#   'grc_pop_corr': 0.02411561930919279,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.36437270220588075,
#   'hamming_distance': 189.81666666666666,
#   'normalized_mse': 0.8827039930555557},
#  {'model': 'Global Random',
#   'grc_pcts': 20.0,
#   'grc_dim': 103.79234911961977,
#   'grc_dim_norm': 0.8507569599968834,
#   'grc_by_mf_dim': 103.79234911961977,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.740432943861927,
#   'grc_pop_corr': 0.015141819822769085,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3375108506944449,
#   'hamming_distance': 200.6125,
#   'normalized_mse': 0.9329078311011906},
#  {'model': 'Global Random',
#   'grc_pcts': 30.0,
#   'grc_dim': 99.15448762020675,
#   'grc_dim_norm': 0.8127417018049734,
#   'grc_by_mf_dim': 99.15448762020675,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7909169466796278,
#   'grc_pop_corr': 0.014663620972374098,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34653320312499986,
#   'hamming_distance': 207.95277777777778,
#   'normalized_mse': 0.9670423073743387},
#  {'model': 'Global Random',
#   'grc_pcts': 40.0,
#   'grc_dim': 118.0747282451175,
#   'grc_dim_norm': 0.9678256413534221,
#   'grc_by_mf_dim': 118.0747282451175,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7672814319088255,
#   'grc_pop_corr': 0.012315814829517907,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3524883319805197,
#   'hamming_distance': 200.48333333333332,
#   'normalized_mse': 0.9323071676587301},
#  {'model': 'Global Random',
#   'grc_pcts': 50.0,
#   'grc_dim': 126.31440121424285,
#   'grc_dim_norm': 1.0353639443790397,
#   'grc_by_mf_dim': 126.31440121424285,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7601467323124023,
#   'grc_pop_corr': 0.011514385905352248,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.35190590659340626,
#   'hamming_distance': 201.65833333333333,
#   'normalized_mse': 0.9377712673611112},
#  {'model': 'Global Random',
#   'grc_pcts': 60.0,
#   'grc_dim': 128.8283040495815,
#   'grc_dim_norm': 1.0559697053244386,
#   'grc_by_mf_dim': 128.8283040495815,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7485698966160013,
#   'grc_pop_corr': 0.011265274643266541,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33915924357476634,
#   'hamming_distance': 201.79444444444445,
#   'normalized_mse': 0.9384042245370371},
#  {'model': 'Global Random',
#   'grc_pcts': 70.0,
#   'grc_dim': 125.48427257280557,
#   'grc_dim_norm': 1.0285596112525046,
#   'grc_by_mf_dim': 125.48427257280557,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7716199281682108,
#   'grc_pop_corr': 0.011402509299213387,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.35528166906130265,
#   'hamming_distance': 202.74404761904762,
#   'normalized_mse': 0.9428201619189343},
#  {'model': 'Global Random',
#   'grc_pcts': 80.0,
#   'grc_dim': 132.10174407431884,
#   'grc_dim_norm': 1.0828011809370397,
#   'grc_by_mf_dim': 132.10174407431884,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.750020232354608,
#   'grc_pop_corr': 0.011013522938430444,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3549379355400699,
#   'hamming_distance': 198.3125,
#   'normalized_mse': 0.9222121465773812},
#  {'model': 'Global Random',
#   'grc_pcts': 90.0,
#   'grc_dim': 132.73360670015742,
#   'grc_dim_norm': 1.0879803827881755,
#   'grc_by_mf_dim': 132.73360670015742,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7555677824458071,
#   'grc_pop_corr': 0.010961157233840694,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33843513257575736,
#   'hamming_distance': 201.97962962962964,
#   'normalized_mse': 0.9392653907627867},
#  {'model': 'Global Random',
#   'grc_pcts': 100.0,
#   'grc_dim': 142.92510968490484,
#   'grc_dim_norm': 1.17151729249922,
#   'grc_by_mf_dim': 142.92510968490484,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7594875628478523,
#   'grc_pop_corr': 0.010466251427419596,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3408017869241186,
#   'hamming_distance': 202.36,
#   'normalized_mse': 0.9410342261904764},
#  {'model': 'Global Random',
#   'grc_pcts': 110.00000000000003,
#   'grc_dim': 142.5411032044181,
#   'grc_dim_norm': 1.1683696983968697,
#   'grc_by_mf_dim': 142.5411032044181,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7540988856296842,
#   'grc_pop_corr': 0.010478335792758761,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34671166561712996,
#   'hamming_distance': 200.72954545454544,
#   'normalized_mse': 0.9334521272997837},
#  {'model': 'Global Random',
#   'grc_pcts': 120.0,
#   'grc_dim': 144.30447990024112,
#   'grc_dim_norm': 1.1828236057396813,
#   'grc_by_mf_dim': 144.30447990024112,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7391869548087155,
#   'grc_pop_corr': 0.010396852688745104,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34418817124105006,
#   'hamming_distance': 198.65347222222223,
#   'normalized_mse': 0.9237977688905424},
#  {'model': 'Global Random',
#   'grc_pcts': 130.0,
#   'grc_dim': 141.6527200318977,
#   'grc_dim_norm': 1.1610878691139155,
#   'grc_by_mf_dim': 141.6527200318977,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7548649504083265,
#   'grc_pop_corr': 0.010516463355525016,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.344495813554852,
#   'hamming_distance': 200.64166666666668,
#   'normalized_mse': 0.9330434647817463},
#  {'model': 'Global Random',
#   'grc_pcts': 140.0,
#   'grc_dim': 145.48373742067088,
#   'grc_dim_norm': 1.1924896509891056,
#   'grc_by_mf_dim': 145.48373742067088,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7623354586032611,
#   'grc_pop_corr': 0.010346724326594338,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34738266050583655,
#   'hamming_distance': 202.04285714285714,
#   'normalized_mse': 0.9395594175170069},
#  {'model': 'Global Random',
#   'grc_pcts': 150.0,
#   'grc_dim': 147.4787073226924,
#   'grc_dim_norm': 1.2088418633007574,
#   'grc_by_mf_dim': 147.4787073226924,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.750036817290087,
#   'grc_pop_corr': 0.010259856145022466,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3453715310167913,
#   'hamming_distance': 200.22277777777776,
#   'normalized_mse': 0.9310955067791006},
#  {'model': 'Global Random',
#   'grc_pcts': 160.0,
#   'grc_dim': 146.22042053526476,
#   'grc_dim_norm': 1.1985280371743015,
#   'grc_by_mf_dim': 146.22042053526476,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7486099272275717,
#   'grc_pop_corr': 0.010316562050260053,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34464275941330974,
#   'hamming_distance': 199.94375,
#   'normalized_mse': 0.9297979445684524},
#  {'model': 'Global Random',
#   'grc_pcts': 170.0,
#   'grc_dim': 145.978946238002,
#   'grc_dim_norm': 1.1965487396557541,
#   'grc_by_mf_dim': 145.978946238002,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.767529137511704,
#   'grc_pop_corr': 0.010325116516243783,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3471819196428566,
#   'hamming_distance': 203.0769607843137,
#   'normalized_mse': 0.9443683072187209},
#  {'model': 'Global Random',
#   'grc_pcts': 180.0,
#   'grc_dim': 144.52774989597881,
#   'grc_dim_norm': 1.1846536876719576,
#   'grc_by_mf_dim': 144.52774989597881,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7541272667534535,
#   'grc_pop_corr': 0.010382642651630714,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34720853365384613,
#   'hamming_distance': 200.36898148148148,
#   'normalized_mse': 0.9317753975143298},
#  {'model': 'Global Random',
#   'grc_pcts': 190.0,
#   'grc_dim': 146.62209665780395,
#   'grc_dim_norm': 1.201820464408229,
#   'grc_by_mf_dim': 146.62209665780395,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7564562799801937,
#   'grc_pop_corr': 0.01029603790080822,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34469533521075574,
#   'hamming_distance': 201.4907894736842,
#   'normalized_mse': 0.9369921385494987},
#  {'model': 'Global Random',
#   'grc_pcts': 200.0,
#   'grc_dim': 146.35753904902896,
#   'grc_dim_norm': 1.1996519594182702,
#   'grc_by_mf_dim': 146.35753904902896,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7583703218769164,
#   'grc_pop_corr': 0.010306987608818164,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3458560482486266,
#   'hamming_distance': 201.49041666666668,
#   'normalized_mse': 0.9369904048859129},
#  {'model': 'Global Random',
#   'grc_pcts': 10.0,
#   'grc_dim': 65.90857584285729,
#   'grc_dim_norm': 0.5402342282201417,
#   'grc_by_mf_dim': 65.90857584285729,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7917951193756965,
#   'grc_pop_corr': 0.024078813104625674,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.323932926829268,
#   'hamming_distance': 217.65,
#   'normalized_mse': 1.0121372767857144},
#  {'model': 'Global Random',
#   'grc_pcts': 20.0,
#   'grc_dim': 90.93789627417031,
#   'grc_dim_norm': 0.7453925924112321,
#   'grc_by_mf_dim': 90.93789627417031,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7915075948458141,
#   'grc_pop_corr': 0.016970934413066623,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3325254141566266,
#   'hamming_distance': 210.7,
#   'normalized_mse': 0.9798177083333335},
#  {'model': 'Global Random',
#   'grc_pcts': 30.0,
#   'grc_dim': 99.34813780904724,
#   'grc_dim_norm': 0.8143289984348134,
#   'grc_by_mf_dim': 99.34813780904724,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7550860823242864,
#   'grc_pop_corr': 0.014650593562599146,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3426928038990828,
#   'hamming_distance': 203.0388888888889,
#   'normalized_mse': 0.9441912615740742},
#  {'model': 'Global Random',
#   'grc_pcts': 40.0,
#   'grc_dim': 119.5060062626762,
#   'grc_dim_norm': 0.9795574283825917,
#   'grc_by_mf_dim': 119.5060062626762,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7789629887106468,
#   'grc_pop_corr': 0.012221401524186177,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.32880859375000027,
#   'hamming_distance': 207.93541666666667,
#   'normalized_mse': 0.9669615730406746},
#  {'model': 'Global Random',
#   'grc_pcts': 50.0,
#   'grc_dim': 134.89461821103325,
#   'grc_dim_norm': 1.1056935918937152,
#   'grc_by_mf_dim': 134.89461821103325,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7824413464466153,
#   'grc_pop_corr': 0.010973862872653882,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3251454878826529,
#   'hamming_distance': 210.76833333333335,
#   'normalized_mse': 0.980135478670635},
#  {'model': 'Global Random',
#   'grc_pcts': 60.0,
#   'grc_dim': 123.03893211310968,
#   'grc_dim_norm': 1.0085158369927023,
#   'grc_by_mf_dim': 123.03893211310968,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7934418010232895,
#   'grc_pop_corr': 0.011608929162697191,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33944498697916675,
#   'hamming_distance': 209.6472222222222,
#   'normalized_mse': 0.9749219783399471},
#  {'model': 'Global Random',
#   'grc_pcts': 70.0,
#   'grc_dim': 130.53538504674196,
#   'grc_dim_norm': 1.0699621725142785,
#   'grc_by_mf_dim': 130.53538504674196,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7819443673527087,
#   'grc_pop_corr': 0.011128572872123325,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33803476706642116,
#   'hamming_distance': 207.7488095238095,
#   'normalized_mse': 0.9660937942885487},
#  {'model': 'Global Random',
#   'grc_pcts': 80.0,
#   'grc_dim': 137.00427730073739,
#   'grc_dim_norm': 1.122985879514241,
#   'grc_by_mf_dim': 137.00427730073739,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7620160475611064,
#   'grc_pop_corr': 0.010762605478843841,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3345480285234904,
#   'hamming_distance': 204.15625,
#   'normalized_mse': 0.9493873232886906},
#  {'model': 'Global Random',
#   'grc_pcts': 90.0,
#   'grc_dim': 131.46569146706048,
#   'grc_dim_norm': 1.0775876349759055,
#   'grc_by_mf_dim': 131.46569146706048,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7700345327969682,
#   'grc_pop_corr': 0.011022043290434753,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34051939498546563,
#   'hamming_distance': 203.77962962962962,
#   'normalized_mse': 0.9476359264770724},
#  {'model': 'Global Random',
#   'grc_pcts': 100.0,
#   'grc_dim': 139.7341567469478,
#   'grc_dim_norm': 1.1453619405487525,
#   'grc_by_mf_dim': 139.7341567469478,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7724574755763838,
#   'grc_pop_corr': 0.010616062598151722,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3345128066976121,
#   'hamming_distance': 206.85083333333333,
#   'normalized_mse': 0.9619179377480159},
#  {'model': 'Global Random',
#   'grc_pcts': 110.00000000000003,
#   'grc_dim': 135.85632795336915,
#   'grc_dim_norm': 1.1135764586341734,
#   'grc_by_mf_dim': 135.85632795336915,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7712653033418408,
#   'grc_pop_corr': 0.010792009670766331,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3341721754807691,
#   'hamming_distance': 206.2810606060606,
#   'normalized_mse': 0.9592683249909812},
#  {'model': 'Global Random',
#   'grc_pcts': 120.0,
#   'grc_dim': 142.98364378206202,
#   'grc_dim_norm': 1.1719970801808361,
#   'grc_by_mf_dim': 142.98364378206202,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7670161323621996,
#   'grc_pop_corr': 0.010459957085083913,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33210972377232156,
#   'hamming_distance': 206.01666666666668,
#   'normalized_mse': 0.9580388144841271},
#  {'model': 'Global Random',
#   'grc_pcts': 130.0,
#   'grc_dim': 143.25698821835738,
#   'grc_dim_norm': 1.1742376083471917,
#   'grc_by_mf_dim': 143.25698821835738,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7878157404736132,
#   'grc_pop_corr': 0.010441736186772708,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3360697231624756,
#   'hamming_distance': 208.32179487179488,
#   'normalized_mse': 0.9687583466880343},
#  {'model': 'Global Random',
#   'grc_pcts': 140.0,
#   'grc_dim': 143.02275575947039,
#   'grc_dim_norm': 1.1723176701595934,
#   'grc_by_mf_dim': 143.02275575947039,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7615977448695639,
#   'grc_pop_corr': 0.010452904311063585,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33394666988416966,
#   'hamming_distance': 204.29642857142858,
#   'normalized_mse': 0.9500391953656464},
#  {'model': 'Global Random',
#   'grc_pcts': 150.0,
#   'grc_dim': 140.59030931519422,
#   'grc_dim_norm': 1.1523795845507723,
#   'grc_by_mf_dim': 140.59030931519422,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7735433347841916,
#   'grc_pop_corr': 0.010554884336415129,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3387027138157892,
#   'hamming_distance': 205.44722222222222,
#   'normalized_mse': 0.9553907283399472},
#  {'model': 'Global Random',
#   'grc_pcts': 160.0,
# ...
#   'hamming_distance': 208.075,
#   'normalized_mse': 0.9676106770833335},
#  {'model': 'Global Random',
#   'grc_pcts': 30.0,
#   'grc_dim': 102.8843640056134,
#   'grc_dim_norm': 0.843314459062405,
#   'grc_by_mf_dim': 102.8843640056134,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.733462647978076,
#   'grc_pop_corr': 0.014292622367226523,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3402885210396037,
#   'hamming_distance': 202.125,
#   'normalized_mse': 0.9399414062500001},
#  {'model': 'Global Random',
#   'grc_pcts': 40.0,
#   'grc_dim': 111.21701651479636,
#   'grc_dim_norm': 0.9116148894655439,
#   'grc_by_mf_dim': 111.21701651479636,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7406879681630283,
#   'grc_pop_corr': 0.012805473887716795,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33802914450354526,
#   'hamming_distance': 200.66041666666666,
#   'normalized_mse': 0.9331306578621033},
#  {'model': 'Global Random',
#   'grc_pcts': 50.0,
#   'grc_dim': 127.74637282538284,
#   'grc_dim_norm': 1.0471014166014987,
#   'grc_by_mf_dim': 127.74637282538284,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7329306319484,
#   'grc_pop_corr': 0.011395824862912489,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34772398843930624,
#   'hamming_distance': 197.14333333333335,
#   'normalized_mse': 0.9167751736111113},
#  {'model': 'Global Random',
#   'grc_pcts': 60.0,
#   'grc_dim': 129.3509908718276,
#   'grc_dim_norm': 1.0602540235395705,
#   'grc_by_mf_dim': 129.3509908718276,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7591696026925099,
#   'grc_pop_corr': 0.011252832392674694,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3454279119318178,
#   'hamming_distance': 201.98194444444445,
#   'normalized_mse': 0.9392761553406085},
#  {'model': 'Global Random',
#   'grc_pcts': 70.0,
#   'grc_dim': 139.4406594796691,
#   'grc_dim_norm': 1.1429562252431895,
#   'grc_by_mf_dim': 139.4406594796691,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7533820119373418,
#   'grc_pop_corr': 0.010650771029006151,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3304625984251967,
#   'hamming_distance': 204.19880952380953,
#   'normalized_mse': 0.9495852377409298},
#  {'model': 'Global Random',
#   'grc_pcts': 80.0,
#   'grc_dim': 131.49304277761425,
#   'grc_dim_norm': 1.0778118260460183,
#   'grc_by_mf_dim': 131.49304277761425,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7653504947330931,
#   'grc_pop_corr': 0.011042645755404694,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34315892269736836,
#   'hamming_distance': 201.93020833333333,
#   'normalized_mse': 0.9390355670262898},
#  {'model': 'Global Random',
#   'grc_pcts': 90.0,
#   'grc_dim': 137.3344391833445,
#   'grc_dim_norm': 1.1256921244536435,
#   'grc_by_mf_dim': 137.3344391833445,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7647367712341084,
#   'grc_pop_corr': 0.010734948785515175,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3331753883136098,
#   'hamming_distance': 204.8074074074074,
#   'normalized_mse': 0.9524153990299824},
#  {'model': 'Global Random',
#   'grc_pcts': 100.0,
#   'grc_dim': 139.3621397744665,
#   'grc_dim_norm': 1.1423126211021843,
#   'grc_by_mf_dim': 139.3621397744665,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7425750606045916,
#   'grc_pop_corr': 0.010633620672528182,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.33841476871468923,
#   'hamming_distance': 200.07916666666668,
#   'normalized_mse': 0.930427672371032},
#  {'model': 'Global Random',
#   'grc_pcts': 110.00000000000003,
#   'grc_dim': 134.373444161876,
#   'grc_dim_norm': 1.101421673458,
#   'grc_by_mf_dim': 134.373444161876,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7401916870374923,
#   'grc_pop_corr': 0.010862020155432452,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3391994724025972,
#   'hamming_distance': 199.87272727272727,
#   'normalized_mse': 0.9294676677489179},
#  {'model': 'Global Random',
#   'grc_pcts': 120.0,
#   'grc_dim': 142.76918762094098,
#   'grc_dim_norm': 1.1702392427945982,
#   'grc_by_mf_dim': 142.76918762094098,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.743676137423059,
#   'grc_pop_corr': 0.010462933816996398,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3398620892018775,
#   'hamming_distance': 199.80069444444445,
#   'normalized_mse': 0.929132693659061},
#  {'model': 'Global Random',
#   'grc_pcts': 130.0,
#   'grc_dim': 145.55778638447714,
#   'grc_dim_norm': 1.193096609708829,
#   'grc_by_mf_dim': 145.55778638447714,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7413597537028191,
#   'grc_pop_corr': 0.010339526494600093,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34042580711920534,
#   'hamming_distance': 200.35128205128206,
#   'normalized_mse': 0.9316930898962151},
#  {'model': 'Global Random',
#   'grc_pcts': 140.0,
#   'grc_dim': 138.82247316215344,
#   'grc_dim_norm': 1.1378891242799463,
#   'grc_by_mf_dim': 138.82247316215344,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7638554980334744,
#   'grc_pop_corr': 0.010632475937445233,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3397202765804601,
#   'hamming_distance': 203.1779761904762,
#   'normalized_mse': 0.9448380589214853},
#  {'model': 'Global Random',
#   'grc_pcts': 150.0,
#   'grc_dim': 140.05426328776792,
#   'grc_dim_norm': 1.1479857646538354,
#   'grc_by_mf_dim': 140.05426328776792,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7523380607001213,
#   'grc_pop_corr': 0.010579790867104116,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.341095940420561,
#   'hamming_distance': 202.0961111111111,
#   'normalized_mse': 0.9398070643187831},
#  {'model': 'Global Random',
#   'grc_pcts': 160.0,
#   'grc_dim': 146.1250899878086,
#   'grc_dim_norm': 1.1977466392443328,
#   'grc_by_mf_dim': 146.1250899878086,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.754629554372878,
#   'grc_pop_corr': 0.010317448903234135,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34224214702072536,
#   'hamming_distance': 201.45885416666667,
#   'normalized_mse': 0.9368436298673116},
#  {'model': 'Global Random',
#   'grc_pcts': 170.0,
#   'grc_dim': 144.49906672537367,
#   'grc_dim_norm': 1.1844185797161777,
#   'grc_by_mf_dim': 144.49906672537367,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7441093486142836,
#   'grc_pop_corr': 0.01038370879760229,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3403140677257525,
#   'hamming_distance': 200.40833333333333,
#   'normalized_mse': 0.9319583953373017},
#  {'model': 'Global Random',
#   'grc_pcts': 180.0,
#   'grc_dim': 145.60929744507638,
#   'grc_dim_norm': 1.1935188315170195,
#   'grc_by_mf_dim': 145.60929744507638,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.742715498203901,
#   'grc_pop_corr': 0.010337010148561842,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3407603346456691,
#   'hamming_distance': 199.6023148148148,
#   'normalized_mse': 0.9282101693397267},
#  {'model': 'Global Random',
#   'grc_pcts': 190.0,
#   'grc_dim': 145.25907142971113,
#   'grc_dim_norm': 1.190648126473042,
#   'grc_by_mf_dim': 145.25907142971113,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7517960818827638,
#   'grc_pop_corr': 0.010351175007877585,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3399609946925343,
#   'hamming_distance': 201.45263157894738,
#   'normalized_mse': 0.9368146929824563},
#  {'model': 'Global Random',
#   'grc_pcts': 200.0,
#   'grc_dim': 147.09708547015956,
#   'grc_dim_norm': 1.2057138153291767,
#   'grc_by_mf_dim': 147.09708547015956,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7525854673202854,
#   'grc_pop_corr': 0.010275065569620124,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34024466886269095,
#   'hamming_distance': 201.43791666666667,
#   'normalized_mse': 0.9367462642609128},
#  {'model': 'Global Random',
#   'grc_pcts': 10.0,
#   'grc_dim': 59.630961230140855,
#   'grc_dim_norm': 0.4887783707388595,
#   'grc_by_mf_dim': 59.630961230140855,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7914723373973032,
#   'grc_pop_corr': 0.026278525755850966,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.35133539244186024,
#   'hamming_distance': 207.15833333333333,
#   'normalized_mse': 0.9633479042658731},
#  {'model': 'Global Random',
#   'grc_pcts': 20.0,
#   'grc_dim': 92.59840099269773,
#   'grc_dim_norm': 0.7590032868253913,
#   'grc_by_mf_dim': 92.59840099269773,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7563861909143546,
#   'grc_pop_corr': 0.016744557490183692,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3338773544520536,
#   'hamming_distance': 205.65833333333333,
#   'normalized_mse': 0.9563724578373017},
#  {'model': 'Global Random',
#   'grc_pcts': 30.0,
#   'grc_dim': 117.8178993609226,
#   'grc_dim_norm': 0.9657204865649394,
#   'grc_by_mf_dim': 117.8178993609226,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7862201640418143,
#   'grc_pop_corr': 0.0128924782135968,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34425511853448254,
#   'hamming_distance': 209.0638888888889,
#   'normalized_mse': 0.9722093047288362},
#  {'model': 'Global Random',
#   'grc_pcts': 40.0,
#   'grc_dim': 117.754603499736,
#   'grc_dim_norm': 0.965201668030623,
#   'grc_by_mf_dim': 117.754603499736,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7611190354880162,
#   'grc_pop_corr': 0.012347006625515437,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3470770474137928,
#   'hamming_distance': 203.74166666666667,
#   'normalized_mse': 0.9474593874007937},
#  {'model': 'Global Random',
#   'grc_pcts': 50.0,
#   'grc_dim': 125.36552113319945,
#   'grc_dim_norm': 1.0275862387967167,
#   'grc_by_mf_dim': 125.36552113319945,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7656910750200574,
#   'grc_pop_corr': 0.011562795640325087,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3433263062169315,
#   'hamming_distance': 202.81333333333333,
#   'normalized_mse': 0.9431423611111113},
#  {'model': 'Global Random',
#   'grc_pcts': 60.0,
#   'grc_dim': 135.7555824200684,
#   'grc_dim_norm': 1.1127506755743313,
#   'grc_by_mf_dim': 135.7555824200684,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7521141293341618,
#   'grc_pop_corr': 0.010880390984560546,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.335480576261468,
#   'hamming_distance': 202.44444444444446,
#   'normalized_mse': 0.9414269179894181},
#  {'model': 'Global Random',
#   'grc_pcts': 70.0,
#   'grc_dim': 128.43500808179925,
#   'grc_dim_norm': 1.0527459678836004,
#   'grc_by_mf_dim': 128.43500808179925,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7706796320094478,
#   'grc_pop_corr': 0.011236227242882164,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3529917983716479,
#   'hamming_distance': 202.96428571428572,
#   'normalized_mse': 0.9438443346088438},
#  {'model': 'Global Random',
#   'grc_pcts': 80.0,
#   'grc_dim': 137.75775073746877,
#   'grc_dim_norm': 1.1291618912907275,
#   'grc_by_mf_dim': 137.75775073746877,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7316188959568453,
#   'grc_pop_corr': 0.010728364118254601,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3438210227272725,
#   'hamming_distance': 197.68229166666666,
#   'normalized_mse': 0.919281490265377},
#  {'model': 'Global Random',
#   'grc_pcts': 90.0,
#   'grc_dim': 133.22182693223473,
#   'grc_dim_norm': 1.0919821879691372,
#   'grc_by_mf_dim': 133.22182693223473,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.765294070879524,
#   'grc_pop_corr': 0.010940275106408999,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.35195312499999987,
#   'hamming_distance': 201.28148148148148,
#   'normalized_mse': 0.936018794091711},
#  {'model': 'Global Random',
#   'grc_pcts': 100.0,
#   'grc_dim': 138.0315319135853,
#   'grc_dim_norm': 1.1314059992916827,
#   'grc_by_mf_dim': 138.0315319135853,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7587557876071707,
#   'grc_pop_corr': 0.01069091305141401,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.35324346823770525,
#   'hamming_distance': 199.93083333333334,
#   'normalized_mse': 0.9297378782242064},
#  {'model': 'Global Random',
#   'grc_pcts': 110.00000000000003,
#   'grc_dim': 135.25314637048453,
#   'grc_dim_norm': 1.1086323472990536,
#   'grc_by_mf_dim': 135.25314637048453,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7297811406190648,
#   'grc_pop_corr': 0.010813563563634979,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34767183344414876,
#   'hamming_distance': 196.45530303030304,
#   'normalized_mse': 0.9135756279310968},
#  {'model': 'Global Random',
#   'grc_pcts': 120.0,
#   'grc_dim': 140.14699925699188,
#   'grc_dim_norm': 1.1487458955491137,
#   'grc_by_mf_dim': 140.14699925699188,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.755747061122342,
#   'grc_pop_corr': 0.010580199179276661,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34195223721590906,
#   'hamming_distance': 201.12083333333334,
#   'normalized_mse': 0.9352717323908731},
#  {'model': 'Global Random',
#   'grc_pcts': 130.0,
#   'grc_dim': 142.47428642776487,
#   'grc_dim_norm': 1.167822019899712,
#   'grc_by_mf_dim': 142.47428642776487,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7371171151932117,
#   'grc_pop_corr': 0.010475468340260084,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34871364653243847,
#   'hamming_distance': 198.18205128205128,
#   'normalized_mse': 0.9216055212148964},
#  {'model': 'Global Random',
#   'grc_pcts': 140.0,
#   'grc_dim': 137.63057744506648,
#   'grc_dim_norm': 1.1281194872546432,
#   'grc_by_mf_dim': 137.63057744506648,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.752969874716329,
#   'grc_pop_corr': 0.010685640622893292,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3447555693069305,
#   'hamming_distance': 200.6702380952381,
#   'normalized_mse': 0.9331763304280045},
#  {'model': 'Global Random',
#   'grc_pcts': 150.0,
#   'grc_dim': 142.47439981660963,
#   'grc_dim_norm': 1.1678229493164725,
#   'grc_by_mf_dim': 142.47439981660963,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7549849706529599,
#   'grc_pop_corr': 0.010470925217511843,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3442839736238533,
#   'hamming_distance': 200.90666666666667,
#   'normalized_mse': 0.9342757936507937},
#  {'model': 'Global Random',
#   'grc_pcts': 160.0,
#   'grc_dim': 143.14110792252205,
#   'grc_dim_norm': 1.173287769856738,
#   'grc_by_mf_dim': 143.14110792252205,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7556628433965547,
#   'grc_pop_corr': 0.010441833583550412,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34378361660929446,
#   'hamming_distance': 201.265625,
#   'normalized_mse': 0.9359450567336312},
#  {'model': 'Global Random',
#   'grc_pcts': 170.0,
#   'grc_dim': 143.58871520914906,
#   'grc_dim_norm': 1.1769566820422055,
#   'grc_by_mf_dim': 143.58871520914906,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7524108282283046,
#   'grc_pop_corr': 0.010422217338729157,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3444911695846906,
#   'hamming_distance': 200.37058823529412,
#   'normalized_mse': 0.9317828693977593},
#  {'model': 'Global Random',
#   'grc_pcts': 180.0,
#   'grc_dim': 145.2819903073522,
#   'grc_dim_norm': 1.1908359861258377,
#   'grc_by_mf_dim': 145.2819903073522,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7498650779282763,
#   'grc_pop_corr': 0.010348375292239838,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34350208010835925,
#   'hamming_distance': 200.17314814814816,
#   'normalized_mse': 0.9308647142305998},
#  {'model': 'Global Random',
#   'grc_pcts': 190.0,
#   'grc_dim': 145.0632822038011,
#   'grc_dim_norm': 1.189043296752468,
#   'grc_by_mf_dim': 145.0632822038011,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7515390477644082,
#   'grc_pop_corr': 0.010358180359550509,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.3474701017228738,
#   'hamming_distance': 199.8671052631579,
#   'normalized_mse': 0.9294415237312031},
#  {'model': 'Global Random',
#   'grc_pcts': 200.0,
#   'grc_dim': 145.72515393827237,
#   'grc_dim_norm': 1.1944684749038719,
#   'grc_by_mf_dim': 145.72515393827237,
#   'num_grcs': 2400,
#   'num_mfs': 400,
#   'voi': 1.7516038535245715,
#   'grc_pop_corr': 0.010329853666207242,
#   'grc_pop_corr_norm': 1.0,
#   'binary_similarity': 0.34397243923611104,
#   'hamming_distance': 200.40916666666666,
#   'normalized_mse': 0.9319622705853176}]
