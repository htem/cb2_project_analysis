# %%
import random
import copy
import logging
import sys

from run_tests_201204 import *

import os
import sys
import importlib
from collections import defaultdict
sys.path.insert(0, '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc')
from tools_pattern import get_eucledean_dist
import compress_pickle
import my_plot
from my_plot import MyPlotData, my_box_plot

# script_n = os.path.basename(__file__).split('.')[0]
script_n = 'batch_dim_210119_plot_8192'


base_path = '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc/dimensionality_sim'

db = {}


name = 'batch_dim_210119_naive_random2_len_8192_10'
dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
db['naive_random2'] = dbb

# name = 'batch_dim_210119_naive_random3_len_8192_10'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['naive_random3'] = dbb

name = 'batch_dim_210119_data_len_8192_10'
dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
db['data'] = dbb

name = 'batch_dim_210119_global_random_len_8192_10'
dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
db['global_random'] = dbb

name = 'batch_dim_210119_expanded_random_30_len_8192_10'
dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
db['expanded_random_30'] = dbb

# db_old = compress_pickle.load(
#     '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc/dimensionality_sim/data/'
#     'batch_dim_201205_db.gz')
# db_old = db_old[0]
# db['data'] = {0: [db_old['data'][0]]}

mpd = MyPlotData()

def get_plot_name(model_name):
    if 'data' in model_name:
        return 'Observation'
    if 'classic_random' in model_name:
        return 'Classic Random'
    if 'naive_random3' in model_name:
        return 'Local\nRandom'
    if 'naive_random2' in model_name:
        return 'Local\nRandom2'
    if 'naive_random' in model_name:
        return 'Local\nRandom'
        # return model_name
    if 'data' in model_name:
        return 'Data'
    if 'expanded_random_30' in model_name:
        return 'LocalEx\nRandom'
    if 'global_random' in model_name:
        return 'Global\nRandom'
    return 'Unknown'


for model_name in [
        'naive_random2',
        'data',
#         'naive_random3',
        'expanded_random_30',
#         'expanded_random_50',
        'global_random',
#         'classic_random',
        ]:
    ress = db[model_name][0]
    for res in ress:
        mpd.add_data_point(
            model=get_plot_name(model_name),
            mf_dim=res['mf_dim'],
            grc_dim=res['grc_dim'],
            grc_dim_norm=res['grc_dim']/599.472991795093,
            pct_grc=res['pct_grc']/100,
            pct_mfs=res['pct_mfs']/100,
            pct_mf_dim=res['pct_mf_dim']/100,
            num_grcs=res['num_grcs'],
            num_mfs=res['num_mfs'],
            )

importlib.reload(my_plot); my_plot.my_catplot(
    mpd,
    x='model',
    y='pct_grc',
    context='paper',
    kind='bar',
    errwidth=4,
    height=4,
    aspect=1.5,
    font_scale=1.25,
    y_axis_label='Normalized Dimensionality',
#     y_axis_label='Dim / # of GrCs',
#     x_axis_label='Normalized Dimensionality',
    save_filename=f'{script_n}_norm_dim_grc.svg',
    show=True,
    )

# importlib.reload(my_plot); my_plot.my_catplot(
#     mpd,
#     x='model',
#     y='pct_mfs',
#     context='paper',
#     height=4,
#     aspect=1.33,
#     y_axis_label='Dim / MF dim',
#     x_axis_label='Normalized Dimensionality',
#     save_filename=f'{script_n}_pct_mfs.svg',
#     show=True,
#     )

# importlib.reload(my_plot); my_plot.my_catplot(
#     mpd,
#     x='model',
#     y='pct_mf_dim',
#     context='paper',
#     height=4,
#     aspect=2.33,
#     y_axis_label='Dim / MF dim',
#     x_axis_label='Normalized Dimensionality',
#     save_filename=f'{script_n}_pct_mf_dim.svg',
#     show=True,
#     )
# Out:
# Height: 4, Aspect: 1.5

# %%
mpd.data
# Out:
# [{'model': 'Observation',
#   'mf_dim': 434.9303375833406,
#   'grc_dim': 599.472991795093,
#   'grc_dim_norm': 0.9951769357697724,
#   'pct_grc': 0.495,
#   'pct_mfs': 1.23,
#   'pct_mf_dim': 1.3780000000000001,
#   'num_grcs': 1211,
#   'num_mfs': 487},
#  {'model': 'Local\nRandom',
#   'mf_dim': 420.0832063684192,
#   'grc_dim': 602.378301031865,
#   'grc_dim_norm': 1.0,
#   'pct_grc': 0.49700000000000005,
#   'pct_mfs': 1.287,
#   'pct_mf_dim': 1.433,
#   'num_grcs': 1211,
#   'num_mfs': 468},
#  {'model': 'Local\nRandom',
#   'mf_dim': 425.63491444561197,
#   'grc_dim': 604.112843861555,
#   'grc_dim_norm': 1.0028794908892282,
#   'pct_grc': 0.498,
#   'pct_mfs': 1.271,
#   'pct_mf_dim': 1.419,
#   'num_grcs': 1211,
#   'num_mfs': 475},
#  {'model': 'Local\nRandom',
#   'mf_dim': 426.3616236959319,
#   'grc_dim': 600.5427186506116,
#   'grc_dim_norm': 0.9969527747295859,
#   'pct_grc': 0.495,
#   'pct_mfs': 1.261,
#   'pct_mf_dim': 1.4080000000000001,
#   'num_grcs': 1211,
#   'num_mfs': 476},
#  {'model': 'Local\nRandom',
#   'mf_dim': 424.1342292198911,
#   'grc_dim': 605.4073176017414,
#   'grc_dim_norm': 1.0050284290863196,
#   'pct_grc': 0.499,
#   'pct_mfs': 1.2790000000000001,
#   'pct_mf_dim': 1.4269999999999998,
#   'num_grcs': 1211,
#   'num_mfs': 473},
#  {'model': 'Local\nRandom',
#   'mf_dim': 423.6286097492696,
#   'grc_dim': 609.1600375735766,
#   'grc_dim_norm': 1.0112582683175912,
#   'pct_grc': 0.503,
#   'pct_mfs': 1.29,
#   'pct_mf_dim': 1.4369999999999998,
#   'num_grcs': 1211,
#   'num_mfs': 472},
#  {'model': 'Local\nRandom',
#   'mf_dim': 421.8320624870213,
#   'grc_dim': 605.4783110724383,
#   'grc_dim_norm': 1.0051462843785424,
#   'pct_grc': 0.499,
#   'pct_mfs': 1.288,
#   'pct_mf_dim': 1.435,
#   'num_grcs': 1211,
#   'num_mfs': 470},
#  {'model': 'Local\nRandom',
#   'mf_dim': 421.8320624870213,
#   'grc_dim': 604.2769299966059,
#   'grc_dim_norm': 1.0031518880435908,
#   'pct_grc': 0.498,
#   'pct_mfs': 1.285,
#   'pct_mf_dim': 1.432,
#   'num_grcs': 1211,
#   'num_mfs': 470},
#  {'model': 'Local\nRandom',
#   'mf_dim': 421.8320624870213,
#   'grc_dim': 605.2856085784463,
#   'grc_dim_norm': 1.0048263815970813,
#   'pct_grc': 0.499,
#   'pct_mfs': 1.287,
#   'pct_mf_dim': 1.4340000000000002,
#   'num_grcs': 1211,
#   'num_mfs': 470},
#  {'model': 'Local\nRandom',
#   'mf_dim': 421.8320624870213,
#   'grc_dim': 607.0048554974566,
#   'grc_dim_norm': 1.0076804799536543,
#   'pct_grc': 0.501,
#   'pct_mfs': 1.291,
#   'pct_mf_dim': 1.4380000000000002,
#   'num_grcs': 1211,
#   'num_mfs': 470},
#  {'model': 'Local\nRandom',
#   'mf_dim': 419.1750538278003,
#   'grc_dim': 604.4671027497704,
#   'grc_dim_norm': 1.0034675912368147,
#   'pct_grc': 0.499,
#   'pct_mfs': 1.294,
#   'pct_mf_dim': 1.442,
#   'num_grcs': 1211,
#   'num_mfs': 467},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 438.5370036705424,
#   'grc_dim': 656.5114131903176,
#   'grc_dim_norm': 1.089865641019478,
#   'pct_grc': 0.542,
#   'pct_mfs': 1.337,
#   'pct_mf_dim': 1.4969999999999999,
#   'num_grcs': 1211,
#   'num_mfs': 491},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 431.1035750043008,
#   'grc_dim': 648.6632025371678,
#   'grc_dim_norm': 1.0768369335781476,
#   'pct_grc': 0.535,
#   'pct_mfs': 1.345,
#   'pct_mf_dim': 1.504,
#   'num_grcs': 1211,
#   'num_mfs': 482},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 443.79430138166765,
#   'grc_dim': 647.620289923949,
#   'grc_dim_norm': 1.0751056085761808,
#   'pct_grc': 0.534,
#   'pct_mfs': 1.3,
#   'pct_mf_dim': 1.459,
#   'num_grcs': 1211,
#   'num_mfs': 498},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 436.8983534022426,
#   'grc_dim': 652.7620954636172,
#   'grc_dim_norm': 1.0836414498089415,
#   'pct_grc': 0.539,
#   'pct_mfs': 1.334,
#   'pct_mf_dim': 1.494,
#   'num_grcs': 1211,
#   'num_mfs': 489},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 439.00831833685993,
#   'grc_dim': 651.1690701443069,
#   'grc_dim_norm': 1.0809968902081368,
#   'pct_grc': 0.537,
#   'pct_mfs': 1.3230000000000002,
#   'pct_mf_dim': 1.483,
#   'num_grcs': 1211,
#   'num_mfs': 492},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 437.75080790730544,
#   'grc_dim': 652.6363746315059,
#   'grc_dim_norm': 1.0834327423706158,
#   'pct_grc': 0.5379999999999999,
#   'pct_mfs': 1.331,
#   'pct_mf_dim': 1.49,
#   'num_grcs': 1211,
#   'num_mfs': 490},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 439.00831833685993,
#   'grc_dim': 654.8078506515269,
#   'grc_dim_norm': 1.0870375800885437,
#   'pct_grc': 0.54,
#   'pct_mfs': 1.33,
#   'pct_mf_dim': 1.4909999999999999,
#   'num_grcs': 1211,
#   'num_mfs': 492},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 442.5060744432268,
#   'grc_dim': 654.1299908359952,
#   'grc_dim_norm': 1.0859122742560285,
#   'pct_grc': 0.54,
#   'pct_mfs': 1.318,
#   'pct_mf_dim': 1.4780000000000002,
#   'num_grcs': 1211,
#   'num_mfs': 496},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 430.2109760944068,
#   'grc_dim': 648.5756804814263,
#   'grc_dim_norm': 1.0766916394073722,
#   'pct_grc': 0.535,
#   'pct_mfs': 1.348,
#   'pct_mf_dim': 1.507,
#   'num_grcs': 1211,
#   'num_mfs': 481},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 441.69610242662327,
#   'grc_dim': 654.4873922316663,
#   'grc_dim_norm': 1.0865055914373727,
#   'pct_grc': 0.54,
#   'pct_mfs': 1.3219999999999998,
#   'pct_mf_dim': 1.4809999999999999,
#   'num_grcs': 1211,
#   'num_mfs': 495},
#  {'model': 'Global\nRandom',
#   'mf_dim': 879.875215372593,
#   'grc_dim': 832.120937495814,
#   'grc_dim_norm': 1.3813926166835746,
#   'pct_grc': 0.687,
#   'pct_mfs': 0.742,
#   'pct_mf_dim': 0.945,
#   'num_grcs': 1211,
#   'num_mfs': 1121},
#  {'model': 'Global\nRandom',
#   'mf_dim': 877.4192947625427,
#   'grc_dim': 829.3346803677733,
#   'grc_dim_norm': 1.376767189234963,
#   'pct_grc': 0.684,
#   'pct_mfs': 0.742,
#   'pct_mf_dim': 0.945,
#   'num_grcs': 1211,
#   'num_mfs': 1117},
#  {'model': 'Global\nRandom',
#   'mf_dim': 867.7326102037305,
#   'grc_dim': 817.0182912226028,
#   'grc_dim_norm': 1.3563209196331651,
#   'pct_grc': 0.674,
#   'pct_mfs': 0.742,
#   'pct_mf_dim': 0.941,
#   'num_grcs': 1211,
#   'num_mfs': 1100},
#  {'model': 'Global\nRandom',
#   'mf_dim': 882.1561176682263,
#   'grc_dim': 837.876124919595,
#   'grc_dim_norm': 1.3909467248144989,
#   'pct_grc': 0.691,
#   'pct_mfs': 0.7440000000000001,
#   'pct_mf_dim': 0.9490000000000001,
#   'num_grcs': 1211,
#   'num_mfs': 1125},
#  {'model': 'Global\nRandom',
#   'mf_dim': 877.9217758022837,
#   'grc_dim': 830.8384941530126,
#   'grc_dim_norm': 1.3792636499850652,
#   'pct_grc': 0.6859999999999999,
#   'pct_mfs': 0.743,
#   'pct_mf_dim': 0.946,
#   'num_grcs': 1211,
#   'num_mfs': 1118},
#  {'model': 'Global\nRandom',
#   'mf_dim': 875.2650080208954,
#   'grc_dim': 825.5846285280575,
#   'grc_dim_norm': 1.3705417793334245,
#   'pct_grc': 0.6809999999999999,
#   'pct_mfs': 0.741,
#   'pct_mf_dim': 0.943,
#   'num_grcs': 1211,
#   'num_mfs': 1113},
#  {'model': 'Global\nRandom',
#   'mf_dim': 882.1017032133109,
#   'grc_dim': 831.9914247481536,
#   'grc_dim_norm': 1.3811776143379746,
#   'pct_grc': 0.687,
#   'pct_mfs': 0.74,
#   'pct_mf_dim': 0.943,
#   'num_grcs': 1211,
#   'num_mfs': 1124},
#  {'model': 'Global\nRandom',
#   'mf_dim': 879.6274532557851,
#   'grc_dim': 831.1977919902906,
#   'grc_dim_norm': 1.3798601154232502,
#   'pct_grc': 0.6859999999999999,
#   'pct_mfs': 0.742,
#   'pct_mf_dim': 0.9440000000000001,
#   'num_grcs': 1211,
#   'num_mfs': 1120},
#  {'model': 'Global\nRandom',
#   'mf_dim': 876.4776850964196,
#   'grc_dim': 830.0395405152956,
#   'grc_dim_norm': 1.3779373179502818,
#   'pct_grc': 0.685,
#   'pct_mfs': 0.743,
#   'pct_mf_dim': 0.9470000000000001,
#   'num_grcs': 1211,
#   'num_mfs': 1116},
#  {'model': 'Global\nRandom',
#   'mf_dim': 868.4622236019846,
#   'grc_dim': 812.3450754387939,
#   'grc_dim_norm': 1.348562977861684,
#   'pct_grc': 0.67,
#   'pct_mfs': 0.737,
#   'pct_mf_dim': 0.935,
#   'num_grcs': 1211,
#   'num_mfs': 1102}]

# %%
importlib.reload(my_plot); my_plot.my_catplot(
    mpd,
    x='model',
    y='grc_dim_norm',
    context='paper',
    height=4,
    aspect=1.2,
    errwidth=4,
    y_axis_label='Normalized Dimensionality',
#     y_axis_label='Dim / # of GrCs',
#     x_axis_label='Normalized Dimensionality',
    save_filename=f'{script_n}_norm_dim_grc_by_local.svg',
    show=True,
    )
# Out:
# Height: 4, Aspect: 1.2

# %%
db['data']
# Out:
# {0: {'mf_dim': 474.7653773986999,
#   'grc_dim': 681.5008632400699,
#   'pct_grc': 56.2,
#   'pct_mfs': 126.9,
#   'pct_mf_dim': 143.5,
#   'num_grcs': 1211,
#   'num_mfs': 537}}

# %%
db_old
# Out:
# {'expanded_random_30': {0: {'mf_dim': 438.5370036705424,
#    'grc_dim': 656.5114131903176,
#    'pct_grc': 54.2,
#    'pct_mfs': 133.7,
#    'pct_mf_dim': 149.7,
#    'num_grcs': 1211,
#    'num_mfs': 491}},
#  'expanded_random_50': {0: {'mf_dim': 474.7653773986999,
#    'grc_dim': 681.5008632400699,
#    'pct_grc': 56.2,
#    'pct_mfs': 126.9,
#    'pct_mf_dim': 143.5,
#    'num_grcs': 1211,
#    'num_mfs': 537}},
#  'data': {0: {'mf_dim': 474.7653773986999,
#    'grc_dim': 681.5008632400699,
#    'pct_grc': 56.2,
#    'pct_mfs': 126.9,
#    'pct_mf_dim': 143.5,
#    'num_grcs': 1211,
#    'num_mfs': 537}},
#  'classic_random': {0: {'mf_dim': 434.9303375833406,
#    'grc_dim': 735.8111799694942,
#    'pct_grc': 60.7,
#    'pct_mfs': 151.0,
#    'pct_mf_dim': 169.1,
#    'num_grcs': 1211,
#    'num_mfs': 487}},
#  'naive_random_17_1': {0: {'mf_dim': 414.05600382650914,
#    'grc_dim': 572.5242247256178,
#    'pct_grc': 47.2,
#    'pct_mfs': 124.1,
#    'pct_mf_dim': 138.2,
#    'num_grcs': 1211,
#    'num_mfs': 461}},
#  'naive_random_17_4': {0: {'mf_dim': 414.05600382650914,
#    'grc_dim': 572.5242247256178,
#    'pct_grc': 47.2,
#    'pct_mfs': 124.1,
#    'pct_mf_dim': 138.2,
#    'num_grcs': 1211,
#    'num_mfs': 461}}}
