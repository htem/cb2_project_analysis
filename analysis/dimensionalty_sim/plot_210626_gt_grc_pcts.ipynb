# %%
import random
import copy
import logging
import sys

# from run_tests_201204 import *

import os
import sys
import importlib
from collections import defaultdict
sys.path.insert(0, '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc')
from tools_pattern import get_eucledean_dist
import compress_pickle
import my_plot
from my_plot import MyPlotData, my_box_plot
import seaborn as sns

script_n = 'plot_210626_gt_grc_pcts'

data_script = 'batch_210623_dim_gt_grc_pct'
db_path = '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc/dimensionality_sim2/' \
            f'{data_script}/'


scaled_noise = 0
core_noise = 0
n_mfs = 497
n_grcs = 1847

pattern_type = 'binary'
db = {}

for model in ['observed', 'local_random', 'global_random']:
    for scale in [1.0, .5]:
        model_name = f'{model}_{scale}'
        db[model_name] = compress_pickle.load(
            db_path + \
                f'{data_script}_{model}_{pattern_type}_{n_grcs}_{n_mfs}_'
                f'scale_{scale}_'
                f'0.3_512_40.gz')

# %%
name_map = {
        'observed_1.0': "Observed",
        'observed_0.5': "50% subsampled",
}

palette = {
#     name_map['scaleup4']: sns.color_palette()[0],
#     name_map['global_random']: sns.color_palette()[1],
#     name_map['random']: sns.color_palette()[1],
#     name_map['local_random']: sns.color_palette()[2],
}


mpd = MyPlotData()
# ress_ref = db['local_random'][0][0]
# resss_ref2 = db['local_random'][0]
for model_name in [
        'observed_1.0',
        'observed_0.5',
        ]:
    resss = db[model_name]
    ress_tries = resss[0]  # get the first element in tuple
#     ress = ress[0]  # get the first try
    for n_try, ress in enumerate(ress_tries):
#         print(resss_ref2[0])
#         print(resss_ref2.keys())
#         if n_try >= len(resss_ref2):
#             print(n_try)
#             continue
#         ress_ref2 = resss_ref2[n_try]
#         noise = .3
#         for noise in ress:
    #         print(noise)
        for noise in ress:
            res = ress[noise]
            grc_dim2 = 1/res['grc_pop_corr']
            mpd.add_data_point(
                model=name_map[model_name],
                noise=noise*100,
                grc_dim=res['grc_dim'],
                grc_dim_norm=res['grc_dim']/79,
                grc_dim2=grc_dim2,
                grc_dim2_norm=grc_dim2/72,
                grc_by_mf_dim=res['grc_dim']/res['mf_dim'],
                num_grcs=res['num_grcs'],
                num_mfs=res['num_mfs'],
                voi=res['voi'],
                grc_pop_corr=res['grc_pop_corr'],
                binary_similarity=res['binary_similarity'],
                hamming_distance=res['hamming_distance'],
                normalized_mse=res['normalized_mse'],
                )

def custom_legend_fn(plt):
#     plt.legend(bbox_to_anchor=(1.025, .8), loc='upper left', borderaxespad=0.)
    plt.legend(loc='lower right', frameon=False, fontsize=13)

importlib.reload(my_plot); my_plot.my_relplot(
    mpd,
    x='noise',
    y='grc_dim2_norm',
    hue='model',
    context='paper',
#     context='talk',
#     palette=palette,
    linewidth=2,
#     log_scale_y=True,
    width=4,
    height=3,
#     ylim=[0, None],
    y_axis_label='Norm. Dim. ($x$)',
    x_axis_label='GrC (%)',
#     title='noise',
#     legend=None,
    save_filename=f'{script_n}_fig.svg',
    show=True,
    custom_legend_fn=custom_legend_fn,
    )
# Out:
# Height: 3, Aspect: 1.3333333333333333

# %%
name_map = {
        'observed_1.0': "Observed",
        'local_random_1.0': "Random",
}

palette = {
#     name_map['scaleup4']: sns.color_palette()[0],
#     name_map['global_random']: sns.color_palette()[1],
#     name_map['random']: sns.color_palette()[1],
#     name_map['local_random']: sns.color_palette()[2],
}


mpd = MyPlotData()
# ress_ref = db['local_random'][0][0]
# resss_ref2 = db['local_random'][0]
for model_name in [
        'local_random_1.0',
        'observed_1.0',
#         'observed_0.5',
        ]:
    resss = db[model_name]
    ress_tries = resss[0]  # get the first element in tuple
#     ress = ress[0]  # get the first try
    for n_try, ress in enumerate(ress_tries):
#         print(resss_ref2[0])
#         print(resss_ref2.keys())
#         if n_try >= len(resss_ref2):
#             print(n_try)
#             continue
#         ress_ref2 = resss_ref2[n_try]
#         noise = .3
#         for noise in ress:
    #         print(noise)
        for noise in ress:
            if noise in [.25, .35, .40, .5, .70]:
                continue
            res = ress[noise]
            grc_dim2 = 1/res['grc_pop_corr']
            mpd.add_data_point(
                model=name_map[model_name],
                noise=noise*100,
                grc_dim=res['grc_dim'],
                grc_dim_norm=res['grc_dim']/81,
                grc_dim2=grc_dim2,
                grc_dim2_norm=grc_dim2/72,
                grc_by_mf_dim=res['grc_dim']/res['mf_dim'],
                num_grcs=res['num_grcs'],
                num_mfs=res['num_mfs'],
                voi=res['voi'],
                grc_pop_corr=res['grc_pop_corr'],
                binary_similarity=res['binary_similarity'],
                hamming_distance=res['hamming_distance'],
                normalized_mse=res['normalized_mse'],
                )

def custom_legend_fn(plt):
#     plt.legend(bbox_to_anchor=(1.025, .8), loc='upper left', borderaxespad=0.)
    plt.legend(loc='lower right', frameon=False, fontsize=13)

importlib.reload(my_plot); my_plot.my_relplot(
    mpd,
    x='noise',
    y='grc_dim_norm',
    hue='model',
    context='paper',
#     context='talk',
#     palette=palette,
    linewidth=2,
#     log_scale_y=True,
    width=4,
    height=3,
    ylim=[.5, None],
    y_axis_label='Norm. Dim. ($x$)',
    x_axis_label='GrC (%)',
#     title='noise',
#     legend=None,
#     save_filename=f'{script_n}_fig_vs_random.svg',
    show=True,
    custom_legend_fn=custom_legend_fn,
    )
# Out:
# Height: 3, Aspect: 1.3333333333333333

# %%
name_map = {
        'observed_1.0': "Reconstructed",
        'local_random_1.0': "Random",
}

palette = {
    'Reconstructed': 'black'
}


mpd = MyPlotData()
# ress_ref = db['local_random'][0][0]
# resss_ref2 = db['local_random'][0]
for model_name in [
#         'local_random_1.0',
        'observed_1.0',
#         'observed_0.5',
        ]:
    resss = db[model_name]
    ress_tries = resss[0]  # get the first element in tuple
#     ress = ress[0]  # get the first try
    for n_try, ress in enumerate(ress_tries):
#         print(resss_ref2[0])
#         print(resss_ref2.keys())
#         if n_try >= len(resss_ref2):
#             print(n_try)
#             continue
#         ress_ref2 = resss_ref2[n_try]
#         noise = .3
#         for noise in ress:
    #         print(noise)
        for noise in ress:
            if noise in [.25, .35, .40, .5, .70]:
                continue
            res = ress[noise]
            grc_dim2 = 1/res['grc_pop_corr']
            mpd.add_data_point(
                model=name_map[model_name],
                noise=noise*100,
                inv_noise=(1-noise)*100,
                grc_dim=res['grc_dim'],
#                 grc_dim_norm=res['grc_dim']/81,
                grc_dim_norm=res['grc_dim']/81,
                grc_dim_norm2=res['grc_dim']/79.75,
                grc_dim2=grc_dim2,
                grc_dim2_norm=grc_dim2/72,
                grc_by_mf_dim=res['grc_dim']/res['mf_dim'],
                num_grcs=res['num_grcs'],
                num_mfs=res['num_mfs'],
                voi=res['voi'],
                grc_pop_corr=res['grc_pop_corr'],
                binary_similarity=res['binary_similarity'],
                hamming_distance=res['hamming_distance'],
                normalized_mse=res['normalized_mse'],
                )

def custom_legend_fn(plt):
#     plt.legend(bbox_to_anchor=(1.025, .8), loc='upper left', borderaxespad=0.)
    plt.legend(loc='lower right', frameon=False, fontsize=13, bbox_to_anchor=(.9, 0))

importlib.reload(my_plot); my_plot.my_relplot(
    mpd,
    x='inv_noise',
    y='grc_dim_norm2',
    hue='model',
    context='paper',
    palette=palette,
#     context='talk',
#     palette=palette,
    linewidth=2,
#     log_scale_y=True,
    width=4,
    height=3,
    ylim=[.55, None],
    xlim=[None, 100],
    y_axis_label='Normalized\nDimensionality ($x$)',
    x_axis_label='Removed GrCs (%)',
#     title='noise',
#     legend=None,
    save_filename=f'{script_n}_fig_decrease.svg',
    show=True,
    custom_legend_fn=custom_legend_fn,
    )
# Out:
# Height: 3, Aspect: 1.3333333333333333

# %%
mpd.data
# Out:
# [{'model': 'Random',
#   'noise': 5.0,
#   'grc_dim': 47.66565719846926,
#   'grc_dim_norm': 0.5607724376290502,
#   'grc_dim2': 30.87217043859902,
#   'grc_dim2_norm': 0.42878014498054196,
#   'grc_by_mf_dim': 47.66565719846926,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7355697247312385,
#   'grc_pop_corr': 0.032391632521881736,
#   'binary_similarity': 0.2890625000000001,
#   'hamming_distance': 37.9765625,
#   'normalized_mse': 0.1766023181733631},
#  {'model': 'Random',
#   'noise': 10.0,
#   'grc_dim': 56.141198027300106,
#   'grc_dim_norm': 0.6604846826741189,
#   'grc_dim2': 40.70179154187169,
#   'grc_dim2_norm': 0.5653026603037735,
#   'grc_by_mf_dim': 56.141198027300106,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7538548843995159,
#   'grc_pop_corr': 0.02456894308869075,
#   'binary_similarity': 0.3396724232456155,
#   'hamming_distance': 73.517578125,
#   'normalized_mse': 0.34187861851283485},
#  {'model': 'Random',
#   'noise': 15.0,
#   'grc_dim': 58.847478619135,
#   'grc_dim_norm': 0.6923232778721765,
#   'grc_dim2': 47.7330990297158,
#   'grc_dim2_norm': 0.6629597087460528,
#   'grc_by_mf_dim': 58.847478619135,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7582114048358342,
#   'grc_pop_corr': 0.020949823504597075,
#   'binary_similarity': 0.37091206395348886,
#   'hamming_distance': 106.466796875,
#   'normalized_mse': 0.49510229201543904},
#  {'model': 'Random',
#   'noise': 20.0,
#   'grc_dim': 71.16413763145447,
#   'grc_dim_norm': 0.8372251486053467,
#   'grc_dim2': 57.29357580774292,
#   'grc_dim2_norm': 0.7957441084408738,
#   'grc_by_mf_dim': 71.16413763145447,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7563371760177056,
#   'grc_pop_corr': 0.017453963832797733,
#   'binary_similarity': 0.3518295940170941,
#   'hamming_distance': 142.765625,
#   'normalized_mse': 0.6639026460193453},
#  {'model': 'Random',
#   'noise': 30.0,
#   'grc_dim': 71.57864205611021,
#   'grc_dim_norm': 0.8421016712483554,
#   'grc_dim2': 63.69937431332685,
#   'grc_dim2_norm': 0.8847135321295396,
#   'grc_by_mf_dim': 71.57864205611021,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.738989287916965,
#   'grc_pop_corr': 0.015698741326424383,
#   'binary_similarity': 0.3632455221036589,
#   'hamming_distance': 210.16796875,
#   'normalized_mse': 0.9773436046781995},
#  {'model': 'Random',
#   'noise': 45.0,
#   'grc_dim': 72.20511040482569,
#   'grc_dim_norm': 0.8494718871155963,
#   'grc_dim2': 67.03755717554729,
#   'grc_dim2_norm': 0.9310771829937123,
#   'grc_by_mf_dim': 72.20511040482569,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7789502535921373,
#   'grc_pop_corr': 0.014917011331146196,
#   'binary_similarity': 0.3603625351123616,
#   'hamming_distance': 327.541015625,
#   'normalized_mse': 1.5231632051013766},
#  {'model': 'Random',
#   'noise': 55.00000000000001,
#   'grc_dim': 81.76877638547396,
#   'grc_dim_norm': 0.9619856045349877,
#   'grc_dim2': 71.6907904870618,
#   'grc_dim2_norm': 0.995705423431414,
#   'grc_by_mf_dim': 81.76877638547396,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.740222083604533,
#   'grc_pop_corr': 0.013948793048675788,
#   'binary_similarity': 0.36725864031456984,
#   'hamming_distance': 382.970703125,
#   'normalized_mse': 1.7809277489071802},
#  {'model': 'Random',
#   'noise': 60.0,
#   'grc_dim': 79.1451340229247,
#   'grc_dim_norm': 0.931119223799114,
#   'grc_dim2': 71.01793950659541,
#   'grc_dim2_norm': 0.9863602709249363,
#   'grc_by_mf_dim': 79.1451340229247,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7666618016007796,
#   'grc_pop_corr': 0.014080949221388354,
#   'binary_similarity': 0.36126638829022956,
#   'hamming_distance': 430.298828125,
#   'normalized_mse': 2.0010176159086686},
#  {'model': 'Random',
#   'noise': 65.0,
#   'grc_dim': 75.24650999327804,
#   'grc_dim_norm': 0.8852530587444475,
#   'grc_dim2': 69.80460254090696,
#   'grc_dim2_norm': 0.9695083686237077,
#   'grc_by_mf_dim': 75.24650999327804,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7681858562922583,
#   'grc_pop_corr': 0.01432570294220899,
#   'binary_similarity': 0.3658033956692915,
#   'hamming_distance': 463.84765625,
#   'normalized_mse': 2.157029651460194},
#  {'model': 'Random',
#   'noise': 75.0,
#   'grc_dim': 77.16798254383039,
#   'grc_dim_norm': 0.9078586181627105,
#   'grc_dim2': 70.9847580093175,
#   'grc_dim2_norm': 0.9858994167960764,
#   'grc_by_mf_dim': 77.16798254383039,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7579718956945476,
#   'grc_pop_corr': 0.01408753129606696,
#   'binary_similarity': 0.3688387368266976,
#   'hamming_distance': 529.30078125,
#   'normalized_mse': 2.4614061628069197},
#  {'model': 'Random',
#   'noise': 80.0,
#   'grc_dim': 78.26912657904994,
#   'grc_dim_norm': 0.9208132538711757,
#   'grc_dim2': 71.58749658745063,
#   'grc_dim2_norm': 0.9942707859368143,
#   'grc_by_mf_dim': 78.26912657904994,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7470213294814603,
#   'grc_pop_corr': 0.013968919820773579,
#   'binary_similarity': 0.3656488078442434,
#   'hamming_distance': 561.986328125,
#   'normalized_mse': 2.6134036836170016},
#  {'model': 'Random',
#   'noise': 85.0,
#   'grc_dim': 78.37099878475343,
#   'grc_dim_norm': 0.9220117504088639,
#   'grc_dim2': 71.78725393347766,
#   'grc_dim2_norm': 0.997045193520523,
#   'grc_by_mf_dim': 78.37099878475343,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7661158645227288,
#   'grc_pop_corr': 0.013930049489379542,
#   'binary_similarity': 0.3637823547979791,
#   'hamming_distance': 606.380859375,
#   'normalized_mse': 2.819851466587612},
#  {'model': 'Random',
#   'noise': 90.0,
#   'grc_dim': 80.07158978893952,
#   'grc_dim_norm': 0.9420187033992885,
#   'grc_dim2': 72.55518474166213,
#   'grc_dim2_norm': 1.0077108991897519,
#   'grc_by_mf_dim': 80.07158978893952,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7544325839030992,
#   'grc_pop_corr': 0.013782612552921899,
#   'binary_similarity': 0.36336566797642433,
#   'hamming_distance': 636.099609375,
#   'normalized_mse': 2.958052498953683},
#  {'model': 'Random',
#   'noise': 95.0,
#   'grc_dim': 79.54217739245624,
#   'grc_dim_norm': 0.935790322264191,
#   'grc_dim2': 72.4896389195763,
#   'grc_dim2_norm': 1.0068005405496707,
#   'grc_by_mf_dim': 79.54217739245624,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.758340488972473,
#   'grc_pop_corr': 0.01379507492249273,
#   'binary_similarity': 0.3667326132162669,
#   'hamming_distance': 672.162109375,
#   'normalized_mse': 3.1257538568405883},
#  {'model': 'Random',
#   'noise': 100.0,
#   'grc_dim': 80.92228535233606,
#   'grc_dim_norm': 0.9520268864980713,
#   'grc_dim2': 73.10965324138313,
#   'grc_dim2_norm': 1.0154118505747656,
#   'grc_by_mf_dim': 80.92228535233606,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7588913719991865,
#   'grc_pop_corr': 0.01367808429754606,
#   'binary_similarity': 0.3633155153508774,
#   'hamming_distance': 710.109375,
#   'normalized_mse': 3.3022199358258932},
#  {'model': 'Random',
#   'noise': 5.0,
#   'grc_dim': 42.16068520974158,
#   'grc_dim_norm': 0.4960080612910774,
#   'grc_dim2': 28.246597543938886,
#   'grc_dim2_norm': 0.392313854776929,
#   'grc_by_mf_dim': 42.16068520974158,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.739466751590429,
#   'grc_pop_corr': 0.03540249399753205,
#   'binary_similarity': 0.37451171875,
#   'hamming_distance': 34.142578125,
#   'normalized_mse': 0.15877314976283483},
#  {'model': 'Random',
#   'noise': 10.0,
#   'grc_dim': 56.36115823510276,
#   'grc_dim_norm': 0.6630724498247383,
#   'grc_dim2': 40.757626421618,
#   'grc_dim2_norm': 0.5660781447446944,
#   'grc_by_mf_dim': 56.36115823510276,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7495817389679227,
#   'grc_pop_corr': 0.0245352854863402,
#   'binary_similarity': 0.36631944444444425,
#   'hamming_distance': 72.431640625,
#   'normalized_mse': 0.3368286859421503},
#  {'model': 'Random',
#   'noise': 15.0,
#   'grc_dim': 69.02646891361482,
#   'grc_dim_norm': 0.8120761048660567,
#   'grc_dim2': 51.57866883321597,
#   'grc_dim2_norm': 0.7163704004613329,
#   'grc_by_mf_dim': 69.02646891361482,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7415440652770966,
#   'grc_pop_corr': 0.019387859799825106,
#   'binary_similarity': 0.3477492559523811,
#   'hamming_distance': 107.01953125,
#   'normalized_mse': 0.4976726713634673},
#  {'model': 'Random',
#   'noise': 20.0,
#   'grc_dim': 63.60581101762449,
#   'grc_dim_norm': 0.7483036590308764,
#   'grc_dim2': 54.43574720619032,
#   'grc_dim2_norm': 0.7560520445304211,
#   'grc_by_mf_dim': 63.60581101762449,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.763645533076038,
#   'grc_pop_corr': 0.018370281502929055,
#   'binary_similarity': 0.34945652173913194,
#   'hamming_distance': 145.6328125,
#   'normalized_mse': 0.6772359212239585},
#  {'model': 'Random',
#   'noise': 30.0,
#   'grc_dim': 70.4909530399627,
#   'grc_dim_norm': 0.8293053298819142,
#   'grc_dim2': 63.30350129359819,
#   'grc_dim2_norm': 0.8792152957444193,
#   'grc_by_mf_dim': 70.4909530399627,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7349197600676676,
#   'grc_pop_corr': 0.015796914539719605,
#   'binary_similarity': 0.34401523919753074,
#   'hamming_distance': 213.734375,
#   'normalized_mse': 0.9939284551711312},
#  {'model': 'Random',
#   'noise': 45.0,
#   'grc_dim': 85.43750465344694,
#   'grc_dim_norm': 1.005147113569964,
#   'grc_dim2': 72.11805176407809,
#   'grc_dim2_norm': 1.0016396078344179,
#   'grc_by_mf_dim': 85.43750465344694,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7793916471411324,
#   'grc_pop_corr': 0.013866153834428716,
#   'binary_similarity': 0.3464956974637677,
#   'hamming_distance': 329.6328125,
#   'normalized_mse': 1.5328906831287203},
#  {'model': 'Random',
#   'noise': 55.00000000000001,
#   'grc_dim': 82.94321755936112,
#   'grc_dim_norm': 0.9758025595218955,
#   'grc_dim2': 72.14048840036695,
#   'grc_dim2_norm': 1.0019512277828744,
#   'grc_by_mf_dim': 82.94321755936112,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7711337649442165,
#   'grc_pop_corr': 0.013861841279063387,
#   'binary_similarity': 0.3533033288043477,
#   'hamming_distance': 399.78125,
#   'normalized_mse': 1.8591017950148812},
#  {'model': 'Random',
#   'noise': 60.0,
#   'grc_dim': 78.031683858493,
#   'grc_dim_norm': 0.9180198100999176,
#   'grc_dim2': 70.60621129267022,
#   'grc_dim2_norm': 0.9806418235093086,
#   'grc_by_mf_dim': 78.031683858493,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7737747223599938,
#   'grc_pop_corr': 0.014163059902122407,
#   'binary_similarity': 0.35799793714887584,
#   'hamming_distance': 433.818359375,
#   'normalized_mse': 2.017384483700707},
#  {'model': 'Random',
#   'noise': 65.0,
#   'grc_dim': 79.83207469162282,
#   'grc_dim_norm': 0.9392008787249744,
#   'grc_dim2': 71.56583273919186,
#   'grc_dim2_norm': 0.9939698991554425,
#   'grc_by_mf_dim': 79.83207469162282,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7690992426034828,
#   'grc_pop_corr': 0.013973148382752853,
#   'binary_similarity': 0.3621534612860896,
#   'hamming_distance': 466.3359375,
#   'normalized_mse': 2.1686008998325894},
#  {'model': 'Random',
#   'noise': 75.0,
#   'grc_dim': 79.34547000646296,
#   'grc_dim_norm': 0.9334761177230937,
#   'grc_dim2': 71.83822310040583,
#   'grc_dim2_norm': 0.9977530986167475,
#   'grc_by_mf_dim': 79.34547000646296,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7771583215613111,
#   'grc_pop_corr': 0.013920166129420188,
#   'binary_similarity': 0.3644801548549107,
#   'hamming_distance': 539.9453125,
#   'normalized_mse': 2.510906401134673},
#  {'model': 'Random',
#   'noise': 80.0,
#   'grc_dim': 82.19957528467201,
#   'grc_dim_norm': 0.9670538268784942,
#   'grc_dim2': 73.05692016246564,
#   'grc_dim2_norm': 1.0146794467009117,
#   'grc_by_mf_dim': 82.19957528467201,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7870693547468703,
#   'grc_pop_corr': 0.013687957249993254,
#   'binary_similarity': 0.356016577743902,
#   'hamming_distance': 586.037109375,
#   'normalized_mse': 2.725246974400112},
#  {'model': 'Random',
#   'noise': 85.0,
#   'grc_dim': 79.7115341178689,
#   'grc_dim_norm': 0.9377827543278693,
#   'grc_dim2': 72.30596062695089,
#   'grc_dim2_norm': 1.0042494531520958,
#   'grc_by_mf_dim': 79.7115341178689,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7633579375009094,
#   'grc_pop_corr': 0.013830118448454247,
#   'binary_similarity': 0.3538311605316972,
#   'hamming_distance': 612.400390625,
#   'normalized_mse': 2.84784407842727},
#  {'model': 'Random',
#   'noise': 90.0,
#   'grc_dim': 79.82712037933962,
#   'grc_dim_norm': 0.9391425926981132,
#   'grc_dim2': 72.4849877009512,
#   'grc_dim2_norm': 1.0067359402909888,
#   'grc_by_mf_dim': 79.82712037933962,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7648807355182226,
#   'grc_pop_corr': 0.013795960125228489,
#   'binary_similarity': 0.35681246971899305,
#   'hamming_distance': 648.51171875,
#   'normalized_mse': 3.015772501627605},
#  {'model': 'Random',
#   'noise': 95.0,
#   'grc_dim': 81.790314625473,
#   'grc_dim_norm': 0.9622389955938,
#   'grc_dim2': 73.3393002238114,
#   'grc_dim2_norm': 1.0186013919973806,
#   'grc_by_mf_dim': 81.790314625473,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7760430416877007,
#   'grc_pop_corr': 0.013635254180886298,
#   'binary_similarity': 0.35632064494680904,
#   'hamming_distance': 690.056640625,
#   'normalized_mse': 3.2089687529064364},
#  {'model': 'Random',
#   'noise': 100.0,
#   'grc_dim': 82.2149536263743,
#   'grc_dim_norm': 0.96723474854558,
#   'grc_dim2': 73.60215054994131,
#   'grc_dim2_norm': 1.0222520909714072,
#   'grc_by_mf_dim': 82.2149536263743,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.771886896027336,
#   'grc_pop_corr': 0.01358655953023369,
#   'binary_similarity': 0.3567863607325384,
#   'hamming_distance': 723.349609375,
#   'normalized_mse': 3.3637909662155883},
#  {'model': 'Random',
#   'noise': 5.0,
#   'grc_dim': 43.52863986254226,
#   'grc_dim_norm': 0.5121016454416737,
#   'grc_dim2': 28.989503433842817,
#   'grc_dim2_norm': 0.4026319921367058,
#   'grc_by_mf_dim': 43.52863986254226,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.650952212285429,
#   'grc_pop_corr': 0.034495244193544335,
#   'binary_similarity': 0.3491847826086967,
#   'hamming_distance': 33.677734375,
#   'normalized_mse': 0.15661148797898067},
#  {'model': 'Random',
#   'noise': 10.0,
#   'grc_dim': 50.636408170771,
#   'grc_dim_norm': 0.5957224490678941,
#   'grc_dim2': 38.69699384682935,
#   'grc_dim2_norm': 0.5374582478726299,
#   'grc_by_mf_dim': 50.636408170771,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7771588485606153,
#   'grc_pop_corr': 0.025841800630772647,
#   'binary_similarity': 0.33483492943548454,
#   'hamming_distance': 75.080078125,
#   'normalized_mse': 0.34914470854259677},
#  {'model': 'Random',
#   'noise': 15.0,
#   'grc_dim': 65.000405513568,
#   'grc_dim_norm': 0.7647106531008,
#   'grc_dim2': 49.946707004149815,
#   'grc_dim2_norm': 0.6937042639465252,
#   'grc_by_mf_dim': 65.000405513568,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.776183395923636,
#   'grc_pop_corr': 0.020021339943730728,
#   'binary_similarity': 0.3551986369680845,
#   'hamming_distance': 108.572265625,
#   'normalized_mse': 0.5048933483305432},
#  {'model': 'Random',
#   'noise': 20.0,
#   'grc_dim': 61.9454147629103,
#   'grc_dim_norm': 0.7287695854460036,
#   'grc_dim2': 53.70177665092362,
#   'grc_dim2_norm': 0.7458580090406058,
#   'grc_by_mf_dim': 61.9454147629103,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7354343765773106,
#   'grc_pop_corr': 0.018621357846319988,
#   'binary_similarity': 0.37619261615044225,
#   'hamming_distance': 136.318359375,
#   'normalized_mse': 0.6339209420340403},
#  {'model': 'Random',
#   'noise': 30.0,
#   'grc_dim': 75.00917570923181,
#   'grc_dim_norm': 0.8824608906968449,
#   'grc_dim2': 65.03758382943147,
#   'grc_dim2_norm': 0.9032997754087704,
#   'grc_by_mf_dim': 75.00917570923181,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7906067429484454,
#   'grc_pop_corr': 0.015375724944250926,
#   'binary_similarity': 0.36738918138586935,
#   'hamming_distance': 218.876953125,
#   'normalized_mse': 1.0178429739815849},
#  {'model': 'Random',
#   'noise': 45.0,
#   'grc_dim': 79.93198393166588,
#   'grc_dim_norm': 0.9403762815490104,
#   'grc_dim2': 69.98157926416991,
#   'grc_dim2_norm': 0.9719663786690265,
#   'grc_by_mf_dim': 79.93198393166588,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7833454605036412,
#   'grc_pop_corr': 0.014289474609098927,
#   'binary_similarity': 0.35321624087591236,
#   'hamming_distance': 329.931640625,
#   'normalized_mse': 1.5342803228469124},
#  {'model': 'Random',
#   'noise': 55.00000000000001,
#   'grc_dim': 86.73135004962978,
#   'grc_dim_norm': 1.0203688241132916,
#   'grc_dim2': 73.57272405637426,
#   'grc_dim2_norm': 1.0218433896718646,
#   'grc_by_mf_dim': 86.73135004962978,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7777549417385745,
#   'grc_pop_corr': 0.013591993674636288,
#   'binary_similarity': 0.34303042763157876,
#   'hamming_distance': 402.2421875,
#   'normalized_mse': 1.8705458868117562},
#  {'model': 'Random',
#   'noise': 60.0,
#   'grc_dim': 83.01086679730467,
#   'grc_dim_norm': 0.9765984329094667,
#   'grc_dim2': 72.45236192544951,
#   'grc_dim2_norm': 1.006282804520132,
#   'grc_by_mf_dim': 83.01086679730467,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7820353673106555,
#   'grc_pop_corr': 0.013802172536886495,
#   'binary_similarity': 0.3515140754132233,
#   'hamming_distance': 440.05078125,
#   'normalized_mse': 2.0463671003069197},
#  {'model': 'Random',
#   'noise': 65.0,
#   'grc_dim': 75.74832947055198,
#   'grc_dim_norm': 0.8911568173006115,
#   'grc_dim2': 69.98196270153389,
#   'grc_dim2_norm': 0.9719717041879706,
#   'grc_by_mf_dim': 75.74832947055198,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7614128476861675,
#   'grc_pop_corr': 0.014289396315803553,
#   'binary_similarity': 0.3635364583333332,
#   'hamming_distance': 462.29296875,
#   'normalized_mse': 2.1497998918805803},
#  {'model': 'Random',
#   'noise': 75.0,
#   'grc_dim': 81.75453762255587,
#   'grc_dim_norm': 0.9618180896771279,
#   'grc_dim2': 72.7209018230178,
#   'grc_dim2_norm': 1.0100125253196917,
#   'grc_by_mf_dim': 81.75453762255587,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7745512843605995,
#   'grc_pop_corr': 0.013751204604608982,
#   'binary_similarity': 0.35949192766075394,
#   'hamming_distance': 539.6484375,
#   'normalized_mse': 2.5095258440290182},
#  {'model': 'Random',
#   'noise': 80.0,
#   'grc_dim': 78.6013575353196,
#   'grc_dim_norm': 0.9247218533567011,
#   'grc_dim2': 71.72068606749657,
#   'grc_dim2_norm': 0.9961206398263412,
#   'grc_by_mf_dim': 78.6013575353196,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7832298541589005,
#   'grc_pop_corr': 0.013942978725257824,
#   'binary_similarity': 0.36338446392276413,
#   'hamming_distance': 577.8984375,
#   'normalized_mse': 2.6873997279575894},
#  {'model': 'Random',
#   'noise': 85.0,
#   'grc_dim': 80.82180877807643,
#   'grc_dim_norm': 0.9508448091538404,
#   'grc_dim2': 72.68111762264614,
#   'grc_dim2_norm': 1.0094599669811963,
#   'grc_by_mf_dim': 80.82180877807643,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7865448750273623,
#   'grc_pop_corr': 0.013758731740916678,
#   'binary_similarity': 0.36073288690476163,
#   'hamming_distance': 618.001953125,
#   'normalized_mse': 2.8738930111839665},
#  {'model': 'Random',
#   'noise': 90.0,
#   'grc_dim': 82.51825371460052,
#   'grc_dim_norm': 0.9708029848776532,
#   'grc_dim2': 73.44715590086176,
#   'grc_dim2_norm': 1.0200993875119688,
#   'grc_by_mf_dim': 82.51825371460052,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.789180006870137,
#   'grc_pop_corr': 0.01361523108328102,
#   'binary_similarity': 0.358256932021467,
#   'hamming_distance': 657.662109375,
#   'normalized_mse': 3.0583245413643976},
#  {'model': 'Random',
#   'noise': 95.0,
#   'grc_dim': 82.41843347192493,
#   'grc_dim_norm': 0.9696286290814697,
#   'grc_dim2': 73.53636324432948,
#   'grc_dim2_norm': 1.021338378393465,
#   'grc_by_mf_dim': 82.41843347192493,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7849041487959436,
#   'grc_pop_corr': 0.013598714375871882,
#   'binary_similarity': 0.35989338077910943,
#   'hamming_distance': 690.4140625,
#   'normalized_mse': 3.2106308710007445},
#  {'model': 'Random',
#   'noise': 100.0,
#   'grc_dim': 81.79444476243586,
#   'grc_dim_norm': 0.9622875854404219,
#   'grc_dim2': 73.41975805501772,
#   'grc_dim2_norm': 1.0197188618752462,
#   'grc_by_mf_dim': 81.79444476243586,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7818512705160745,
#   'grc_pop_corr': 0.013620311840998461,
#   'binary_similarity': 0.359336640752864,
#   'hamming_distance': 724.572265625,
#   'normalized_mse': 3.369476681663877},
#  {'model': 'Random',
#   'noise': 5.0,
#   'grc_dim': 49.51445204149096,
#   'grc_dim_norm': 0.5825229651940114,
#   'grc_dim2': 31.65245130605254,
#   'grc_dim2_norm': 0.43961737925072975,
#   'grc_by_mf_dim': 49.51445204149096,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.5136647220532875,
#   'grc_pop_corr': 0.031593129717848466,
#   'binary_similarity': 0.38683363970588186,
#   'hamming_distance': 30.05859375,
#   'normalized_mse': 0.13978140694754465},
#  {'model': 'Random',
#   'noise': 10.0,
#   'grc_dim': 60.282305529926376,
#   'grc_dim_norm': 0.709203594469722,
#   'grc_dim2': 42.206483654750606,
#   'grc_dim2_norm': 0.5862011618715361,
#   'grc_by_mf_dim': 60.282305529926376,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7299666504783222,
#   'grc_pop_corr': 0.02369304223919738,
#   'binary_similarity': 0.3597586495535714,
#   'hamming_distance': 69.671875,
#   'normalized_mse': 0.32399495442708337},
#  {'model': 'Random',
#   'noise': 15.0,
#   'grc_dim': 71.45475593789956,
#   'grc_dim_norm': 0.8406441875047007,
#   'grc_dim2': 52.51948181117386,
#   'grc_dim2_norm': 0.7294372473774148,
#   'grc_by_mf_dim': 71.45475593789956,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7039058064026178,
#   'grc_pop_corr': 0.019040553438728777,
#   'binary_similarity': 0.3372558593749995,
#   'hamming_distance': 103.33203125,
#   'normalized_mse': 0.48052469889322924},
#  {'model': 'Random',
#   'noise': 20.0,
#   'grc_dim': 77.46171944869835,
#   'grc_dim_norm': 0.9113143464552746,
#   'grc_dim2': 59.68044571775196,
#   'grc_dim2_norm': 0.8288950794132216,
#   'grc_by_mf_dim': 77.46171944869835,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6747269496209822,
#   'grc_pop_corr': 0.016755907030743738,
#   'binary_similarity': 0.329460299744898,
#   'hamming_distance': 135.998046875,
#   'normalized_mse': 0.6324313935779391},
#  {'model': 'Random',
#   'noise': 30.0,
#   'grc_dim': 71.08089866795412,
#   'grc_dim_norm': 0.8362458666818131,
#   'grc_dim2': 63.524150131267234,
#   'grc_dim2_norm': 0.8822798629342672,
#   'grc_by_mf_dim': 71.08089866795412,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7287940289147203,
#   'grc_pop_corr': 0.015742044528475947,
#   'binary_similarity': 0.36618652343750013,
#   'hamming_distance': 207.919921875,
#   'normalized_mse': 0.9668895176478796},
#  {'model': 'Random',
#   'noise': 45.0,
#   'grc_dim': 75.65046595381213,
#   'grc_dim_norm': 0.8900054818095545,
#   'grc_dim2': 68.4004975153186,
#   'grc_dim2_norm': 0.9500069099349806,
#   'grc_by_mf_dim': 75.65046595381213,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7424036819705306,
#   'grc_pop_corr': 0.014619776702297312,
#   'binary_similarity': 0.3654894770408161,
#   'hamming_distance': 316.1015625,
#   'normalized_mse': 1.4699663434709822},
#  {'model': 'Random',
#   'noise': 55.00000000000001,
#   'grc_dim': 76.47326952501005,
#   'grc_dim_norm': 0.8996855238236476,
#   'grc_dim2': 69.66313689006803,
#   'grc_dim2_norm': 0.9675435679176115,
#   'grc_by_mf_dim': 76.47326952501005,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7649107874534962,
#   'grc_pop_corr': 0.014354794294980584,
#   'binary_similarity': 0.3663434049684544,
#   'hamming_distance': 392.34765625,
#   'normalized_mse': 1.824533371698289},
#  {'model': 'Random',
#   'noise': 60.0,
#   'grc_dim': 80.38692490540758,
#   'grc_dim_norm': 0.9457285282989127,
#   'grc_dim2': 71.47482307975702,
#   'grc_dim2_norm': 0.9927058761077363,
#   'grc_by_mf_dim': 80.38692490540758,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.73434501945628,
#   'grc_pop_corr': 0.013990940542575731,
#   'binary_similarity': 0.3748296339563856,
#   'hamming_distance': 414.6953125,
#   'normalized_mse': 1.9284566243489587},
#  {'model': 'Random',
#   'noise': 65.0,
#   'grc_dim': 79.58275947157784,
#   'grc_dim_norm': 0.9362677584891511,
#   'grc_dim2': 71.47064530676963,
#   'grc_dim2_norm': 0.9926478514829115,
#   'grc_by_mf_dim': 79.58275947157784,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7508540837226754,
#   'grc_pop_corr': 0.013991758374473232,
#   'binary_similarity': 0.362603743224932,
#   'hamming_distance': 457.296875,
#   'normalized_mse': 2.126566569010417},
#  {'model': 'Random',
#   'noise': 75.0,
#   'grc_dim': 81.35021631885833,
#   'grc_dim_norm': 0.9570613684571568,
#   'grc_dim2': 72.56723286648484,
#   'grc_dim2_norm': 1.0078782342567338,
#   'grc_by_mf_dim': 81.35021631885833,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.751672093288716,
#   'grc_pop_corr': 0.013780324266186118,
#   'binary_similarity': 0.36842869454436455,
#   'hamming_distance': 528.369140625,
#   'normalized_mse': 2.457073756626674},
#  {'model': 'Random',
#   'noise': 80.0,
#   'grc_dim': 80.88286801636927,
#   'grc_dim_norm': 0.9515631531337562,
#   'grc_dim2': 72.5567311865097,
#   'grc_dim2_norm': 1.0077323775904123,
#   'grc_by_mf_dim': 80.88286801636927,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7556290237276275,
#   'grc_pop_corr': 0.013782318795887647,
#   'binary_similarity': 0.36623042544345924,
#   'hamming_distance': 566.080078125,
#   'normalized_mse': 2.632440839494978},
#  {'model': 'Random',
#   'noise': 85.0,
#   'grc_dim': 80.38081245185029,
#   'grc_dim_norm': 0.9456566170805917,
#   'grc_dim2': 72.55720256638276,
#   'grc_dim2_norm': 1.0077389245330939,
#   'grc_by_mf_dim': 80.38081245185029,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7362908702807456,
#   'grc_pop_corr': 0.013782229256772926,
#   'binary_similarity': 0.365174802559913,
#   'hamming_distance': 592.05859375,
#   'normalized_mse': 2.753248668852307},
#  {'model': 'Random',
#   'noise': 90.0,
#   'grc_dim': 80.97922737478436,
#   'grc_dim_norm': 0.9526967926445219,
#   'grc_dim2': 72.89535802705275,
#   'grc_dim2_norm': 1.0124355281535105,
#   'grc_by_mf_dim': 80.97922737478436,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7422794290031756,
#   'grc_pop_corr': 0.01371829464955618,
#   'binary_similarity': 0.36564243154158216,
#   'hamming_distance': 629.337890625,
#   'normalized_mse': 2.9266084943498885},
#  {'model': 'Random',
#   'noise': 95.0,
#   'grc_dim': 79.6560808005515,
#   'grc_dim_norm': 0.9371303623594295,
#   'grc_dim2': 72.52986764354628,
#   'grc_dim2_norm': 1.0073592728270317,
#   'grc_by_mf_dim': 79.6560808005515,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7478535355242684,
#   'grc_pop_corr': 0.013787423477932957,
#   'binary_similarity': 0.3671986394961973,
#   'hamming_distance': 667.033203125,
#   'normalized_mse': 3.101902916317895},
#  {'model': 'Random',
#   'noise': 100.0,
#   'grc_dim': 81.05806580183351,
#   'grc_dim_norm': 0.9536243035509825,
#   'grc_dim2': 73.15806632971685,
#   'grc_dim2_norm': 1.0160842545794007,
#   'grc_by_mf_dim': 81.05806580183351,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7462463391396537,
#   'grc_pop_corr': 0.01366903268729233,
#   'binary_similarity': 0.3657093636569872,
#   'hamming_distance': 702.287109375,
#   'normalized_mse': 3.2658440726143976},
#  {'model': 'Random',
#   'noise': 5.0,
#   'grc_dim': 44.83982437591358,
#   'grc_dim_norm': 0.5275273455989833,
#   'grc_dim2': 29.50473358956567,
#   'grc_dim2_norm': 0.40978796652174543,
#   'grc_by_mf_dim': 44.83982437591358,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.5715191124601897,
#   'grc_pop_corr': 0.03389286661288985,
#   'binary_similarity': 0.3296669407894749,
#   'hamming_distance': 32.68359375,
#   'normalized_mse': 0.15198843819754465},
#  {'model': 'Random',
#   'noise': 10.0,
#   'grc_dim': 70.98337423534815,
#   'grc_dim_norm': 0.8350985204158606,
#   'grc_dim2': 46.60523368628762,
#   'grc_dim2_norm': 0.6472949123095503,
#   'grc_by_mf_dim': 70.98337423534815,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.760759531758587,
#   'grc_pop_corr': 0.021456817634072374,
#   'binary_similarity': 0.3523995535714289,
#   'hamming_distance': 71.5703125,
#   'normalized_mse': 0.33282325381324407},
#  {'model': 'Random',
#   'noise': 15.0,
#   'grc_dim': 74.65906367674381,
#   'grc_dim_norm': 0.8783419256087507,
#   'grc_dim2': 53.6347909267319,
#   'grc_dim2_norm': 0.7449276517601653,
#   'grc_by_mf_dim': 74.65906367674381,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6609043372705294,
#   'grc_pop_corr': 0.01864461448849601,
#   'binary_similarity': 0.3420719630281693,
#   'hamming_distance': 100.3046875,
#   'normalized_mse': 0.4664466494605656},
#  {'model': 'Random',
#   'noise': 20.0,
#   'grc_dim': 83.61196617594828,
#   'grc_dim_norm': 0.9836701903052739,
#   'grc_dim2': 62.079787432638696,
#   'grc_dim2_norm': 0.8622192698977597,
#   'grc_by_mf_dim': 83.61196617594828,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7386400545325225,
#   'grc_pop_corr': 0.016108302578920333,
#   'binary_similarity': 0.36653645833333304,
#   'hamming_distance': 137.8671875,
#   'normalized_mse': 0.6411234537760417},
#  {'model': 'Random',
#   'noise': 30.0,
#   'grc_dim': 70.4894133726768,
#   'grc_dim_norm': 0.8292872161491387,
#   'grc_dim2': 63.300043569084785,
#   'grc_dim2_norm': 0.8791672717928443,
#   'grc_by_mf_dim': 70.4894133726768,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7286664048966667,
#   'grc_pop_corr': 0.015797777436102615,
#   'binary_similarity': 0.3856795873397433,
#   'hamming_distance': 206.419921875,
#   'normalized_mse': 0.959914071219308},
#  {'model': 'Random',
#   'noise': 45.0,
#   'grc_dim': 67.83391820944672,
#   'grc_dim_norm': 0.7980460965817261,
#   'grc_dim2': 65.30120856740012,
#   'grc_dim2_norm': 0.9069612301027795,
#   'grc_by_mf_dim': 67.83391820944672,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.729168684565967,
#   'grc_pop_corr': 0.015313652257566687,
#   'binary_similarity': 0.38972542790456444,
#   'hamming_distance': 304.70703125,
#   'normalized_mse': 1.4169783819289437},
#  {'model': 'Random',
#   'noise': 55.00000000000001,
#   'grc_dim': 75.71661325582957,
#   'grc_dim_norm': 0.8907836853627008,
#   'grc_dim2': 69.42131316272395,
#   'grc_dim2_norm': 0.9641849050378326,
#   'grc_by_mf_dim': 75.71661325582957,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7313141072947533,
#   'grc_pop_corr': 0.014404798100779142,
#   'binary_similarity': 0.3737884004237295,
#   'hamming_distance': 378.421875,
#   'normalized_mse': 1.7597743443080358},
#  {'model': 'Random',
#   'noise': 60.0,
#   'grc_dim': 76.1822441350347,
#   'grc_dim_norm': 0.8962616957062906,
#   'grc_dim2': 69.8843444241314,
#   'grc_dim2_norm': 0.9706158947796028,
#   'grc_by_mf_dim': 76.1822441350347,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7436868806445136,
#   'grc_pop_corr': 0.01430935652670579,
#   'binary_similarity': 0.36935434080547114,
#   'hamming_distance': 419.1484375,
#   'normalized_mse': 1.94916498093378},
#  {'model': 'Random',
#   'noise': 65.0,
#   'grc_dim': 77.61168735298772,
#   'grc_dim_norm': 0.913078674741032,
#   'grc_dim2': 70.70507067390828,
#   'grc_dim2_norm': 0.9820148704709484,
#   'grc_by_mf_dim': 77.61168735298772,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7465366267998437,
#   'grc_pop_corr': 0.014143257201622766,
#   'binary_similarity': 0.37125108506944476,
#   'hamming_distance': 453.9921875,
#   'normalized_mse': 2.1111987885974703},
#  {'model': 'Random',
#   'noise': 75.0,
#   'grc_dim': 76.71315912995439,
#   'grc_dim_norm': 0.9025077544700517,
#   'grc_dim2': 70.82429997802342,
#   'grc_dim2_norm': 0.983670833028103,
#   'grc_by_mf_dim': 76.71315912995439,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7585416826441052,
#   'grc_pop_corr': 0.014119447708064848,
#   'binary_similarity': 0.376803234011628,
#   'hamming_distance': 524.568359375,
#   'normalized_mse': 2.4393989926292785},
#  {'model': 'Random',
#   'noise': 80.0,
#   'grc_dim': 79.35012531364055,
#   'grc_dim_norm': 0.93353088604283,
#   'grc_dim2': 72.00017545140415,
#   'grc_dim2_norm': 1.0000024368250575,
#   'grc_by_mf_dim': 79.35012531364055,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7384121581504208,
#   'grc_pop_corr': 0.013888855044178897,
#   'binary_similarity': 0.3730958143507973,
#   'hamming_distance': 552.16796875,
#   'normalized_mse': 2.5677453903924854},
#  {'model': 'Random',
#   'noise': 85.0,
#   'grc_dim': 81.30150546238558,
#   'grc_dim_norm': 0.9564882995574774,
#   'grc_dim2': 72.88575304097554,
#   'grc_dim2_norm': 1.0123021255691047,
#   'grc_by_mf_dim': 81.30150546238558,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.748797600153439,
#   'grc_pop_corr': 0.013720102465536869,
#   'binary_similarity': 0.37349728118448533,
#   'hamming_distance': 591.37109375,
#   'normalized_mse': 2.7500515892392117},
#  {'model': 'Random',
#   'noise': 90.0,
#   'grc_dim': 82.42893749001438,
#   'grc_dim_norm': 0.969752205764875,
#   'grc_dim2': 73.42887774980503,
#   'grc_dim2_norm': 1.0198455243028475,
#   'grc_by_mf_dim': 82.42893749001438,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7511039780082154,
#   'grc_pop_corr': 0.013618620230140386,
#   'binary_similarity': 0.3701937806372541,
#   'hamming_distance': 628.28125,
#   'normalized_mse': 2.9216948009672623},
#  {'model': 'Random',
#   'noise': 95.0,
#   'grc_dim': 82.0992417712076,
#   'grc_dim_norm': 0.9658734326024424,
#   'grc_dim2': 73.42808947814196,
#   'grc_dim2_norm': 1.019834576085305,
#   'grc_by_mf_dim': 82.0992417712076,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7383218627100891,
#   'grc_pop_corr': 0.013618766429946126,
#   'binary_similarity': 0.37082331730769197,
#   'hamming_distance': 657.294921875,
#   'normalized_mse': 3.056617010207404},
#  {'model': 'Random',
#   'noise': 100.0,
#   'grc_dim': 81.761542154367,
#   'grc_dim_norm': 0.9619004959337295,
#   'grc_dim2': 73.41280031008996,
#   'grc_dim2_norm': 1.0196222265290273,
#   'grc_by_mf_dim': 81.761542154367,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7440974947025354,
#   'grc_pop_corr': 0.013621602714732004,
#   'binary_similarity': 0.37242991313177004,
#   'hamming_distance': 694.0703125,
#   'normalized_mse': 3.2276335216703873},
#  {'model': 'Random',
#   'noise': 5.0,
#   'grc_dim': 43.624758924162705,
#   'grc_dim_norm': 0.513232457931326,
#   'grc_dim2': 28.84616703973461,
#   'grc_dim2_norm': 0.40064120888520294,
#   'grc_by_mf_dim': 43.624758924162705,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7860217294596135,
#   'grc_pop_corr': 0.03466665081092175,
#   'binary_similarity': 0.38715977822580433,
#   'hamming_distance': 36.302734375,
#   'normalized_mse': 0.16881851922898067},
#  {'model': 'Random',
#   'noise': 10.0,
#   'grc_dim': 51.51174146826231,
#   'grc_dim_norm': 0.6060204878619095,
#   'grc_dim2': 39.00917297815751,
#   'grc_dim2_norm': 0.5417940691410765,
#   'grc_by_mf_dim': 51.51174146826231,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.753630406312661,
#   'grc_pop_corr': 0.02563499617282151,
#   'binary_similarity': 0.3858398437500003,
#   'hamming_distance': 69.134765625,
#   'normalized_mse': 0.3214972359793527},
#  {'model': 'Random',
#   'noise': 15.0,
#   'grc_dim': 58.61387334388652,
#   'grc_dim_norm': 0.6895749805163119,
#   'grc_dim2': 47.66815374153161,
#   'grc_dim2_norm': 0.6620576908546058,
#   'grc_by_mf_dim': 58.61387334388652,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.8032695240535614,
#   'grc_pop_corr': 0.020978366509058533,
#   'binary_similarity': 0.36275227864583376,
#   'hamming_distance': 111.8671875,
#   'normalized_mse': 0.5202157156808036},
#  {'model': 'Random',
#   'noise': 20.0,
#   'grc_dim': 62.97559649322539,
#   'grc_dim_norm': 0.740889370508534,
#   'grc_dim2': 54.16273721426759,
#   'grc_dim2_norm': 0.7522602390870499,
#   'grc_by_mf_dim': 62.97559649322539,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7453102564842018,
#   'grc_pop_corr': 0.01846287782768444,
#   'binary_similarity': 0.38353650323275873,
#   'hamming_distance': 136.490234375,
#   'normalized_mse': 0.6347202119373141},
#  {'model': 'Random',
#   'noise': 30.0,
#   'grc_dim': 81.05030329700507,
#   'grc_dim_norm': 0.9535329799647656,
#   'grc_dim2': 67.38093874883735,
#   'grc_dim2_norm': 0.9358463715116299,
#   'grc_by_mf_dim': 81.05030329700507,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.745609368834173,
#   'grc_pop_corr': 0.01484099240183493,
#   'binary_similarity': 0.35469443417159746,
#   'hamming_distance': 212.060546875,
#   'normalized_mse': 0.9861446562267486},
#  {'model': 'Random',
#   'noise': 45.0,
#   'grc_dim': 77.25074314346027,
#   'grc_dim_norm': 0.9088322722760032,
#   'grc_dim2': 68.97181783216148,
#   'grc_dim2_norm': 0.9579419143355761,
#   'grc_by_mf_dim': 77.25074314346027,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7511761104406578,
#   'grc_pop_corr': 0.014498675421799613,
#   'binary_similarity': 0.35628906250000014,
#   'hamming_distance': 321.208984375,
#   'normalized_mse': 1.4937173752557666},
#  {'model': 'Random',
#   'noise': 55.00000000000001,
#   'grc_dim': 76.53863853564754,
#   'grc_dim_norm': 0.900454571007618,
#   'grc_dim2': 69.65372724844057,
#   'grc_dim2_norm': 0.9674128784505636,
#   'grc_by_mf_dim': 76.53863853564754,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.758643107995512,
#   'grc_pop_corr': 0.014356733508792786,
#   'binary_similarity': 0.3612544221698115,
#   'hamming_distance': 390.140625,
#   'normalized_mse': 1.8142700195312502},
#  {'model': 'Random',
#   'noise': 60.0,
#   'grc_dim': 74.79194893323275,
#   'grc_dim_norm': 0.8799052815674441,
#   'grc_dim2': 69.36627055303276,
#   'grc_dim2_norm': 0.9634204243476773,
#   'grc_by_mf_dim': 74.79194893323275,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7611079432676298,
#   'grc_pop_corr': 0.014416228406505832,
#   'binary_similarity': 0.37345658225574724,
#   'hamming_distance': 421.345703125,
#   'normalized_mse': 1.9593829200381327},
#  {'model': 'Random',
#   'noise': 65.0,
#   'grc_dim': 80.97037335967639,
#   'grc_dim_norm': 0.9525926277608987,
#   'grc_dim2': 71.95283488209712,
#   'grc_dim2_norm': 0.9993449289180156,
#   'grc_by_mf_dim': 80.97037335967639,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7545257066795297,
#   'grc_pop_corr': 0.013897993062241583,
#   'binary_similarity': 0.36928315033783776,
#   'hamming_distance': 456.65625,
#   'normalized_mse': 2.1235874720982144},
#  {'model': 'Random',
#   'noise': 75.0,
#   'grc_dim': 77.47404046839847,
#   'grc_dim_norm': 0.9114592996282173,
#   'grc_dim2': 71.11297739279676,
#   'grc_dim2_norm': 0.9876802415666217,
#   'grc_by_mf_dim': 77.47404046839847,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7741725741642802,
#   'grc_pop_corr': 0.014062130945192191,
#   'binary_similarity': 0.36704490459070727,
#   'hamming_distance': 534.779296875,
#   'normalized_mse': 2.4868828909737726},
#  {'model': 'Random',
#   'noise': 80.0,
#   'grc_dim': 79.32780586327328,
#   'grc_dim_norm': 0.9332683042738034,
#   'grc_dim2': 71.96882712058107,
#   'grc_dim2_norm': 0.9995670433414037,
#   'grc_by_mf_dim': 79.32780586327328,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7676007660749349,
#   'grc_pop_corr': 0.013894904780434139,
#   'binary_similarity': 0.3663988173890061,
#   'hamming_distance': 568.220703125,
#   'normalized_mse': 2.6423953828357516},
#  {'model': 'Random',
#   'noise': 85.0,
#   'grc_dim': 79.68313094100185,
#   'grc_dim_norm': 0.9374485993059041,
#   'grc_dim2': 72.26607243546317,
#   'grc_dim2_norm': 1.0036954504925442,
#   'grc_by_mf_dim': 79.68313094100185,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7697425485904923,
#   'grc_pop_corr': 0.013837752160850373,
#   'binary_similarity': 0.36593027189960714,
#   'hamming_distance': 603.978515625,
#   'normalized_mse': 2.808679853166853},
#  {'model': 'Random',
#   'noise': 90.0,
#   'grc_dim': 77.70395248206445,
#   'grc_dim_norm': 0.9141641468478171,
#   'grc_dim2': 71.6537815213573,
#   'grc_dim2_norm': 0.9951914100188515,
#   'grc_by_mf_dim': 77.70395248206445,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.777073159052705,
#   'grc_pop_corr': 0.013955997558927683,
#   'binary_similarity': 0.3674450549450545,
#   'hamming_distance': 643.02734375,
#   'normalized_mse': 2.9902685256231405},
#  {'model': 'Random',
#   'noise': 95.0,
#   'grc_dim': 78.05875237934019,
#   'grc_dim_norm': 0.9183382632863551,
#   'grc_dim2': 71.92072248287157,
#   'grc_dim2_norm': 0.9988989233732162,
#   'grc_by_mf_dim': 78.05875237934019,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7696938669916074,
#   'grc_pop_corr': 0.013904198476845906,
#   'binary_similarity': 0.3666601909413855,
#   'hamming_distance': 676.126953125,
#   'normalized_mse': 3.1441915602911092},
#  {'model': 'Random',
#   'noise': 100.0,
#   'grc_dim': 79.56666093161148,
#   'grc_dim_norm': 0.9360783639013115,
#   'grc_dim2': 72.59059263493126,
#   'grc_dim2_norm': 1.0082026754851563,
#   'grc_by_mf_dim': 79.56666093161148,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7668373683904888,
#   'grc_pop_corr': 0.01377588973586628,
#   'binary_similarity': 0.36645466362478746,
#   'hamming_distance': 709.70703125,
#   'normalized_mse': 3.30034891764323},
#  {'model': 'Random',
#   'noise': 5.0,
#   'grc_dim': 53.63605624341865,
#   'grc_dim_norm': 0.6310124263931606,
#   'grc_dim2': 34.04808441549481,
#   'grc_dim2_norm': 0.47289006132631684,
#   'grc_by_mf_dim': 53.63605624341865,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.724493842864926,
#   'grc_pop_corr': 0.029370227934024794,
#   'binary_similarity': 0.32184709821428575,
#   'hamming_distance': 36.416015625,
#   'normalized_mse': 0.1693453107561384},
#  {'model': 'Random',
#   'noise': 10.0,
#   'grc_dim': 58.408736642662255,
#   'grc_dim_norm': 0.6871616075607324,
#   'grc_dim2': 41.5521025596963,
#   'grc_dim2_norm': 0.5771125355513376,
#   'grc_by_mf_dim': 58.408736642662255,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6509454753427468,
#   'grc_pop_corr': 0.024066170864960167,
#   'binary_similarity': 0.3921535326086976,
#   'hamming_distance': 64.55078125,
#   'normalized_mse': 0.3001803443545387},
#  {'model': 'Random',
#   'noise': 15.0,
#   'grc_dim': 66.05702811767442,
#   'grc_dim_norm': 0.7771415072667579,
#   'grc_dim2': 50.42304073091633,
#   'grc_dim2_norm': 0.7003200101516156,
#   'grc_by_mf_dim': 66.05702811767442,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6454383724323198,
#   'grc_pop_corr': 0.01983220340352979,
#   'binary_similarity': 0.37641225961538494,
#   'hamming_distance': 98.89453125,
#   'normalized_mse': 0.4598890032087054},
#  {'model': 'Random',
#   'noise': 20.0,
#   'grc_dim': 73.11259150345808,
#   'grc_dim_norm': 0.860148135334801,
#   'grc_dim2': 58.02615195936492,
#   'grc_dim2_norm': 0.8059187772134017,
#   'grc_by_mf_dim': 73.11259150345808,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7340436075208026,
#   'grc_pop_corr': 0.017233608747660695,
#   'binary_similarity': 0.3699041193181818,
#   'hamming_distance': 138.095703125,
#   'normalized_mse': 0.6421861194428944},
#  {'model': 'Random',
#   'noise': 30.0,
#   'grc_dim': 73.20081533912267,
#   'grc_dim_norm': 0.8611860628132079,
#   'grc_dim2': 64.42325667298783,
#   'grc_dim2_norm': 0.8947674537914977,
#   'grc_by_mf_dim': 73.20081533912267,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7781094663358648,
#   'grc_pop_corr': 0.015522344750064337,
#   'binary_similarity': 0.36705942622950777,
#   'hamming_distance': 215.28515625,
#   'normalized_mse': 1.0011400495256697},
#  {'model': 'Random',
#   'noise': 45.0,
#   'grc_dim': 77.05737963765911,
#   'grc_dim_norm': 0.9065574075018719,
#   'grc_dim2': 68.85086346962358,
#   'grc_dim2_norm': 0.9562619926336607,
#   'grc_by_mf_dim': 77.05737963765911,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7517002618689865,
#   'grc_pop_corr': 0.01452414609790902,
#   'binary_similarity': 0.36664032101167343,
#   'hamming_distance': 315.390625,
#   'normalized_mse': 1.4666602725074407},
#  {'model': 'Random',
#   'noise': 55.00000000000001,
#   'grc_dim': 80.67529243542481,
#   'grc_dim_norm': 0.949121087475586,
#   'grc_dim2': 71.21398553433818,
#   'grc_dim2_norm': 0.9890831324213636,
#   'grc_by_mf_dim': 80.67529243542481,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.754774203067475,
#   'grc_pop_corr': 0.014042185569263173,
#   'binary_similarity': 0.3751617237261145,
#   'hamming_distance': 384.029296875,
#   'normalized_mse': 1.785850524902344},
#  {'model': 'Random',
#   'noise': 60.0,
#   'grc_dim': 77.6073995497026,
#   'grc_dim_norm': 0.9130282299965012,
#   'grc_dim2': 70.42815276975934,
#   'grc_dim2_norm': 0.9781687884688797,
#   'grc_by_mf_dim': 77.6073995497026,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7654371442079246,
#   'grc_pop_corr': 0.014198867365855196,
#   'binary_similarity': 0.37125466086647724,
#   'hamming_distance': 423.783203125,
#   'normalized_mse': 1.9707180204845614},
#  {'model': 'Random',
#   'noise': 65.0,
#   'grc_dim': 72.78022598461908,
#   'grc_dim_norm': 0.8562379527602244,
#   'grc_dim2': 68.85701187078615,
#   'grc_dim2_norm': 0.9563473870942522,
#   'grc_by_mf_dim': 72.78022598461908,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7655069015103433,
#   'grc_pop_corr': 0.014522849203455899,
#   'binary_similarity': 0.380491246727749,
#   'hamming_distance': 455.087890625,
#   'normalized_mse': 2.116294134230841},
#  {'model': 'Random',
#   'noise': 75.0,
#   'grc_dim': 79.9670767216917,
#   'grc_dim_norm': 0.9407891379022553,
#   'grc_dim2': 72.02869079252332,
#   'grc_dim2_norm': 1.0003984832294905,
#   'grc_by_mf_dim': 79.9670767216917,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7599147952631555,
#   'grc_pop_corr': 0.013883356604113111,
#   'binary_similarity': 0.37661933458429586,
#   'hamming_distance': 524.763671875,
#   'normalized_mse': 2.440307253882999},
#  {'model': 'Random',
#   'noise': 80.0,
#   'grc_dim': 77.39735548325658,
#   'grc_dim_norm': 0.9105571233324303,
#   'grc_dim2': 71.25630243149057,
#   'grc_dim2_norm': 0.9896708671040356,
#   'grc_by_mf_dim': 77.39735548325658,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7651347134143374,
#   'grc_pop_corr': 0.014033846352909638,
#   'binary_similarity': 0.3765330981182794,
#   'hamming_distance': 563.353515625,
#   'normalized_mse': 2.6197615123930436},
#  {'model': 'Random',
#   'noise': 85.0,
#   'grc_dim': 81.55346902949904,
#   'grc_dim_norm': 0.9594525768176357,
#   'grc_dim2': 72.95167294041256,
#   'grc_dim2_norm': 1.0132176797279522,
#   'grc_by_mf_dim': 81.55346902949904,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.76830979068968,
#   'grc_pop_corr': 0.013707704836554015,
#   'binary_similarity': 0.3770312499999996,
#   'hamming_distance': 598.90234375,
#   'normalized_mse': 2.785074143182664},
#  {'model': 'Random',
#   'noise': 90.0,
#   'grc_dim': 82.10689768297904,
#   'grc_dim_norm': 0.9659635021526946,
#   'grc_dim2': 73.31384066827879,
#   'grc_dim2_norm': 1.0182477870594275,
#   'grc_by_mf_dim': 82.10689768297904,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.750267593584885,
#   'grc_pop_corr': 0.013639989269211441,
#   'binary_similarity': 0.369451436640472,
#   'hamming_distance': 628.314453125,
#   'normalized_mse': 2.921849205380395},
#  {'model': 'Random',
#   'noise': 95.0,
#   'grc_dim': 80.04666525225534,
#   'grc_dim_norm': 0.9417254735559452,
#   'grc_dim2': 72.67177647425117,
#   'grc_dim2_norm': 1.009330228809044,
#   'grc_by_mf_dim': 80.04666525225534,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7524073696320022,
#   'grc_pop_corr': 0.013760500272816598,
#   'binary_similarity': 0.3725730613425922,
#   'hamming_distance': 662.625,
#   'normalized_mse': 3.081403459821429},
#  {'model': 'Random',
#   'noise': 100.0,
#   'grc_dim': 80.05072842531548,
#   'grc_dim_norm': 0.9417732755919469,
#   'grc_dim2': 72.77514981699457,
#   'grc_dim2_norm': 1.01076596968048,
#   'grc_by_mf_dim': 80.05072842531548,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7544558119209666,
#   'grc_pop_corr': 0.01374095419266974,
#   'binary_similarity': 0.37476014254385975,
#   'hamming_distance': 697.470703125,
#   'normalized_mse': 3.2434463500976562},
#  {'model': 'Random',
#   'noise': 5.0,
#   'grc_dim': 49.29791546356821,
#   'grc_dim_norm': 0.579975476041979,
#   'grc_dim2': 31.577632378470167,
#   'grc_dim2_norm': 0.4385782274787523,
#   'grc_by_mf_dim': 49.29791546356821,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.633818355284363,
#   'grc_pop_corr': 0.03166798536427976,
#   'binary_similarity': 0.3388671875,
#   'hamming_distance': 33.822265625,
#   'normalized_mse': 0.15728360130673366},
#  {'model': 'Random',
#   'noise': 10.0,
#   'grc_dim': 64.49090813017976,
#   'grc_dim_norm': 0.7587165662374089,
#   'grc_dim2': 43.893712958144995,
#   'grc_dim2_norm': 0.6096349021964582,
#   'grc_by_mf_dim': 64.49090813017976,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7641573000083668,
#   'grc_pop_corr': 0.02278230599798093,
#   'binary_similarity': 0.3519787397540981,
#   'hamming_distance': 72.40625,
#   'normalized_mse': 0.33671061197916674},
#  {'model': 'Random',
#   'noise': 15.0,
#   'grc_dim': 63.64475799926968,
#   'grc_dim_norm': 0.7487618588149374,
#   'grc_dim2': 49.53231036444606,
#   'grc_dim2_norm': 0.6879487550617509,
#   'grc_by_mf_dim': 63.64475799926968,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7222995954163978,
#   'grc_pop_corr': 0.02018884224544052,
#   'binary_similarity': 0.4003182870370375,
#   'hamming_distance': 100.10546875,
# ...
#   'grc_dim2_norm': 0.9512967386852925,
#   'grc_by_mf_dim': 83.78415826988393,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7171402892367102,
#   'grc_pop_corr': 0.014599954277235889,
#   'binary_similarity': 0.35536922770700585,
#   'hamming_distance': 207.759765625,
#   'normalized_mse': 0.966144743419829},
#  {'model': 'Observed',
#   'noise': 45.0,
#   'grc_dim': 76.94807636338894,
#   'grc_dim_norm': 0.9052714866281051,
#   'grc_dim2': 68.68245370857694,
#   'grc_dim2_norm': 0.9539229681746798,
#   'grc_by_mf_dim': 76.94807636338894,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.690579538816059,
#   'grc_pop_corr': 0.014559759385461817,
#   'binary_similarity': 0.3710301598837214,
#   'hamming_distance': 304.919921875,
#   'normalized_mse': 1.4179683866954986},
#  {'model': 'Observed',
#   'noise': 55.00000000000001,
#   'grc_dim': 82.2755722920251,
#   'grc_dim_norm': 0.9679479093179424,
#   'grc_dim2': 71.72063330208985,
#   'grc_dim2_norm': 0.9961199069734702,
#   'grc_by_mf_dim': 82.2755722920251,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.726369847551405,
#   'grc_pop_corr': 0.013942988983211632,
#   'binary_similarity': 0.3655541036476867,
#   'hamming_distance': 386.484375,
#   'normalized_mse': 1.7972673688616072},
#  {'model': 'Observed',
#   'noise': 60.0,
#   'grc_dim': 80.90074124025615,
#   'grc_dim_norm': 0.9517734263559547,
#   'grc_dim2': 71.52046189829139,
#   'grc_dim2_norm': 0.9933397485873804,
#   'grc_by_mf_dim': 80.90074124025615,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7509275452003483,
#   'grc_pop_corr': 0.013982012608113341,
#   'binary_similarity': 0.3678522684487962,
#   'hamming_distance': 423.779296875,
#   'normalized_mse': 1.9706998552594868},
#  {'model': 'Observed',
#   'noise': 65.0,
#   'grc_dim': 80.30420623582496,
#   'grc_dim_norm': 0.9447553674802937,
#   'grc_dim2': 71.59134711108719,
#   'grc_dim2_norm': 0.9943242654317666,
#   'grc_by_mf_dim': 80.30420623582496,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7259460521201304,
#   'grc_pop_corr': 0.01396816850573178,
#   'binary_similarity': 0.37109952847633115,
#   'hamming_distance': 450.435546875,
#   'normalized_mse': 2.094659351167225},
#  {'model': 'Observed',
#   'noise': 75.0,
#   'grc_dim': 79.85476484688495,
#   'grc_dim_norm': 0.9394678217280582,
#   'grc_dim2': 71.84495617544631,
#   'grc_dim2_norm': 0.9978466135478654,
#   'grc_by_mf_dim': 79.85476484688495,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7144025946282884,
#   'grc_pop_corr': 0.013918861576837586,
#   'binary_similarity': 0.3702135416666669,
#   'hamming_distance': 518.10546875,
#   'normalized_mse': 2.4093446277436756},
#  {'model': 'Observed',
#   'noise': 80.0,
#   'grc_dim': 81.47789256949217,
#   'grc_dim_norm': 0.9585634419940255,
#   'grc_dim2': 72.63098658585525,
#   'grc_dim2_norm': 1.008763702581323,
#   'grc_by_mf_dim': 81.47789256949217,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7394466491793361,
#   'grc_pop_corr': 0.013768228231595412,
#   'binary_similarity': 0.3683134191176468,
#   'hamming_distance': 563.18359375,
#   'normalized_mse': 2.618971325102307},
#  {'model': 'Observed',
#   'noise': 85.0,
#   'grc_dim': 80.28361562069588,
#   'grc_dim_norm': 0.9445131249493633,
#   'grc_dim2': 72.33183405177338,
#   'grc_dim2_norm': 1.0046088062746303,
#   'grc_by_mf_dim': 80.28361562069588,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7321040506228382,
#   'grc_pop_corr': 0.013825171352412052,
#   'binary_similarity': 0.37346289938340804,
#   'hamming_distance': 591.0703125,
#   'normalized_mse': 2.748652866908482},
#  {'model': 'Observed',
#   'noise': 90.0,
#   'grc_dim': 79.61032837501166,
#   'grc_dim_norm': 0.9365920985295489,
#   'grc_dim2': 72.20996840252437,
#   'grc_dim2_norm': 1.0029162278128385,
#   'grc_by_mf_dim': 79.61032837501166,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7312335970797637,
#   'grc_pop_corr': 0.01384850349782235,
#   'binary_similarity': 0.3693889036016945,
#   'hamming_distance': 627.064453125,
#   'normalized_mse': 2.916036333356585},
#  {'model': 'Observed',
#   'noise': 95.0,
#   'grc_dim': 82.18070737827613,
#   'grc_dim_norm': 0.9668318515091309,
#   'grc_dim2': 73.29591697205856,
#   'grc_dim2_norm': 1.0179988468341468,
#   'grc_by_mf_dim': 82.18070737827613,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7245749532086754,
#   'grc_pop_corr': 0.013643324775938256,
#   'binary_similarity': 0.3675196913422133,
#   'hamming_distance': 661.634765625,
#   'normalized_mse': 3.0767985752650673},
#  {'model': 'Observed',
#   'noise': 100.0,
#   'grc_dim': 80.19533814904231,
#   'grc_dim_norm': 0.9434745664593214,
#   'grc_dim2': 72.66050684399424,
#   'grc_dim2_norm': 1.0091737061665866,
#   'grc_by_mf_dim': 80.19533814904231,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7280701310735773,
#   'grc_pop_corr': 0.01376263452369043,
#   'binary_similarity': 0.36895282451923084,
#   'hamming_distance': 695.783203125,
#   'normalized_mse': 3.2355989728655135},
#  {'model': 'Observed',
#   'noise': 5.0,
#   'grc_dim': 36.89632604432178,
#   'grc_dim_norm': 0.4340744240508445,
#   'grc_dim2': 26.229907104034037,
#   'grc_dim2_norm': 0.36430426533380605,
#   'grc_by_mf_dim': 36.89632604432178,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.688324898130808,
#   'grc_pop_corr': 0.03812442019080596,
#   'binary_similarity': 0.39235276442307754,
#   'hamming_distance': 32.97265625,
#   'normalized_mse': 0.1533326648530506},
#  {'model': 'Observed',
#   'noise': 10.0,
#   'grc_dim': 73.63273981804998,
#   'grc_dim_norm': 0.8662675272711763,
#   'grc_dim2': 47.93211131715019,
#   'grc_dim2_norm': 0.6657237682937526,
#   'grc_by_mf_dim': 73.63273981804998,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6519542290977614,
#   'grc_pop_corr': 0.020862840641075586,
#   'binary_similarity': 0.345126065340909,
#   'hamming_distance': 68.71484375,
#   'normalized_mse': 0.31954447428385424},
#  {'model': 'Observed',
#   'noise': 15.0,
#   'grc_dim': 70.18038796897596,
#   'grc_dim_norm': 0.8256516231644231,
#   'grc_dim2': 52.079081978029116,
#   'grc_dim2_norm': 0.7233205830281821,
#   'grc_by_mf_dim': 70.18038796897596,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6890230566597997,
#   'grc_pop_corr': 0.019201567347555692,
#   'binary_similarity': 0.3585416666666669,
#   'hamming_distance': 101.23828125,
#   'normalized_mse': 0.47078813825334825},
#  {'model': 'Observed',
#   'noise': 20.0,
#   'grc_dim': 64.23086122513769,
#   'grc_dim_norm': 0.7556571908839728,
#   'grc_dim2': 54.545056065690005,
#   'grc_dim2_norm': 0.7575702231345834,
#   'grc_by_mf_dim': 64.23086122513769,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6690842856810602,
#   'grc_pop_corr': 0.0183334672677882,
#   'binary_similarity': 0.36171874999999915,
#   'hamming_distance': 135.982421875,
#   'normalized_mse': 0.6323587326776414},
#  {'model': 'Observed',
#   'noise': 30.0,
#   'grc_dim': 75.66505957891776,
#   'grc_dim_norm': 0.8901771715166795,
#   'grc_dim2': 65.29564067560662,
#   'grc_dim2_norm': 0.9068838982723142,
#   'grc_by_mf_dim': 75.66505957891776,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6529143335738938,
#   'grc_pop_corr': 0.015314958083772715,
#   'binary_similarity': 0.38123553240740804,
#   'hamming_distance': 195.009765625,
#   'normalized_mse': 0.9068534487769718},
#  {'model': 'Observed',
#   'noise': 45.0,
#   'grc_dim': 77.4011070731753,
#   'grc_dim_norm': 0.9106012596844153,
#   'grc_dim2': 68.87477112273382,
#   'grc_dim2_norm': 0.956594043371303,
#   'grc_by_mf_dim': 77.4011070731753,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7118353860401816,
#   'grc_pop_corr': 0.014519104509516479,
#   'binary_similarity': 0.35891396190987107,
#   'hamming_distance': 308.708984375,
#   'normalized_mse': 1.4355886550176713},
#  {'model': 'Observed',
#   'noise': 55.00000000000001,
#   'grc_dim': 75.16644807979102,
#   'grc_dim_norm': 0.8843111538798945,
#   'grc_dim2': 68.9452696764658,
#   'grc_dim2_norm': 0.9575731899509139,
#   'grc_by_mf_dim': 75.16644807979102,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7120066982612663,
#   'grc_pop_corr': 0.014504258300716258,
#   'binary_similarity': 0.37645069067028974,
#   'hamming_distance': 376.498046875,
#   'normalized_mse': 1.7508279709588916},
#  {'model': 'Observed',
#   'noise': 60.0,
#   'grc_dim': 78.43535796036738,
#   'grc_dim_norm': 0.9227689171807928,
#   'grc_dim2': 70.57163181331447,
#   'grc_dim2_norm': 0.9801615529627009,
#   'grc_by_mf_dim': 78.43535796036738,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.708150363141514,
#   'grc_pop_corr': 0.01416999967699959,
#   'binary_similarity': 0.36859737168874185,
#   'hamming_distance': 409.806640625,
#   'normalized_mse': 1.905722845168341},
#  {'model': 'Observed',
#   'noise': 65.0,
#   'grc_dim': 74.14098740285215,
#   'grc_dim_norm': 0.8722469106217899,
#   'grc_dim2': 69.19751641949213,
#   'grc_dim2_norm': 0.9610766169373908,
#   'grc_by_mf_dim': 74.14098740285215,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.686686395969648,
#   'grc_pop_corr': 0.014451385710691659,
#   'binary_similarity': 0.3857738940746751,
#   'hamming_distance': 433.9453125,
#   'normalized_mse': 2.017974853515625},
#  {'model': 'Observed',
#   'noise': 75.0,
#   'grc_dim': 73.9538530864738,
#   'grc_dim_norm': 0.8700453304291035,
#   'grc_dim2': 69.54619840725834,
#   'grc_dim2_norm': 0.9659194223230325,
#   'grc_by_mf_dim': 73.9538530864738,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7158163005424023,
#   'grc_pop_corr': 0.014378931169523606,
#   'binary_similarity': 0.3709509627937338,
#   'hamming_distance': 514.341796875,
#   'normalized_mse': 2.3918424333844865},
#  {'model': 'Observed',
#   'noise': 80.0,
#   'grc_dim': 79.51067847964484,
#   'grc_dim_norm': 0.935419746819351,
#   'grc_dim2': 71.86160007425232,
#   'grc_dim2_norm': 0.99807777880906,
#   'grc_by_mf_dim': 79.51067847964484,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7266316354733036,
#   'grc_pop_corr': 0.013915637822797316,
#   'binary_similarity': 0.37034835446859854,
#   'hamming_distance': 556.220703125,
#   'normalized_mse': 2.5865918114071804},
#  {'model': 'Observed',
#   'noise': 85.0,
#   'grc_dim': 75.35331920583256,
#   'grc_dim_norm': 0.8865096377156773,
#   'grc_dim2': 70.43969084171624,
#   'grc_dim2_norm': 0.9783290394682811,
#   'grc_by_mf_dim': 75.35331920583256,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7107199480598299,
#   'grc_pop_corr': 0.01419654158118158,
#   'binary_similarity': 0.3721272217365971,
#   'hamming_distance': 580.408203125,
#   'normalized_mse': 2.699070885067895},
#  {'model': 'Observed',
#   'noise': 90.0,
#   'grc_dim': 80.14088591076218,
#   'grc_dim_norm': 0.9428339518913198,
#   'grc_dim2': 72.39598945921978,
#   'grc_dim2_norm': 1.0054998536002746,
#   'grc_by_mf_dim': 80.14088591076218,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7126843201828468,
#   'grc_pop_corr': 0.01381291985191105,
#   'binary_similarity': 0.36812123081140374,
#   'hamming_distance': 617.423828125,
#   'normalized_mse': 2.871204557872954},
#  {'model': 'Observed',
#   'noise': 95.0,
#   'grc_dim': 78.26347404352634,
#   'grc_dim_norm': 0.9207467534532511,
#   'grc_dim2': 71.79492227258925,
#   'grc_dim2_norm': 0.9971516982304062,
#   'grc_by_mf_dim': 78.26347404352634,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7168907946617218,
#   'grc_pop_corr': 0.013928561635643589,
#   'binary_similarity': 0.37066285438144325,
#   'hamming_distance': 653.06640625,
#   'normalized_mse': 3.0369531540643604},
#  {'model': 'Observed',
#   'noise': 100.0,
#   'grc_dim': 78.98831596036985,
#   'grc_dim_norm': 0.9292743054161159,
#   'grc_dim2': 72.1783566649127,
#   'grc_dim2_norm': 1.0024771759015652,
#   'grc_by_mf_dim': 78.98831596036985,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7165655450015747,
#   'grc_pop_corr': 0.013854568685215292,
#   'binary_similarity': 0.3724839154411761,
#   'hamming_distance': 686.00390625,
#   'normalized_mse': 3.1901223318917413},
#  {'model': 'Observed',
#   'noise': 5.0,
#   'grc_dim': 35.06051277872343,
#   'grc_dim_norm': 0.412476620926158,
#   'grc_dim2': 25.487720304632905,
#   'grc_dim2_norm': 0.35399611534212366,
#   'grc_by_mf_dim': 35.06051277872343,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6808716951681415,
#   'grc_pop_corr': 0.03923457994861274,
#   'binary_similarity': 0.4003906250000002,
#   'hamming_distance': 33.369140625,
#   'normalized_mse': 0.15517643519810267},
#  {'model': 'Observed',
#   'noise': 10.0,
#   'grc_dim': 47.173948910843926,
#   'grc_dim_norm': 0.5549876342452227,
#   'grc_dim2': 37.41003068702632,
#   'grc_dim2_norm': 0.5195837595420323,
#   'grc_by_mf_dim': 47.173948910843926,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6977133010948615,
#   'grc_pop_corr': 0.02673079870920279,
#   'binary_similarity': 0.3911611519607848,
#   'hamming_distance': 66.650390625,
#   'normalized_mse': 0.30994415283203125},
#  {'model': 'Observed',
#   'noise': 15.0,
#   'grc_dim': 57.82056969802988,
#   'grc_dim_norm': 0.6802419964474103,
#   'grc_dim2': 47.30713308282389,
#   'grc_dim2_norm': 0.6570435150392206,
#   'grc_by_mf_dim': 57.82056969802988,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7449825507102568,
#   'grc_pop_corr': 0.0211384612601493,
#   'binary_similarity': 0.3722132240853663,
#   'hamming_distance': 106.119140625,
#   'normalized_mse': 0.493485586983817},
#  {'model': 'Observed',
#   'noise': 20.0,
#   'grc_dim': 63.51304153373222,
#   'grc_dim_norm': 0.7472122533380261,
#   'grc_dim2': 54.316777610276596,
#   'grc_dim2_norm': 0.7543996890316194,
#   'grc_by_mf_dim': 63.51304153373222,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.6890471338831863,
#   'grc_pop_corr': 0.018410517780988588,
#   'binary_similarity': 0.3568178157216497,
#   'hamming_distance': 136.599609375,
#   'normalized_mse': 0.6352288382393974},
#  {'model': 'Observed',
#   'noise': 30.0,
#   'grc_dim': 80.57067182400431,
#   'grc_dim_norm': 0.9478902567529919,
#   'grc_dim2': 67.12067213825526,
#   'grc_dim2_norm': 0.9322315574757675,
#   'grc_by_mf_dim': 80.57067182400431,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7463552715288917,
#   'grc_pop_corr': 0.014898539721714921,
#   'binary_similarity': 0.3618047805059529,
#   'hamming_distance': 211.587890625,
#   'normalized_mse': 0.9839466639927456},
#  {'model': 'Observed',
#   'noise': 45.0,
#   'grc_dim': 72.21806371664478,
#   'grc_dim_norm': 0.8496242790193503,
#   'grc_dim2': 66.85333043739861,
#   'grc_dim2_norm': 0.9285184782972029,
#   'grc_by_mf_dim': 72.21806371664478,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.789066789070378,
#   'grc_pop_corr': 0.01495811791959114,
#   'binary_similarity': 0.3659998855311361,
#   'hamming_distance': 329.490234375,
#   'normalized_mse': 1.5322276524135046},
#  {'model': 'Observed',
#   'noise': 55.00000000000001,
#   'grc_dim': 77.87672587590733,
#   'grc_dim_norm': 0.9161967750106744,
#   'grc_dim2': 69.9780105255421,
#   'grc_dim2_norm': 0.9719168128547514,
#   'grc_by_mf_dim': 77.87672587590733,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7491108037884144,
#   'grc_pop_corr': 0.014290203343734645,
#   'binary_similarity': 0.35817751024590144,
#   'hamming_distance': 391.7578125,
#   'normalized_mse': 1.8217904227120536},
#  {'model': 'Observed',
#   'noise': 60.0,
#   'grc_dim': 77.88851460302003,
#   'grc_dim_norm': 0.9163354659178827,
#   'grc_dim2': 70.33686708466489,
#   'grc_dim2_norm': 0.9769009317314568,
#   'grc_by_mf_dim': 77.88851460302003,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.760026117290547,
#   'grc_pop_corr': 0.014217295160392832,
#   'binary_similarity': 0.3549689797794125,
#   'hamming_distance': 432.59375,
#   'normalized_mse': 2.0116896856398814},
#  {'model': 'Observed',
#   'noise': 65.0,
#   'grc_dim': 81.07154687080373,
#   'grc_dim_norm': 0.9537829043623968,
#   'grc_dim2': 71.88019739066434,
#   'grc_dim2_norm': 0.998336074870338,
#   'grc_by_mf_dim': 81.07154687080373,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7751866226143946,
#   'grc_pop_corr': 0.013912037477652756,
#   'binary_similarity': 0.34580993652343756,
#   'hamming_distance': 479.3359375,
#   'normalized_mse': 2.2290547688802085},
#  {'model': 'Observed',
#   'noise': 75.0,
#   'grc_dim': 80.09852652171155,
#   'grc_dim_norm': 0.9423356061377829,
#   'grc_dim2': 71.90258659915855,
#   'grc_dim2_norm': 0.9986470360994244,
#   'grc_by_mf_dim': 80.09852652171155,
#   'num_grcs': 1847,
#   'num_mfs': 643,
#   'voi': 1.7699271021032723,
#   'grc_pop_corr': 0.013907705512386985,
#   'binary_similarity': 0.35767604880137,
#   'hamming_distance': 542.447265625,
#   'normalized_mse': 2.522541227794829},
#  ...]

# %%
name_map = {
        'observed_1.0': "Observed",
        'observed_0.5': "50% subsampled",
}

palette = {
#     name_map['scaleup4']: sns.color_palette()[0],
#     name_map['global_random']: sns.color_palette()[1],
#     name_map['random']: sns.color_palette()[1],
#     name_map['local_random']: sns.color_palette()[2],
}


mpd = MyPlotData()
# ress_ref = db['local_random'][0][0]
# resss_ref2 = db['local_random'][0]
for model_name in [
        'observed_1.0',
        'observed_0.5',
        ]:
    resss = db[model_name]
    ress_tries = resss[0]  # get the first element in tuple
#     ress = ress[0]  # get the first try
    for n_try, ress in enumerate(ress_tries):
#         print(resss_ref2[0])
#         print(resss_ref2.keys())
#         if n_try >= len(resss_ref2):
#             print(n_try)
#             continue
#         ress_ref2 = resss_ref2[n_try]
#         noise = .3
#         for noise in ress:
    #         print(noise)
        for noise in ress:
            res = ress[noise]
            grc_dim2 = 1/res['grc_pop_corr']
            mpd.add_data_point(
                model=name_map[model_name],
                noise=noise*100,
                grc_dim=res['grc_dim'],
                grc_dim_norm=res['grc_dim']/79,
                grc_dim2=grc_dim2,
                grc_dim2_norm=grc_dim2/72,
                grc_by_mf_dim=res['grc_dim']/res['mf_dim'],
                num_grcs=res['num_grcs'],
                num_mfs=res['num_mfs'],
                voi=res['voi'],
                grc_pop_corr=res['grc_pop_corr'],
                binary_similarity=res['binary_similarity'],
                hamming_distance=res['hamming_distance'],
                normalized_mse=res['normalized_mse'],
                )

def custom_legend_fn(plt):
#     plt.legend(bbox_to_anchor=(1.025, .8), loc='upper left', borderaxespad=0.)
    plt.legend(loc='lower right', frameon=False, fontsize=13)

importlib.reload(my_plot); my_plot.my_relplot(
    mpd,
    x='noise',
    y='grc_dim2_norm',
    hue='model',
#     context='paper',
    context='talk',
#     palette=palette,
    linewidth=2,
#     log_scale_y=True,
    width=6,
    height=4,
    ylim=[.5, None],
    y_axis_label='Norm. Dim. ($x$)',
    x_axis_label='GrC (%)',
#     title='noise',
#     legend=None,
    save_filename=f'{script_n}_fig_plus.svg',
    show=True,
    custom_legend_fn=custom_legend_fn,
    )
# Out:
# Height: 4, Aspect: 1.5

# %%
name_map = {
        'observed_1.0': "Observed",
        'observed_0.5': "50% subsampled",
}

palette = {
#     name_map['scaleup4']: sns.color_palette()[0],
#     name_map['global_random']: sns.color_palette()[1],
#     name_map['random']: sns.color_palette()[1],
#     name_map['local_random']: sns.color_palette()[2],
}


mpd = MyPlotData()
# ress_ref = db['local_random'][0][0]
# resss_ref2 = db['local_random'][0]
for model_name in [
        'observed_1.0',
#         'observed_0.5',
        ]:
    resss = db[model_name]
    ress_tries = resss[0]  # get the first element in tuple
#     ress = ress[0]  # get the first try
    for n_try, ress in enumerate(ress_tries):
#         print(resss_ref2[0])
#         print(resss_ref2.keys())
#         if n_try >= len(resss_ref2):
#             print(n_try)
#             continue
#         ress_ref2 = resss_ref2[n_try]
#         noise = .3
#         for noise in ress:
    #         print(noise)
        for noise in ress:
            res = ress[noise]
            grc_dim2 = 1/res['grc_pop_corr']
            mpd.add_data_point(
                model=name_map[model_name],
                noise=noise*100,
                grc_dim=res['grc_dim'],
                grc_dim_norm=res['grc_dim']/79,
                grc_dim2=grc_dim2,
                grc_dim2_norm=grc_dim2/72,
                grc_by_mf_dim=res['grc_dim']/res['mf_dim'],
                num_grcs=res['num_grcs'],
                num_mfs=res['num_mfs'],
                voi=res['voi'],
                grc_pop_corr=res['grc_pop_corr'],
                binary_similarity=res['binary_similarity'],
                hamming_distance=res['hamming_distance'],
                normalized_mse=res['normalized_mse'],
                )

def custom_legend_fn(plt):
#     plt.legend(bbox_to_anchor=(1.025, .8), loc='upper left', borderaxespad=0.)
    plt.legend(loc='lower right', frameon=False, fontsize=13)

importlib.reload(my_plot); my_plot.my_relplot(
    mpd,
    x='noise',
    y='grc_dim2_norm',
    hue='model',
    context='paper',
#     palette=palette,
    linewidth=2,
#     log_scale_y=True,
    width=4,
    height=3,
#     ylim=[0, None],
    y_axis_label='Norm. Dim. ($x$)',
    x_axis_label='GrC (%)',
#     title='noise',
#     legend=None,
    save_filename=f'{script_n}_observed.svg',
    show=True,
    custom_legend_fn=custom_legend_fn,
    )
# Out:
# Height: 3, Aspect: 1.3333333333333333

# %%
name_map = {
        'scaleup4': "Observed",
        'global_random': "Global Random",
        'random': "Global Random",
        'local_random': "Local Random",
}

palette = {
    name_map['scaleup4']: sns.color_palette()[0],
    name_map['global_random']: sns.color_palette()[1],
    name_map['random']: sns.color_palette()[1],
    name_map['local_random']: sns.color_palette()[2],
}


mpd = MyPlotData()
# ress_ref = db['local_random'][0][0]
# resss_ref2 = db['local_random'][0]
for model_name in [
#         'observed_1.0',
#         'observed_0.5',
        'local_random_1.0',
        'local_random_0.5',
        ]:
    resss = db[model_name]
    ress_tries = resss[0]  # get the first element in tuple
#     ress = ress[0]  # get the first try
    for n_try, ress in enumerate(ress_tries):
#         print(resss_ref2[0])
#         print(resss_ref2.keys())
#         if n_try >= len(resss_ref2):
#             print(n_try)
#             continue
#         ress_ref2 = resss_ref2[n_try]
#         noise = .3
#         for noise in ress:
    #         print(noise)
        for noise in ress:
            res = ress[noise]
            grc_dim2 = 1/res['grc_pop_corr']
            mpd.add_data_point(
                model=model_name,
                noise=noise*100,
                grc_dim=res['grc_dim'],
                grc_dim_norm=res['grc_dim']/79,
                grc_dim2=grc_dim2,
                grc_dim2_norm=grc_dim2/72,
                grc_by_mf_dim=res['grc_dim']/res['mf_dim'],
                num_grcs=res['num_grcs'],
                num_mfs=res['num_mfs'],
                voi=res['voi'],
                grc_pop_corr=res['grc_pop_corr'],
                binary_similarity=res['binary_similarity'],
                hamming_distance=res['hamming_distance'],
                normalized_mse=res['normalized_mse'],
                )

importlib.reload(my_plot); my_plot.my_relplot(
    mpd,
    x='noise',
    y='grc_dim2_norm',
    hue='model',
    context='paper',
#     palette=palette,
    linewidth=1,
#     log_scale_y=True,
    width=5.5,
#     ylim=[0, None],
    y_axis_label='Norm. Dim. ($x$)',
    x_axis_label='GrC (%)',
#     title='noise',
#     legend=None,
    save_filename=f'{script_n}_local.svg',
    show=True,
    )
# Out:
# Height: 4.135338345864661, Aspect: 1.33

# %%
name_map = {
        'scaleup4': "Observed",
        'global_random': "Global Random",
        'random': "Global Random",
        'local_random': "Local Random",
}

palette = {
    name_map['scaleup4']: sns.color_palette()[0],
    name_map['global_random']: sns.color_palette()[1],
    name_map['random']: sns.color_palette()[1],
    name_map['local_random']: sns.color_palette()[2],
}


mpd = MyPlotData()
# ress_ref = db['local_random'][0][0]
# resss_ref2 = db['local_random'][0]
for model_name in [
#         'observed_1.0',
#         'observed_0.5',
#         'local_random_1.0',
#         'local_random_0.5',
        'global_random_1.0',
        'global_random_0.5',
        ]:
    resss = db[model_name]
    ress_tries = resss[0]  # get the first element in tuple
#     ress = ress[0]  # get the first try
    for n_try, ress in enumerate(ress_tries):
#         print(resss_ref2[0])
#         print(resss_ref2.keys())
#         if n_try >= len(resss_ref2):
#             print(n_try)
#             continue
#         ress_ref2 = resss_ref2[n_try]
#         noise = .3
#         for noise in ress:
    #         print(noise)
        for noise in ress:
            res = ress[noise]
            grc_dim2 = 1/res['grc_pop_corr']
            mpd.add_data_point(
                model=model_name,
                noise=noise*100,
                grc_dim=res['grc_dim'],
                grc_dim_norm=res['grc_dim']/79,
                grc_dim2=grc_dim2,
                grc_dim2_norm=grc_dim2/72,
                grc_by_mf_dim=res['grc_dim']/res['mf_dim'],
                num_grcs=res['num_grcs'],
                num_mfs=res['num_mfs'],
                voi=res['voi'],
                grc_pop_corr=res['grc_pop_corr'],
                binary_similarity=res['binary_similarity'],
                hamming_distance=res['hamming_distance'],
                normalized_mse=res['normalized_mse'],
                )

importlib.reload(my_plot); my_plot.my_relplot(
    mpd,
    x='noise',
    y='grc_dim2_norm',
    hue='model',
    context='paper',
#     palette=palette,
    linewidth=1,
#     log_scale_y=True,
    width=5.5,
#     ylim=[0, None],
    y_axis_label='Norm. Dim. ($x$)',
    x_axis_label='GrC (%)',
#     title='noise',
#     legend=None,
    save_filename=f'{script_n}_global.svg',
    show=True,
    )
# Out:
# Height: 4.135338345864661, Aspect: 1.33
