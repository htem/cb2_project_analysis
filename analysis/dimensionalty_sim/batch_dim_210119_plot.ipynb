# %%
import random
import copy
import logging
import sys

from run_tests_201204 import *

import os
import sys
import importlib
from collections import defaultdict
sys.path.insert(0, '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc')
from tools_pattern import get_eucledean_dist
import compress_pickle
import my_plot
from my_plot import MyPlotData, my_box_plot

# script_n = os.path.basename(__file__).split('.')[0]
script_n = 'batch_dim_210119_plot'


base_path = '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc/dimensionality_sim'

db = {}


# name = 'batch_dim_210119_naive_random2_10'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['naive_random2'] = dbb

# name = 'batch_dim_210119_naive_random3_100'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['naive_random3'] = dbb

# name = 'batch_dim_210119_data_1'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['data'] = dbb

# name = 'batch_dim_210119_global_random_100'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['global_random'] = dbb

# name = 'batch_dim_210119_expanded_random_30_100'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['expanded_random_30'] = dbb


for model_name in [
        'naive_random2',
        'naive_random3',
        'naive_random_15_1',
        'naive_random_15_2',
        'naive_random_15_3',
        'naive_random_15_4',
        'naive_random_17_2',
        'naive_random_17_3',
        'expanded_random_30',
#         'expanded_random_50',
        'data',
        'global_random',
#         'classic_random',
        ]:
    name = f'batch_dim_210119_{model_name}_len_8192_10'
    dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
    db[model_name] = dbb


# db_old = compress_pickle.load(
#     '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc/dimensionality_sim/data/'
#     'batch_dim_201205_db.gz')
# db_old = db_old[0]
# db['data'] = {0: [db_old['data'][0]]}

mpd = MyPlotData()

def get_plot_name(model_name):
    if 'data' == model_name:
        return 'Observation'
    if 'classic_random' == model_name:
        return 'Classic Random'
    if 'naive_random_15_2' == model_name:
        return 'Local\nRandom'
    if 'data' == model_name:
        return 'Data'
    if 'expanded_random_30' == model_name:
        return 'LocalEx\nRandom'
    if 'global_random' == model_name:
        return 'Global\nRandom'
    return model_name


for model_name in [
#         'naive_random2',
        'data',
        'naive_random_15_2',
#         'naive_random3',
        'expanded_random_30',
#         'expanded_random_50',
        'global_random',
#         'classic_random',
#         'naive_random_15_1',
#         'naive_random_15_3',
#         'naive_random_15_4',
#         'naive_random_17_2',
#         'naive_random_17_3',
        ]:
    ress = db[model_name][0]
    for res in ress:
        mpd.add_data_point(
            model=get_plot_name(model_name),
            mf_dim=res['mf_dim'],
            grc_dim=res['grc_dim'],
            grc_dim_norm=res['grc_dim']/649.054596599147,
            pct_grc=res['pct_grc']/100,
            pct_mfs=res['pct_mfs']/100,
            pct_mf_dim=res['pct_mf_dim']/100,
            num_grcs=res['num_grcs'],
            num_mfs=res['num_mfs'],
            )

importlib.reload(my_plot); my_plot.my_catplot(
    mpd,
    x='model',
    y='pct_grc',
    context='paper',
    kind='bar',
    errwidth=4,
    height=4,
    aspect=1.5,
    font_scale=1.25,
    y_axis_label='Normalized Dimensionality',
#     y_axis_label='Dim / # of GrCs',
#     x_axis_label='Normalized Dimensionality',
    save_filename=f'{script_n}_norm_dim_grc.svg',
    show=True,
    )

# importlib.reload(my_plot); my_plot.my_catplot(
#     mpd,
#     x='model',
#     y='pct_mfs',
#     context='paper',
#     height=4,
#     aspect=1.33,
#     y_axis_label='Dim / MF dim',
#     x_axis_label='Normalized Dimensionality',
#     save_filename=f'{script_n}_pct_mfs.svg',
#     show=True,
#     )

# importlib.reload(my_plot); my_plot.my_catplot(
#     mpd,
#     x='model',
#     y='pct_mf_dim',
#     context='paper',
#     height=4,
#     aspect=2.33,
#     y_axis_label='Dim / MF dim',
#     x_axis_label='Normalized Dimensionality',
#     save_filename=f'{script_n}_pct_mf_dim.svg',
#     show=True,
#     )
# Out:
# Height: 4, Aspect: 1.5

# %%
mpd.data
# Out:
# [{'model': 'Observation',
#   'mf_dim': 459.62162516179563,
#   'grc_dim': 649.054596599147,
#   'grc_dim_norm': 1.082708654906344,
#   'pct_grc': 0.535,
#   'pct_mfs': 1.3319999999999999,
#   'pct_mf_dim': 1.412,
#   'num_grcs': 1211,
#   'num_mfs': 487},
#  {'model': 'Local\nRandom',
#   'mf_dim': 441.9350522747359,
#   'grc_dim': 652.6199414685711,
#   'grc_dim_norm': 1.0886561202938136,
#   'pct_grc': 0.5379999999999999,
#   'pct_mfs': 1.3969999999999998,
#   'pct_mf_dim': 1.476,
#   'num_grcs': 1211,
#   'num_mfs': 467},
#  {'model': 'Local\nRandom',
#   'mf_dim': 437.20659106496925,
#   'grc_dim': 655.1156821590957,
#   'grc_dim_norm': 1.0928193448672032,
#   'pct_grc': 0.54,
#   'pct_mfs': 1.4169999999999998,
#   'pct_mf_dim': 1.4980000000000002,
#   'num_grcs': 1211,
#   'num_mfs': 462},
#  {'model': 'Local\nRandom',
#   'mf_dim': 440.82633972161443,
#   'grc_dim': 651.4893462951601,
#   'grc_dim_norm': 1.0867701384582926,
#   'pct_grc': 0.537,
#   'pct_mfs': 1.3980000000000001,
#   'pct_mf_dim': 1.4769999999999999,
#   'num_grcs': 1211,
#   'num_mfs': 466},
#  {'model': 'Local\nRandom',
#   'mf_dim': 440.82633972161443,
#   'grc_dim': 656.8196822435546,
#   'grc_dim_norm': 1.0956618417065624,
#   'pct_grc': 0.542,
#   'pct_mfs': 1.409,
#   'pct_mf_dim': 1.489,
#   'num_grcs': 1211,
#   'num_mfs': 466},
#  {'model': 'Local\nRandom',
#   'mf_dim': 444.58673428944087,
#   'grc_dim': 652.093119598838,
#   'grc_dim_norm': 1.0877773119455751,
#   'pct_grc': 0.5379999999999999,
#   'pct_mfs': 1.3869999999999998,
#   'pct_mf_dim': 1.466,
#   'num_grcs': 1211,
#   'num_mfs': 470},
#  {'model': 'Local\nRandom',
#   'mf_dim': 440.82633972161443,
#   'grc_dim': 655.2374683731445,
#   'grc_dim_norm': 1.093022500331612,
#   'pct_grc': 0.541,
#   'pct_mfs': 1.406,
#   'pct_mf_dim': 1.486,
#   'num_grcs': 1211,
#   'num_mfs': 466},
#  {'model': 'Local\nRandom',
#   'mf_dim': 440.26303373347037,
#   'grc_dim': 650.7948854080885,
#   'grc_dim_norm': 1.085611686123364,
#   'pct_grc': 0.537,
#   'pct_mfs': 1.399,
#   'pct_mf_dim': 1.4780000000000002,
#   'num_grcs': 1211,
#   'num_mfs': 465},
#  {'model': 'Local\nRandom',
#   'mf_dim': 443.52341211752815,
#   'grc_dim': 652.3323730153312,
#   'grc_dim_norm': 1.0881764181935092,
#   'pct_grc': 0.5379999999999999,
#   'pct_mfs': 1.39,
#   'pct_mf_dim': 1.47,
#   'num_grcs': 1211,
#   'num_mfs': 469},
#  {'model': 'Local\nRandom',
#   'mf_dim': 437.20659106496925,
#   'grc_dim': 649.4468368002684,
#   'grc_dim_norm': 1.0833629632846864,
#   'pct_grc': 0.536,
#   'pct_mfs': 1.405,
#   'pct_mf_dim': 1.485,
#   'num_grcs': 1211,
#   'num_mfs': 462},
#  {'model': 'Local\nRandom',
#   'mf_dim': 442.67807877129854,
#   'grc_dim': 648.7602339968487,
#   'grc_dim_norm': 1.0822176192694977,
#   'pct_grc': 0.535,
#   'pct_mfs': 1.386,
#   'pct_mf_dim': 1.465,
#   'num_grcs': 1211,
#   'num_mfs': 468},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 463.43552857462043,
#   'grc_dim': 714.2383941002465,
#   'grc_dim_norm': 1.1914438246191776,
#   'pct_grc': 0.589,
#   'pct_mfs': 1.454,
#   'pct_mf_dim': 1.541,
#   'num_grcs': 1211,
#   'num_mfs': 491},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 455.3765026847403,
#   'grc_dim': 705.6371040096435,
#   'grc_dim_norm': 1.1770957385363554,
#   'pct_grc': 0.5820000000000001,
#   'pct_mfs': 1.463,
#   'pct_mf_dim': 1.5490000000000002,
#   'num_grcs': 1211,
#   'num_mfs': 482},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 469.4559480775253,
#   'grc_dim': 704.0644378851268,
#   'grc_dim_norm': 1.1744723240605717,
#   'pct_grc': 0.581,
#   'pct_mfs': 1.413,
#   'pct_mf_dim': 1.499,
#   'num_grcs': 1211,
#   'num_mfs': 498},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 461.39489011517094,
#   'grc_dim': 710.838033504598,
#   'grc_dim_norm': 1.1857715747560666,
#   'pct_grc': 0.586,
#   'pct_mfs': 1.453,
#   'pct_mf_dim': 1.54,
#   'num_grcs': 1211,
#   'num_mfs': 489},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 464.18184405506594,
#   'grc_dim': 708.3562694733572,
#   'grc_dim_norm': 1.181631665093399,
#   'pct_grc': 0.584,
#   'pct_mfs': 1.439,
#   'pct_mf_dim': 1.526,
#   'num_grcs': 1211,
#   'num_mfs': 492},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 462.41688395655405,
#   'grc_dim': 710.0117331410146,
#   'grc_dim_norm': 1.1843931967892642,
#   'pct_grc': 0.586,
#   'pct_mfs': 1.449,
#   'pct_mf_dim': 1.535,
#   'num_grcs': 1211,
#   'num_mfs': 490},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 464.18184405506594,
#   'grc_dim': 712.978393134201,
#   'grc_dim_norm': 1.1893419768574087,
#   'pct_grc': 0.588,
#   'pct_mfs': 1.449,
#   'pct_mf_dim': 1.535,
#   'num_grcs': 1211,
#   'num_mfs': 492},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 467.5435199237564,
#   'grc_dim': 709.973583690917,
#   'grc_dim_norm': 1.184329558475913,
#   'pct_grc': 0.586,
#   'pct_mfs': 1.431,
#   'pct_mf_dim': 1.518,
#   'num_grcs': 1211,
#   'num_mfs': 496},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 454.26697170041916,
#   'grc_dim': 706.4835545501171,
#   'grc_dim_norm': 1.1785077296553197,
#   'pct_grc': 0.583,
#   'pct_mfs': 1.4680000000000002,
#   'pct_mf_dim': 1.555,
#   'num_grcs': 1211,
#   'num_mfs': 481},
#  {'model': 'LocalEx\nRandom',
#   'mf_dim': 466.8800688495802,
#   'grc_dim': 712.4867889677637,
#   'grc_dim_norm': 1.1885219162822604,
#   'pct_grc': 0.588,
#   'pct_mfs': 1.439,
#   'pct_mf_dim': 1.526,
#   'num_grcs': 1211,
#   'num_mfs': 495},
#  {'model': 'Global\nRandom',
#   'mf_dim': 973.5962403269881,
#   'grc_dim': 908.5890014465031,
#   'grc_dim_norm': 1.5156462657738377,
#   'pct_grc': 0.75,
#   'pct_mfs': 0.8220000000000001,
#   'pct_mf_dim': 0.9329999999999999,
#   'num_grcs': 1211,
#   'num_mfs': 1105},
#  {'model': 'Global\nRandom',
#   'mf_dim': 982.7888509903844,
#   'grc_dim': 922.8563670791776,
#   'grc_dim_norm': 1.5394461130195853,
#   'pct_grc': 0.762,
#   'pct_mfs': 0.826,
#   'pct_mf_dim': 0.9390000000000001,
#   'num_grcs': 1211,
#   'num_mfs': 1117},
#  {'model': 'Global\nRandom',
#   'mf_dim': 969.9716364775221,
#   'grc_dim': 907.4354298014184,
#   'grc_dim_norm': 1.5137219561537656,
#   'pct_grc': 0.7490000000000001,
#   'pct_mfs': 0.8240000000000001,
#   'pct_mf_dim': 0.935,
#   'num_grcs': 1211,
#   'num_mfs': 1100},
#  {'model': 'Global\nRandom',
#   'mf_dim': 988.7990054009828,
#   'grc_dim': 933.9914200966429,
#   'grc_dim_norm': 1.5580208497798218,
#   'pct_grc': 0.7709999999999999,
#   'pct_mfs': 0.83,
#   'pct_mf_dim': 0.9440000000000001,
#   'num_grcs': 1211,
#   'num_mfs': 1125},
#  {'model': 'Global\nRandom',
#   'mf_dim': 983.6379991705276,
#   'grc_dim': 924.5192917389902,
#   'grc_dim_norm': 1.5422200906342114,
#   'pct_grc': 0.763,
#   'pct_mfs': 0.826,
#   'pct_mf_dim': 0.9390000000000001,
#   'num_grcs': 1211,
#   'num_mfs': 1118},
#  {'model': 'Global\nRandom',
#   'mf_dim': 979.5142490837374,
#   'grc_dim': 917.9555833127531,
#   'grc_dim_norm': 1.5312709594538685,
#   'pct_grc': 0.758,
#   'pct_mfs': 0.8240000000000001,
#   'pct_mf_dim': 0.937,
#   'num_grcs': 1211,
#   'num_mfs': 1113},
#  {'model': 'Global\nRandom',
#   'mf_dim': 988.4473642610571,
#   'grc_dim': 926.0380345632212,
#   'grc_dim_norm': 1.5447535539345068,
#   'pct_grc': 0.764,
#   'pct_mfs': 0.823,
#   'pct_mf_dim': 0.9359999999999999,
#   'num_grcs': 1211,
#   'num_mfs': 1124},
#  {'model': 'Global\nRandom',
#   'mf_dim': 985.082816357109,
#   'grc_dim': 924.8347663373436,
#   'grc_dim_norm': 1.5427463438644173,
#   'pct_grc': 0.763,
#   'pct_mfs': 0.825,
#   'pct_mf_dim': 0.938,
#   'num_grcs': 1211,
#   'num_mfs': 1120},
#  {'model': 'Global\nRandom',
#   'mf_dim': 982.1553349540749,
#   'grc_dim': 923.4008481531318,
#   'grc_dim_norm': 1.540354379249101,
#   'pct_grc': 0.762,
#   'pct_mfs': 0.8270000000000001,
#   'pct_mf_dim': 0.94,
#   'num_grcs': 1211,
#   'num_mfs': 1116},
#  {'model': 'Global\nRandom',
#   'mf_dim': 971.4652629244843,
#   'grc_dim': 902.0470811285825,
#   'grc_dim_norm': 1.5047334800312622,
#   'pct_grc': 0.7440000000000001,
#   'pct_mfs': 0.818,
#   'pct_mf_dim': 0.9279999999999999,
#   'num_grcs': 1211,
#   'num_mfs': 1102}]

# %%
importlib.reload(my_plot); my_plot.my_catplot(
    mpd,
    x='model',
    y='grc_dim_norm',
    context='paper',
    height=4,
    aspect=1,
    errwidth=4,
    font_scale=1.3,
    ci=100,
    y_axis_label='Normalized Dimensionality',
#     y_axis_label='Dim / # of GrCs',
#     x_axis_label='Normalized Dimensionality',
    save_filename=f'{script_n}_norm_dim_grc_by_local.svg',
    show=True,
    )
# Out:
# Height: 4, Aspect: 1

# %%
db['data']
# Out:
# {0: {'mf_dim': 474.7653773986999,
#   'grc_dim': 681.5008632400699,
#   'pct_grc': 56.2,
#   'pct_mfs': 126.9,
#   'pct_mf_dim': 143.5,
#   'num_grcs': 1211,
#   'num_mfs': 537}}

# %%
db_old
# Out:
# {'expanded_random_30': {0: {'mf_dim': 438.5370036705424,
#    'grc_dim': 656.5114131903176,
#    'pct_grc': 54.2,
#    'pct_mfs': 133.7,
#    'pct_mf_dim': 149.7,
#    'num_grcs': 1211,
#    'num_mfs': 491}},
#  'expanded_random_50': {0: {'mf_dim': 474.7653773986999,
#    'grc_dim': 681.5008632400699,
#    'pct_grc': 56.2,
#    'pct_mfs': 126.9,
#    'pct_mf_dim': 143.5,
#    'num_grcs': 1211,
#    'num_mfs': 537}},
#  'data': {0: {'mf_dim': 474.7653773986999,
#    'grc_dim': 681.5008632400699,
#    'pct_grc': 56.2,
#    'pct_mfs': 126.9,
#    'pct_mf_dim': 143.5,
#    'num_grcs': 1211,
#    'num_mfs': 537}},
#  'classic_random': {0: {'mf_dim': 434.9303375833406,
#    'grc_dim': 735.8111799694942,
#    'pct_grc': 60.7,
#    'pct_mfs': 151.0,
#    'pct_mf_dim': 169.1,
#    'num_grcs': 1211,
#    'num_mfs': 487}},
#  'naive_random_17_1': {0: {'mf_dim': 414.05600382650914,
#    'grc_dim': 572.5242247256178,
#    'pct_grc': 47.2,
#    'pct_mfs': 124.1,
#    'pct_mf_dim': 138.2,
#    'num_grcs': 1211,
#    'num_mfs': 461}},
#  'naive_random_17_4': {0: {'mf_dim': 414.05600382650914,
#    'grc_dim': 572.5242247256178,
#    'pct_grc': 47.2,
#    'pct_mfs': 124.1,
#    'pct_mf_dim': 138.2,
#    'num_grcs': 1211,
#    'num_mfs': 461}}}
