# %%
import random
import copy
import logging
import sys

from run_tests_201204 import *

import os
import sys
import importlib
from collections import defaultdict
sys.path.insert(0, '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc')
from tools_pattern import get_eucledean_dist
import compress_pickle
import my_plot
from my_plot import MyPlotData, my_box_plot

# script_n = os.path.basename(__file__).split('.')[0]
script_n = 'plot_grcdim_by_mfdim_by_actlv_210119_test'
show = True

base_path = '/n/groups/htem/Segmentation/shared-nondev/cb2_segmentation/analysis_mf_grc/dimensionality_sim'

db = {}
# db = compress_pickle.load(f'{base_path}/data/batch_similarity_by_activation_level_201210_4096.gz')
# db = db[0]

# name = 'batch_similarity_by_activation_level_210118_data_4096_1'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['data'] = dbb

# name = 'batch_similarity_by_activation_level_210118_naive_random2_4096_10'
# # name = 'batch_similarity_by_activation_level_210118_naive_random2_4096_'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['naive_random2'] = dbb

# name = 'batch_similarity_by_activation_level_210118_naive_random3_4096_10'
# # name = 'batch_similarity_by_activation_level_210118_naive_random2_4096_'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['naive_random3'] = dbb

# name = 'batch_similarity_by_activation_level_210118_expanded_random_30_4096_10'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['expanded_random_30'] = dbb

# name = 'batch_similarity_by_activation_level_210118_global_random_4096_10'
# dbb = compress_pickle.load(f'{base_path}/data/{name}.gz')
# db['global_random'] = dbb


for model_name in [
#         'naive_random2',
#         'naive_random3',
#         'naive_random_15_1',
#         'naive_random_15_2',
#         'naive_random_15_3',
#         'naive_random_15_4',
        'naive_random_17_2',
#         'naive_random_17_3',
        'expanded_random_30',
#         'expanded_random_50',
        'data',
        'global_random',
#         'classic_random',
        ]:
    name = f'batch_similarity_by_activation_level_210118_{model_name}_4096_10'
    dbb = compress_pickle.load(f'{base_path}/data/210119/{name}.gz')
    db[model_name] = dbb


# fix global random mf dim
for activation_level in db['data'][0][0]:
    ressss = db['global_random']
    ressss = ressss[0]
    ressss_data = db['naive_random_17_2']
    ressss_data = ressss_data[0]
    for resss, resss_data in zip(ressss, ressss_data):
        ress = resss[activation_level]
        ress_data = resss_data[activation_level]
        for noise_level in ress:
            ress[noise_level]['mf_dim'] = ress_data[noise_level]['mf_dim']
#             pass

# fix global random mf dim
for activation_level in db['data'][0][0]:
    ressss = db['data']
    ressss = ressss[0]
    ressss_data = db['naive_random_17_2']
    ressss_data = ressss_data[0]
    for resss, resss_data in zip(ressss, ressss_data):
        ress = resss[activation_level]
        ress_data = resss_data[activation_level]
        for noise_level in ress:
            ress[noise_level]['mf_dim'] = ress_data[noise_level]['mf_dim']
#             pass


def get_plot_name(model_name):
    if 'data' == model_name:
        return 'Observation'
    if 'classic_random' == model_name:
        return 'Classic Random'
    if 'naive_random_15_2' == model_name:
        return 'Local Random'
    if 'naive_random_17_2' == model_name:
        return 'Local Random'
    if 'data' == model_name:
        return 'Data'
    if 'expanded_random_30' == model_name:
        return 'LocalEx Random'
    if 'global_random' == model_name:
        return 'Global Random'
    return model_name


def add_results(res, mpd):
    hamming_distance_norm = res['hamming_distance']/res['num_grcs']
    mpd.add_data_point(
        model=get_plot_name(model_name),
        # mf_dim=res[0]['mf_dim'],
        activation_level=activation_level,
        noise_level=noise_level*100,
        grc_dim=res['grc_dim'],
        mf_dim=res['mf_dim'],
        grc_mf_dim=res['grc_dim']/res['mf_dim'],
        mf_grc_dim=res['mf_dim']/res['grc_dim'],
        pct_grc=res['pct_grc']/100,
        pct_mfs=res['pct_mfs']/100,
        # pct_mf_dim=res['pct_mf_dim']/100,
        num_grcs=res['num_grcs'],
        num_mfs=res['num_mfs'],
        voi=res['voi'],
        grc_pop_corr=res['grc_pop_corr'],
        mf_pop_corr=res['mf_pop_corr'],
        binary_similarity=res['binary_similarity'],
        hamming_distance=res['hamming_distance'],
        hamming_distance_norm=hamming_distance_norm,
        # hamming_distance_norm_max=hamming_distance_norm_max,
        )

os.makedirs(script_n, exist_ok=True)

# %%
# def custom_legend_fn(plt):
# #     plt.legend(bbox_to_anchor=(1.025, .8), loc='upper left', borderaxespad=0.)
#     plt.legend(bbox_to_anchor=(1, .8), loc='upper left', frameon=False)

    
for activation_level in db['data'][0][0]:
    mpd = MyPlotData()
    for model_name in [
            'data',
#             'naive_random2',
#             'naive_random3',
#             'classic_random',
#         'naive_random_15_2',
        'naive_random_17_2',
            'expanded_random_30',
#             'expanded_random_50',
            'global_random',
#         'naive_random2',
#         'naive_random3',
#         'naive_random_15_1',
#         'naive_random_15_3',
#         'naive_random_15_4',
#         'naive_random_17_3',
            ]:
        resss = db[model_name]
        resss_tries = resss[0]
        for resss in resss_tries:
            ress = resss[activation_level]
            for noise_level, res in ress.items():
                add_results(res, mpd)

    if activation_level <= .20:
        show = True
    else:
        show = False
    importlib.reload(my_plot); my_plot.my_relplot(
        mpd,
        x='noise_level',
#         y='grc_mf_dim',
        y='grc_dim',
        hue='model',
        context='paper',
        height=4,
        aspect=1.1,
        ylim=[0, None],
#         custom_legend_fn=custom_legend_fn,
        custom_legend_loc='lower right',
        y_axis_label='Dim. Expansion (x)',
        x_axis_label='MF Input Variation (%)',
        save_filename=f'{script_n}/{script_n}_{activation_level*100}.svg',
        show=show,
        )
# Out:
# Height: 4, Aspect: 1.1

# %%
for activation_level in db['data'][0][0]:
    mpd = MyPlotData()
    for model_name in [
            'data',
#             'naive_random2',
#             'naive_random3',
#             'classic_random',
        'naive_random_17_2',
#         'naive_random_15_2',
            'expanded_random_30',
#             'expanded_random_50',
            'global_random',
#         'naive_random2',
#         'naive_random3',
#         'naive_random_15_1',
#         'naive_random_15_3',
#         'naive_random_15_4',
#         'naive_random_17_3',
            ]:
        resss = db[model_name]
        resss_tries = resss[0]
        for resss in resss_tries:
            ress = resss[activation_level]
            for noise_level, res in ress.items():
                add_results(res, mpd)

    if activation_level <= .20:
        show = True
    else:
        show = False
    importlib.reload(my_plot); my_plot.my_relplot(
        mpd,
        x='noise_level',
        y='mf_grc_dim',
        hue='model',
        context='paper',
        height=4,
        aspect=1.1,
        ylim=[.8, None],
        custom_legend_loc='upper right',
        y_axis_label='Dim. Convergence (x)',
        x_axis_label='MF Input Variation (%)',
        save_filename=f'{script_n}/{script_n}_{activation_level*100}_dim_convergence.svg',
        show=show,
        )
# Out:
# Height: 4, Aspect: 1.1

# %%
db['naive_random_17_2']
# Out:
# ([{0.2: {0.025: {'voi': 0.20338223828651955,
#      'binary_similarity': 0.962694891567892,
#      'hamming_distance': 18.140625,
#      'normalized_mse': 0.04681210002064409,
#      'grc_pop_corr': 0.004425162404546161,
#      'mf_dim': 352.2646563123422,
#      'mf_pop_corr': 0.0014940040181238116,
#      'grc_dim': 248.87169094238695,
#      'pct_grc': 20.5,
#      'pct_mfs': 52.8,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.05: {'voi': 0.3484951269024161,
#      'binary_similarity': 0.927329227842136,
#      'hamming_distance': 35.195556640625,
#      'normalized_mse': 0.09082255532778952,
#      'grc_pop_corr': 0.00394880535405988,
#      'mf_dim': 355.297325645378,
#      'mf_pop_corr': 0.0014508501476307336,
#      'grc_dim': 264.8094637146752,
#      'pct_grc': 21.8,
#      'pct_mfs': 56.2,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.075: {'voi': 0.46854126156865644,
#      'binary_similarity': 0.8924623686691774,
#      'hamming_distance': 51.8017578125,
#      'normalized_mse': 0.1336750562874174,
#      'grc_pop_corr': 0.0040119271977073125,
#      'mf_dim': 359.04174813919946,
#      'mf_pop_corr': 0.0014048334028650133,
#      'grc_dim': 273.9349511287636,
#      'pct_grc': 22.6,
#      'pct_mfs': 58.1,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.1: {'voi': 0.5722212720294862,
#      'binary_similarity': 0.859169795595365,
#      'hamming_distance': 67.91943359375,
#      'normalized_mse': 0.17526691162714178,
#      'grc_pop_corr': 0.0037190097810158498,
#      'mf_dim': 359.39223424235263,
#      'mf_pop_corr': 0.001401389925704291,
#      'grc_dim': 287.01450168154116,
#      'pct_grc': 23.7,
#      'pct_mfs': 60.9,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.125: {'voi': 0.6614165994586503,
#      'binary_similarity': 0.828654322130927,
#      'hamming_distance': 83.296875,
#      'normalized_mse': 0.2149485832989265,
#      'grc_pop_corr': 0.003642380754167325,
#      'mf_dim': 362.08826411264755,
#      'mf_pop_corr': 0.0013408829271909595,
#      'grc_dim': 296.15627133896464,
#      'pct_grc': 24.4,
#      'pct_mfs': 62.8,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.15: {'voi': 0.74107341489789,
#      'binary_similarity': 0.7971454488820031,
#      'hamming_distance': 98.26025390625,
#      'normalized_mse': 0.2535617617316525,
#      'grc_pop_corr': 0.0034014727773526757,
#      'mf_dim': 363.5882358846033,
#      'mf_pop_corr': 0.0013312210360069562,
#      'grc_dim': 306.2193961766908,
#      'pct_grc': 25.2,
#      'pct_mfs': 65.0,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.175: {'voi': 0.8082392998028521,
#      'binary_similarity': 0.768060092268319,
#      'hamming_distance': 111.905029296875,
#      'normalized_mse': 0.2887722680039094,
#      'grc_pop_corr': 0.0034044506618293433,
#      'mf_dim': 365.14586855121036,
#      'mf_pop_corr': 0.001311194016374217,
#      'grc_dim': 315.08795847479666,
#      'pct_grc': 26.0,
#      'pct_mfs': 66.8,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.2: {'voi': 0.8711012465249199,
#      'binary_similarity': 0.7400102286503256,
#      'hamming_distance': 125.65185546875,
#      'normalized_mse': 0.3242461175390947,
#      'grc_pop_corr': 0.0032139423695861143,
#      'mf_dim': 367.53517769791097,
#      'mf_pop_corr': 0.0013220586284091978,
#      'grc_dim': 325.62718417023757,
#      'pct_grc': 26.8,
#      'pct_mfs': 69.1,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.225: {'voi': 0.9271298419230143,
#      'binary_similarity': 0.7117172767376101,
#      'hamming_distance': 138.865966796875,
#      'normalized_mse': 0.3583452900414817,
#      'grc_pop_corr': 0.0031689339857666216,
#      'mf_dim': 369.26158541229006,
#      'mf_pop_corr': 0.0012677522713702822,
#      'grc_dim': 333.10338885009793,
#      'pct_grc': 27.5,
#      'pct_mfs': 70.7,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.25: {'voi': 0.9753173245428358,
#      'binary_similarity': 0.6849491514008604,
#      'hamming_distance': 151.01025390625,
#      'normalized_mse': 0.38968376833776314,
#      'grc_pop_corr': 0.0031060422237056393,
#      'mf_dim': 370.7332153469201,
#      'mf_pop_corr': 0.0012841137163166945,
#      'grc_dim': 343.0418156803568,
#      'pct_grc': 28.3,
#      'pct_mfs': 72.8,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.275: {'voi': 1.0199009653371027,
#      'binary_similarity': 0.6611096612338364,
#      'hamming_distance': 162.765380859375,
#      'normalized_mse': 0.420018014191203,
#      'grc_pop_corr': 0.0030672495380983326,
#      'mf_dim': 372.82862492290263,
#      'mf_pop_corr': 0.001235562769837915,
#      'grc_dim': 351.0634037557284,
#      'pct_grc': 28.9,
#      'pct_mfs': 74.5,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.3: {'voi': 1.0594617758900953,
#      'binary_similarity': 0.6378636853448262,
#      'hamming_distance': 174.04150390625,
#      'normalized_mse': 0.44911618472917525,
#      'grc_pop_corr': 0.002999330506391393,
#      'mf_dim': 374.7596070016858,
#      'mf_pop_corr': 0.0012256964109072976,
#      'grc_dim': 360.6942550039032,
#      'pct_grc': 29.7,
#      'pct_mfs': 76.5,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.325: {'voi': 1.0979811697617878,
#      'binary_similarity': 0.6133759597252157,
#      'hamming_distance': 185.648681640625,
#      'normalized_mse': 0.47906864585214953,
#      'grc_pop_corr': 0.0029742842139248234,
#      'mf_dim': 375.85499988461913,
#      'mf_pop_corr': 0.0012323695058690022,
#      'grc_dim': 368.04513730889215,
#      'pct_grc': 30.3,
#      'pct_mfs': 78.1,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.35: {'voi': 1.1298966781564894,
#      'binary_similarity': 0.589794290476832,
#      'hamming_distance': 196.040283203125,
#      'normalized_mse': 0.5058842981088072,
#      'grc_pop_corr': 0.0028902279875328957,
#      'mf_dim': 378.12533982190513,
#      'mf_pop_corr': 0.0011942902459927665,
#      'grc_dim': 377.32143037435657,
#      'pct_grc': 31.1,
#      'pct_mfs': 80.1,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.375: {'voi': 1.160353002738286,
#      'binary_similarity': 0.5701746447332968,
#      'hamming_distance': 206.2373046875,
#      'normalized_mse': 0.5321978341440441,
#      'grc_pop_corr': 0.002834547429631753,
#      'mf_dim': 379.98294276222384,
#      'mf_pop_corr': 0.0011714953198466863,
#      'grc_dim': 383.2809992901374,
#      'pct_grc': 31.6,
#      'pct_mfs': 81.3,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.4: {'voi': 1.1862233216909381,
#      'binary_similarity': 0.550405568089978,
#      'hamming_distance': 215.521240234375,
#      'normalized_mse': 0.5561551409846588,
#      'grc_pop_corr': 0.0027358410120470735,
#      'mf_dim': 381.43289332848775,
#      'mf_pop_corr': 0.001175662224639089,
#      'grc_dim': 392.3353831755736,
#      'pct_grc': 32.3,
#      'pct_mfs': 83.2,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.425: {'voi': 1.2108434941169341,
#      'binary_similarity': 0.5296904465247873,
#      'hamming_distance': 224.95458984375,
#      'normalized_mse': 0.5804980126025753,
#      'grc_pop_corr': 0.0027112727614424185,
#      'mf_dim': 383.68449194121996,
#      'mf_pop_corr': 0.0011542407035056363,
#      'grc_dim': 398.00057893760174,
#      'pct_grc': 32.8,
#      'pct_mfs': 84.5,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.45: {'voi': 1.2330509084209504,
#      'binary_similarity': 0.5102012897359905,
#      'hamming_distance': 234.02099609375,
#      'normalized_mse': 0.6038939824880005,
#      'grc_pop_corr': 0.0027561260797872343,
#      'mf_dim': 386.08816620215754,
#      'mf_pop_corr': 0.0011524642947235114,
#      'grc_dim': 404.77094742236335,
#      'pct_grc': 33.4,
#      'pct_mfs': 85.9,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.475: {'voi': 1.2544848834100177,
#      'binary_similarity': 0.4911404313712302,
#      'hamming_distance': 243.1416015625,
#      'normalized_mse': 0.6274298141063686,
#      'grc_pop_corr': 0.002687827712518069,
#      'mf_dim': 388.1469036645862,
#      'mf_pop_corr': 0.001089795036653963,
#      'grc_dim': 411.73137178189853,
#      'pct_grc': 33.9,
#      'pct_mfs': 87.4,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.5: {'voi': 1.274366839027862,
#      'binary_similarity': 0.4721342941810349,
#      'hamming_distance': 252.17333984375,
#      'normalized_mse': 0.6507363228833349,
#      'grc_pop_corr': 0.002612959668306229,
#      'mf_dim': 389.5864809293382,
#      'mf_pop_corr': 0.0010808710458118716,
#      'grc_dim': 418.60928388143225,
#      'pct_grc': 34.5,
#      'pct_mfs': 88.8,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.525: {'voi': 1.2904538908199277,
#      'binary_similarity': 0.4551738870554959,
#      'hamming_distance': 260.032958984375,
#      'normalized_mse': 0.6710181641834614,
#      'grc_pop_corr': 0.002557032289843065,
#      'mf_dim': 391.9246478684661,
#      'mf_pop_corr': 0.00109883599156307,
#      'grc_dim': 424.58424203331,
#      'pct_grc': 35.0,
#      'pct_mfs': 90.1,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.55: {'voi': 1.3064222251157658,
#      'binary_similarity': 0.43794092638739346,
#      'hamming_distance': 268.227783203125,
#      'normalized_mse': 0.6921650062012927,
#      'grc_pop_corr': 0.002590380835988513,
#      'mf_dim': 394.1885485515227,
#      'mf_pop_corr': 0.001047049299485271,
#      'grc_dim': 430.45258654219566,
#      'pct_grc': 35.5,
#      'pct_mfs': 91.3,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.575: {'voi': 1.3218749017188132,
#      'binary_similarity': 0.42264741042564596,
#      'hamming_distance': 276.32861328125,
#      'normalized_mse': 0.7130692952137954,
#      'grc_pop_corr': 0.0025065275973460547,
#      'mf_dim': 395.9008826873084,
#      'mf_pop_corr': 0.001032184853932758,
#      'grc_dim': 436.3344689345498,
#      'pct_grc': 36.0,
#      'pct_mfs': 92.6,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.6: {'voi': 1.333874656703386,
#      'binary_similarity': 0.4068929738011853,
#      'hamming_distance': 283.540771484375,
#      'normalized_mse': 0.7316803558122805,
#      'grc_pop_corr': 0.002455655569680531,
#      'mf_dim': 397.78819251239696,
#      'mf_pop_corr': 0.0010291517201492116,
#      'grc_dim': 440.2803435264549,
#      'pct_grc': 36.3,
#      'pct_mfs': 93.4,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.625: {'voi': 1.3447531509427153,
#      'binary_similarity': 0.3915647309401945,
#      'hamming_distance': 290.4541015625,
#      'normalized_mse': 0.7495202868561621,
#      'grc_pop_corr': 0.002367149946321217,
#      'mf_dim': 399.9814824876895,
#      'mf_pop_corr': 0.0009970896448857896,
#      'grc_dim': 448.17458164343856,
#      'pct_grc': 37.0,
#      'pct_mfs': 95.1,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.65: {'voi': 1.3537194400162635,
#      'binary_similarity': 0.37542935075430955,
#      'hamming_distance': 297.120361328125,
#      'normalized_mse': 0.7667226500003225,
#      'grc_pop_corr': 0.002376573184261599,
#      'mf_dim': 401.86769819420516,
#      'mf_pop_corr': 0.0009644528302779064,
#      'grc_dim': 452.90445747884127,
#      'pct_grc': 37.3,
#      'pct_mfs': 96.1,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.675: {'voi': 1.3658489945194563,
#      'binary_similarity': 0.3607588143184265,
#      'hamming_distance': 305.368408203125,
#      'normalized_mse': 0.7880068337198726,
#      'grc_pop_corr': 0.0023960921412962202,
#      'mf_dim': 404.01619461552133,
#      'mf_pop_corr': 0.0009769847006434768,
#      'grc_dim': 457.19103173127075,
#      'pct_grc': 37.7,
#      'pct_mfs': 97.0,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.7: {'voi': 1.3728497437728742,
#      'binary_similarity': 0.34801298996497826,
#      'hamming_distance': 310.953125,
#      'normalized_mse': 0.8024182622832369,
#      'grc_pop_corr': 0.0023706945945034734,
#      'mf_dim': 406.52922899490835,
#      'mf_pop_corr': 0.0009473424773637021,
#      'grc_dim': 460.89990334073354,
#      'pct_grc': 38.0,
#      'pct_mfs': 97.8,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.725: {'voi': 1.3789631832613272,
#      'binary_similarity': 0.3344305630387935,
#      'hamming_distance': 316.832763671875,
#      'normalized_mse': 0.8175907402763083,
#      'grc_pop_corr': 0.002332280751218675,
#      'mf_dim': 407.98132249939516,
#      'mf_pop_corr': 0.0009119013963209701,
#      'grc_dim': 466.57702455039754,
#      'pct_grc': 38.5,
#      'pct_mfs': 99.0,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.75: {'voi': 1.3877632620930744,
#      'binary_similarity': 0.3213279987203675,
#      'hamming_distance': 323.87939453125,
#      'normalized_mse': 0.8357746555822924,
#      'grc_pop_corr': 0.0023051512186243327,
#      'mf_dim': 410.1686082225598,
#      'mf_pop_corr': 0.0009038132758443628,
#      'grc_dim': 471.5327708578142,
#      'pct_grc': 38.9,
#      'pct_mfs': 100.1,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.775: {'voi': 1.3946202362240196,
#      'binary_similarity': 0.3070752374057102,
#      'hamming_distance': 330.776123046875,
#      'normalized_mse': 0.8535717460953627,
#      'grc_pop_corr': 0.0022277633711141154,
#      'mf_dim': 412.0217037080202,
#      'mf_pop_corr': 0.0008631070511335006,
#      'grc_dim': 475.00689753040086,
#      'pct_grc': 39.2,
#      'pct_mfs': 100.8,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.8: {'voi': 1.3991144589095774,
#      'binary_similarity': 0.29435151198814624,
#      'hamming_distance': 336.504150390625,
#      'normalized_mse': 0.8683529892408778,
#      'grc_pop_corr': 0.0021924665426455007,
#      'mf_dim': 413.9238789764547,
#      'mf_pop_corr': 0.0008434990854722715,
#      'grc_dim': 481.79059285430185,
#      'pct_grc': 39.7,
#      'pct_mfs': 102.2,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.825: {'voi': 1.4042258418468332,
#      'binary_similarity': 0.28268537850215514,
#      'hamming_distance': 342.506591796875,
#      'normalized_mse': 0.8838423611603915,
#      'grc_pop_corr': 0.002205079697718637,
#      'mf_dim': 415.7586883782626,
#      'mf_pop_corr': 0.0008372744735827422,
#      'grc_dim': 482.05434257629764,
#      'pct_grc': 39.8,
#      'pct_mfs': 102.3,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.85: {'voi': 1.4078788024046718,
#      'binary_similarity': 0.2705530627020467,
#      'hamming_distance': 348.08349609375,
#      'normalized_mse': 0.8982336294739625,
#      'grc_pop_corr': 0.002143013494544779,
#      'mf_dim': 417.1051370782416,
#      'mf_pop_corr': 0.0008202268556636844,
#      'grc_dim': 486.3417297670529,
#      'pct_grc': 40.1,
#      'pct_mfs': 103.2,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.875: {'voi': 1.4105555923731352,
#      'binary_similarity': 0.25796403556034603,
#      'hamming_distance': 353.496826171875,
#      'normalized_mse': 0.9122027925574808,
#      'grc_pop_corr': 0.0020908377561431775,
#      'mf_dim': 418.27012022470296,
#      'mf_pop_corr': 0.0008138497043293343,
#      'grc_dim': 489.94835495487496,
#      'pct_grc': 40.4,
#      'pct_mfs': 104.0,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.9: {'voi': 1.4156777200271295,
#      'binary_similarity': 0.24665990369073218,
#      'hamming_distance': 360.283935546875,
#      'normalized_mse': 0.9297170095656352,
#      'grc_pop_corr': 0.002169255228920151,
#      'mf_dim': 419.7267858982705,
#      'mf_pop_corr': 0.0007889534298106605,
#      'grc_dim': 489.08431180684096,
#      'pct_grc': 40.3,
#      'pct_mfs': 103.8,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.925: {'voi': 1.4170937858974424,
#      'binary_similarity': 0.23486117658944014,
#      'hamming_distance': 365.48828125,
#      'normalized_mse': 0.9431468859671758,
#      'grc_pop_corr': 0.002117273676865715,
#      'mf_dim': 420.85013888246147,
#      'mf_pop_corr': 0.0007632833061071986,
#      'grc_dim': 492.5319717813073,
#      'pct_grc': 40.6,
#      'pct_mfs': 104.5,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.95: {'voi': 1.4175043473489055,
#      'binary_similarity': 0.22287408236799552,
#      'hamming_distance': 370.54931640625,
#      'normalized_mse': 0.9562069477865657,
#      'grc_pop_corr': 0.002129070347146481,
#      'mf_dim': 422.1744420173423,
#      'mf_pop_corr': 0.000766784599702696,
#      'grc_dim': 493.241092852554,
#      'pct_grc': 40.7,
#      'pct_mfs': 104.7,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     0.975: {'voi': 1.4193130242774745,
#      'binary_similarity': 0.21195510338092713,
#      'hamming_distance': 376.153564453125,
#      'normalized_mse': 0.9706687769744141,
#      'grc_pop_corr': 0.0021303731706076947,
#      'mf_dim': 422.26673157621144,
#      'mf_pop_corr': 0.0007568535956836897,
#      'grc_dim': 494.30356953167643,
#      'pct_grc': 40.8,
#      'pct_mfs': 104.9,
#      'num_grcs': 1211,
#      'num_mfs': 471},
#     1.0: {'voi': 1.4211294068620215,
#      'binary_similarity': 0.2018800932785562,
#      'hamming_distance': 381.706298828125,
#      'normalized_mse': 0.9849976745151863,
#      'grc_pop_corr': 0.0021132266398821648,
#      'mf_dim': 422.303438059309,
#      'mf_pop_corr': 0.000756896614266331,
#      'grc_dim': 493.0681826774928,
#      'pct_grc': 40.7,
#      'pct_mfs': 104.6,
#      'num_grcs': 1211,
#      'num_mfs': 471}}},
#   {0.2: {0.025: {'voi': 0.20932237013029076,
#      'binary_similarity': 0.9598767510775887,
#      'hamming_distance': 18.78076171875,
#      'normalized_mse': 0.04846398048810383,
#      'grc_pop_corr': 0.00437810250382821,
#      'mf_dim': 350.5621467598708,
#      'mf_pop_corr': 0.0015376152329017207,
#      'grc_dim': 246.57058927551637,
#      'pct_grc': 20.3,
#      'pct_mfs': 52.1,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.05: {'voi': 0.35929718826432394,
#      'binary_similarity': 0.9216824235587298,
#      'hamming_distance': 36.62890625,
#      'normalized_mse': 0.09452133115710155,
#      'grc_pop_corr': 0.004042490901496222,
#      'mf_dim': 356.75147332305573,
#      'mf_pop_corr': 0.0014400002674584379,
#      'grc_dim': 262.0958124986099,
#      'pct_grc': 21.6,
#      'pct_mfs': 55.4,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.075: {'voi': 0.483862309275322,
#      'binary_similarity': 0.8839184991244607,
#      'hamming_distance': 54.072998046875,
#      'normalized_mse': 0.13953601890708867,
#      'grc_pop_corr': 0.003821974752211363,
#      'mf_dim': 358.53174966390776,
#      'mf_pop_corr': 0.0013763195477868265,
#      'grc_dim': 270.4125381842084,
#      'pct_grc': 22.3,
#      'pct_mfs': 57.1,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.1: {'voi': 0.5866290690503793,
#      'binary_similarity': 0.8489169416756457,
#      'hamming_distance': 70.396728515625,
#      'normalized_mse': 0.18165960083511817,
#      'grc_pop_corr': 0.0037752514388672467,
#      'mf_dim': 360.9217767063058,
#      'mf_pop_corr': 0.00135636799297352,
#      'grc_dim': 278.72689368086105,
#      'pct_grc': 23.0,
#      'pct_mfs': 58.9,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.125: {'voi': 0.6758327237451981,
#      'binary_similarity': 0.8155833277209056,
#      'hamming_distance': 85.9794921875,
#      'normalized_mse': 0.22187110907178983,
#      'grc_pop_corr': 0.003691713596668726,
#      'mf_dim': 364.5431582669538,
#      'mf_pop_corr': 0.001333324251321898,
#      'grc_dim': 291.02975339055797,
#      'pct_grc': 24.0,
#      'pct_mfs': 61.5,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.15: {'voi': 0.7544448189357581,
#      'binary_similarity': 0.7853688207165933,
#      'hamming_distance': 101.0185546875,
#      'normalized_mse': 0.26067958992439094,
#      'grc_pop_corr': 0.0035028551208215832,
#      'mf_dim': 365.53913146266444,
#      'mf_pop_corr': 0.0013443981246293614,
#      'grc_dim': 302.52373385215714,
#      'pct_grc': 24.9,
#      'pct_mfs': 63.9,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.175: {'voi': 0.8274539115728115,
#      'binary_similarity': 0.7515427161907308,
#      'hamming_distance': 116.222412109375,
#      'normalized_mse': 0.299913326046075,
#      'grc_pop_corr': 0.0034226673103809656,
#      'mf_dim': 366.82019785736327,
#      'mf_pop_corr': 0.0012709283470071855,
#      'grc_dim': 310.7336031861718,
#      'pct_grc': 25.6,
#      'pct_mfs': 65.6,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.2: {'voi': 0.8879092419317266,
#      'binary_similarity': 0.7217912345096985,
#      'hamming_distance': 129.875244140625,
#      'normalized_mse': 0.3351446225759315,
#      'grc_pop_corr': 0.0034260574859886397,
#      'mf_dim': 368.0798903019216,
#      'mf_pop_corr': 0.0013054022465603182,
#      'grc_dim': 319.04533038548243,
#      'pct_grc': 26.3,
#      'pct_mfs': 67.4,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.225: {'voi': 0.9414924012291843,
#      'binary_similarity': 0.696351149986529,
#      'hamming_distance': 142.58349609375,
#      'normalized_mse': 0.36793841890418555,
#      'grc_pop_corr': 0.0032667801560467753,
#      'mf_dim': 371.0116963819214,
#      'mf_pop_corr': 0.001236195015987831,
#      'grc_dim': 330.53538648180313,
#      'pct_grc': 27.2,
#      'pct_mfs': 69.8,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.25: {'voi': 0.9894863416876998,
#      'binary_similarity': 0.6702586206896574,
#      'hamming_distance': 154.89111328125,
#      'normalized_mse': 0.3996983724227136,
#      'grc_pop_corr': 0.0031741459754725883,
#      'mf_dim': 371.8475569677562,
#      'mf_pop_corr': 0.001260448384735645,
#      'grc_dim': 341.1555146386193,
#      'pct_grc': 28.1,
#      'pct_mfs': 72.1,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.275: {'voi': 1.033598531371058,
#      'binary_similarity': 0.6436725484913773,
#      'hamming_distance': 167.064208984375,
#      'normalized_mse': 0.4311111916401088,
#      'grc_pop_corr': 0.003077963451309944,
#      'mf_dim': 374.5658778452215,
#      'mf_pop_corr': 0.0012360958642806026,
#      'grc_dim': 349.0834081076863,
#      'pct_grc': 28.8,
#      'pct_mfs': 73.8,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.3: {'voi': 1.0747086548467693,
#      'binary_similarity': 0.619677313442888,
#      'hamming_distance': 178.9560546875,
#      'normalized_mse': 0.4617982418649359,
#      'grc_pop_corr': 0.0030306322454048337,
#      'mf_dim': 376.5683366448697,
#      'mf_pop_corr': 0.001275841802348319,
#      'grc_dim': 357.7595681941169,
#      'pct_grc': 29.5,
#      'pct_mfs': 75.6,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.325: {'voi': 1.1103580019740502,
#      'binary_similarity': 0.5945118871228439,
#      'hamming_distance': 190.10107421875,
#      'normalized_mse': 0.49055809821106006,
#      'grc_pop_corr': 0.00303603217323314,
#      'mf_dim': 377.4716741034447,
#      'mf_pop_corr': 0.0012121813442400118,
#      'grc_dim': 364.81863956851225,
#      'pct_grc': 30.1,
#      'pct_mfs': 77.1,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.35: {'voi': 1.1415309022018296,
#      'binary_similarity': 0.5752321440598054,
#      'hamming_distance': 200.303466796875,
#      'normalized_mse': 0.51688549441803,
#      'grc_pop_corr': 0.0029124345542199817,
#      'mf_dim': 379.52507390932016,
#      'mf_pop_corr': 0.0011766601759030835,
#      'grc_dim': 375.02270419966004,
#      'pct_grc': 30.9,
#      'pct_mfs': 79.2,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.375: {'voi': 1.1715212467621101,
#      'binary_similarity': 0.5528795965786646,
#      'hamming_distance': 210.788818359375,
#      'normalized_mse': 0.5439430696722104,
#      'grc_pop_corr': 0.0028199221151645484,
#      'mf_dim': 381.31529528186445,
#      'mf_pop_corr': 0.0011696752257219492,
#      'grc_dim': 381.65854587896587,
#      'pct_grc': 31.5,
#      'pct_mfs': 80.6,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.4: {'voi': 1.1978210693277251,
#      'binary_similarity': 0.5321718413254317,
#      'hamming_distance': 220.4599609375,
#      'normalized_mse': 0.5688995688932184,
#      'grc_pop_corr': 0.0028053339879157094,
#      'mf_dim': 383.4614581073677,
#      'mf_pop_corr': 0.001165065680318732,
#      'grc_dim': 390.33989036136427,
#      'pct_grc': 32.2,
#      'pct_mfs': 82.5,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.425: {'voi': 1.221632243058733,
#      'binary_similarity': 0.5115145979256461,
#      'hamming_distance': 230.0078125,
#      'normalized_mse': 0.5935379141721717,
#      'grc_pop_corr': 0.0027657276788910297,
#      'mf_dim': 385.5681414330599,
#      'mf_pop_corr': 0.0011241476301269012,
#      'grc_dim': 395.83094991958166,
#      'pct_grc': 32.6,
#      'pct_mfs': 83.6,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.45: {'voi': 1.2424201777318504,
#      'binary_similarity': 0.4927536536907327,
#      'hamming_distance': 238.71142578125,
#      'normalized_mse': 0.6159976924578086,
#      'grc_pop_corr': 0.0026973164664558596,
#      'mf_dim': 386.9072084888428,
#      'mf_pop_corr': 0.0011549895406133468,
#      'grc_dim': 404.0094166827318,
#      'pct_grc': 33.3,
#      'pct_mfs': 85.4,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.475: {'voi': 1.2637211390372125,
#      'binary_similarity': 0.4743925949622849,
#      'hamming_distance': 248.078125,
#      'normalized_mse': 0.6401685719446738,
#      'grc_pop_corr': 0.0027270783526624418,
#      'mf_dim': 389.303762549179,
#      'mf_pop_corr': 0.0011053767453941886,
#      'grc_dim': 409.44293340030794,
#      'pct_grc': 33.8,
#      'pct_mfs': 86.5,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.5: {'voi': 1.2803384836394618,
#      'binary_similarity': 0.45892228751346953,
#      'hamming_distance': 255.808349609375,
#      'normalized_mse': 0.6601165091075945,
#      'grc_pop_corr': 0.0026158733262773323,
#      'mf_dim': 391.8447616036128,
#      'mf_pop_corr': 0.0010798673380696972,
#      'grc_dim': 416.23061942096024,
#      'pct_grc': 34.3,
#      'pct_mfs': 87.9,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.525: {'voi': 1.2974614121352561,
#      'binary_similarity': 0.44067803744611983,
#      'hamming_distance': 264.39111328125,
#      'normalized_mse': 0.6822644335292372,
#      'grc_pop_corr': 0.0025685494894676993,
#      'mf_dim': 393.2501567453149,
#      'mf_pop_corr': 0.0010673258313877653,
#      'grc_dim': 423.1005899002645,
#      'pct_grc': 34.9,
#      'pct_mfs': 89.4,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.55: {'voi': 1.3128347249654713,
#      'binary_similarity': 0.4271219187769392,
#      'hamming_distance': 272.16015625,
#      'normalized_mse': 0.7023125419333195,
#      'grc_pop_corr': 0.002596127090441651,
#      'mf_dim': 395.3444041199674,
#      'mf_pop_corr': 0.0010585009378607435,
#      'grc_dim': 426.1136996385232,
#      'pct_grc': 35.1,
#      'pct_mfs': 90.0,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.575: {'voi': 1.3236920784242125,
#      'binary_similarity': 0.4102414887526937,
#      'hamming_distance': 278.874267578125,
#      'normalized_mse': 0.7196383866074654,
#      'grc_pop_corr': 0.0025160140676249057,
#      'mf_dim': 397.250979661985,
#      'mf_pop_corr': 0.0010557983504918328,
#      'grc_dim': 434.81552526656805,
#      'pct_grc': 35.9,
#      'pct_mfs': 91.9,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.6: {'voi': 1.3369663908567808,
#      'binary_similarity': 0.39464069234913685,
#      'hamming_distance': 286.75244140625,
#      'normalized_mse': 0.7399681085008515,
#      'grc_pop_corr': 0.0025253204854170474,
#      'mf_dim': 399.25967419402946,
#      'mf_pop_corr': 0.0010363679031890668,
#      'grc_dim': 439.782748758016,
#      'pct_grc': 36.3,
#      'pct_mfs': 92.9,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.625: {'voi': 1.346565767013493,
#      'binary_similarity': 0.3802921689789873,
#      'hamming_distance': 293.125244140625,
#      'normalized_mse': 0.7564132022621413,
#      'grc_pop_corr': 0.002462627749514815,
#      'mf_dim': 401.43417813156276,
#      'mf_pop_corr': 0.0010223467523259235,
#      'grc_dim': 445.89674518021496,
#      'pct_grc': 36.8,
#      'pct_mfs': 94.2,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.65: {'voi': 1.3579405974962788,
#      'binary_similarity': 0.36666659651131583,
#      'hamming_distance': 300.544189453125,
#      'normalized_mse': 0.7755578794723497,
#      'grc_pop_corr': 0.0023704756018581587,
#      'mf_dim': 403.45160017290954,
#      'mf_pop_corr': 0.0009833353842283892,
#      'grc_dim': 450.63537438939227,
#      'pct_grc': 37.2,
#      'pct_mfs': 95.2,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.675: {'voi': 1.3677260926065204,
#      'binary_similarity': 0.3527758368130384,
#      'hamming_distance': 307.624267578125,
#      'normalized_mse': 0.7938281058477626,
#      'grc_pop_corr': 0.0023714401103319864,
#      'mf_dim': 405.41294141049434,
#      'mf_pop_corr': 0.0009603972762288982,
#      'grc_dim': 455.6809865149011,
#      'pct_grc': 37.6,
#      'pct_mfs': 96.3,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.7: {'voi': 1.3745358160551155,
#      'binary_similarity': 0.33905976394127146,
#      'hamming_distance': 313.518310546875,
#      'normalized_mse': 0.8090377543013908,
#      'grc_pop_corr': 0.0023063064647811157,
#      'mf_dim': 407.8115810959597,
#      'mf_pop_corr': 0.0009215502365769095,
#      'grc_dim': 461.6919509114358,
#      'pct_grc': 38.1,
#      'pct_mfs': 97.6,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.725: {'voi': 1.3810803407412962,
#      'binary_similarity': 0.325054300242456,
#      'hamming_distance': 319.843017578125,
#      'normalized_mse': 0.8253587365248889,
#      'grc_pop_corr': 0.0023546853986717246,
#      'mf_dim': 409.85121906940697,
#      'mf_pop_corr': 0.0009144194743503201,
#      'grc_dim': 463.92559787316304,
#      'pct_grc': 38.3,
#      'pct_mfs': 98.0,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.75: {'voi': 1.38803033974501,
#      'binary_similarity': 0.31416057718211227,
#      'hamming_distance': 325.721435546875,
#      'normalized_mse': 0.84052806447893,
#      'grc_pop_corr': 0.0023002970452538885,
#      'mf_dim': 411.6279793589625,
#      'mf_pop_corr': 0.000897033062130105,
#      'grc_dim': 470.16492225925515,
#      'pct_grc': 38.8,
#      'pct_mfs': 99.4,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.775: {'voi': 1.395013642920398,
#      'binary_similarity': 0.3005897258890101,
#      'hamming_distance': 332.70263671875,
#      'normalized_mse': 0.8585431376928933,
#      'grc_pop_corr': 0.002322173140811062,
#      'mf_dim': 413.26866160858106,
#      'mf_pop_corr': 0.0008792585493542818,
#      'grc_dim': 472.1976315860134,
#      'pct_grc': 38.9,
#      'pct_mfs': 99.8,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.8: {'voi': 1.4012804193591035,
#      'binary_similarity': 0.2896623282596986,
#      'hamming_distance': 338.73193359375,
#      'normalized_mse': 0.8741018104710724,
#      'grc_pop_corr': 0.0022165657841372436,
#      'mf_dim': 415.48354420549737,
#      'mf_pop_corr': 0.0008674129707377474,
#      'grc_dim': 476.98961732300256,
#      'pct_grc': 39.3,
#      'pct_mfs': 100.8,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.825: {'voi': 1.4054248215663547,
#      'binary_similarity': 0.277019632273707,
#      'hamming_distance': 344.712890625,
#      'normalized_mse': 0.8895357417036539,
#      'grc_pop_corr': 0.0022017256231541596,
#      'mf_dim': 416.78962657074396,
#      'mf_pop_corr': 0.0008478659643072458,
#      'grc_dim': 480.50754135607616,
#      'pct_grc': 39.6,
#      'pct_mfs': 101.5,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.85: {'voi': 1.409716120565158,
#      'binary_similarity': 0.2669446221713375,
#      'hamming_distance': 350.00830078125,
#      'normalized_mse': 0.9032006110168506,
#      'grc_pop_corr': 0.002152291238048606,
#      'mf_dim': 418.8503788937402,
#      'mf_pop_corr': 0.0008243317773258423,
#      'grc_dim': 483.34411030875793,
#      'pct_grc': 39.9,
#      'pct_mfs': 102.1,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.875: {'voi': 1.4128214911297532,
#      'binary_similarity': 0.2549522662984915,
#      'hamming_distance': 355.5810546875,
#      'normalized_mse': 0.9175811691977187,
#      'grc_pop_corr': 0.0020706388147894187,
#      'mf_dim': 419.8384410300998,
#      'mf_pop_corr': 0.0007958822752894902,
#      'grc_dim': 486.41142085669463,
#      'pct_grc': 40.1,
#      'pct_mfs': 102.8,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.9: {'voi': 1.4153424680617777,
#      'binary_similarity': 0.24463311557112158,
#      'hamming_distance': 360.819091796875,
#      'normalized_mse': 0.9310979866764941,
#      'grc_pop_corr': 0.002188735982966928,
#      'mf_dim': 421.43657062315606,
#      'mf_pop_corr': 0.0008008527297023504,
#      'grc_dim': 486.77391082026776,
#      'pct_grc': 40.1,
#      'pct_mfs': 102.9,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.925: {'voi': 1.4163284341826619,
#      'binary_similarity': 0.23268916689116376,
#      'hamming_distance': 365.77880859375,
#      'normalized_mse': 0.9438965952563738,
#      'grc_pop_corr': 0.0021403490141022803,
#      'mf_dim': 422.56160012242646,
#      'mf_pop_corr': 0.0007810640667509783,
#      'grc_dim': 490.6004339966648,
#      'pct_grc': 40.5,
#      'pct_mfs': 103.7,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.95: {'voi': 1.4183062355820104,
#      'binary_similarity': 0.22241737102640138,
#      'hamming_distance': 370.981689453125,
#      'normalized_mse': 0.9573226916110781,
#      'grc_pop_corr': 0.0021341104706305643,
#      'mf_dim': 423.61274345262325,
#      'mf_pop_corr': 0.0007558948097860157,
#      'grc_dim': 489.5869828647037,
#      'pct_grc': 40.4,
#      'pct_mfs': 103.5,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     0.975: {'voi': 1.420105662768474,
#      'binary_similarity': 0.21217714507004343,
#      'hamming_distance': 376.36376953125,
#      'normalized_mse': 0.9712112136954222,
#      'grc_pop_corr': 0.0021352337534144544,
#      'mf_dim': 423.9363210579052,
#      'mf_pop_corr': 0.0007545283804651085,
#      'grc_dim': 491.53550217618454,
#      'pct_grc': 40.5,
#      'pct_mfs': 103.9,
#      'num_grcs': 1211,
#      'num_mfs': 473},
#     1.0: {'voi': 1.421382715929579,
#      'binary_similarity': 0.20172329606681036,
#      'hamming_distance': 381.771728515625,
#      'normalized_mse': 0.9851665166072072,
#      'grc_pop_corr': 0.002142458974915718,
#      'mf_dim': 423.96969617086893,
#      'mf_pop_corr': 0.0007574973841831087,
#      'grc_dim': 490.1687348902977,
#      'pct_grc': 40.4,
#      'pct_mfs': 103.6,
#      'num_grcs': 1211,
#      'num_mfs': 473}}},
#   {0.2: {0.025: {'voi': 0.22124239808915136,
#      'binary_similarity': 0.9623934335082077,
#      'hamming_distance': 19.79345703125,
#      'normalized_mse': 0.051077252867593924,
#      'grc_pop_corr': 0.004507481563304227,
#      'mf_dim': 356.06856918848644,
#      'mf_pop_corr': 0.0016055392742998105,
#      'grc_dim': 263.39244348744796,
#      'pct_grc': 21.7,
#      'pct_mfs': 55.4,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.05: {'voi': 0.38234500120792003,
#      'binary_similarity': 0.9257126411382294,
#      'hamming_distance': 38.973876953125,
#      'normalized_mse': 0.10057255613419952,
#      'grc_pop_corr': 0.004071010904267465,
#      'mf_dim': 358.8473548684867,
#      'mf_pop_corr': 0.0014309316500456422,
#      'grc_dim': 272.9148787880217,
#      'pct_grc': 22.5,
#      'pct_mfs': 57.4,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.075: {'voi': 0.5153322488459045,
#      'binary_similarity': 0.8899255460196107,
#      'hamming_distance': 57.654296875,
#      'normalized_mse': 0.14877760341401733,
#      'grc_pop_corr': 0.0038028861150296027,
#      'mf_dim': 361.2747848813842,
#      'mf_pop_corr': 0.0014346005339259556,
#      'grc_dim': 281.8602275561885,
#      'pct_grc': 23.2,
#      'pct_mfs': 59.3,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.1: {'voi': 0.6249382239779772,
#      'binary_similarity': 0.8566671775205232,
#      'hamming_distance': 75.0078125,
#      'normalized_mse': 0.19355855826796034,
#      'grc_pop_corr': 0.003640297541139063,
#      'mf_dim': 362.4534906944612,
#      'mf_pop_corr': 0.0013767334757613236,
#      'grc_dim': 296.0131661313402,
#      'pct_grc': 24.4,
#      'pct_mfs': 62.3,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.125: {'voi': 0.7211031727543062,
#      'binary_similarity': 0.8235210780679714,
#      'hamming_distance': 91.9501953125,
#      'normalized_mse': 0.23727857997651733,
#      'grc_pop_corr': 0.003549996242874886,
#      'mf_dim': 364.14057291346364,
#      'mf_pop_corr': 0.001318030461012204,
#      'grc_dim': 305.09250880120817,
#      'pct_grc': 25.1,
#      'pct_mfs': 64.2,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.15: {'voi': 0.8023540951907658,
#      'binary_similarity': 0.7944665616446176,
#      'hamming_distance': 107.482421875,
#      'normalized_mse': 0.27735967659733685,
#      'grc_pop_corr': 0.0034333897527475754,
#      'mf_dim': 366.7557789838561,
#      'mf_pop_corr': 0.0013860374676663186,
#      'grc_dim': 316.3746579774982,
#      'pct_grc': 26.1,
#      'pct_mfs': 66.6,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.175: {'voi': 0.8785538796787011,
#      'binary_similarity': 0.7653532376254537,
#      'hamming_distance': 123.21728515625,
#      'normalized_mse': 0.3179636796971769,
#      'grc_pop_corr': 0.003202628402611148,
#      'mf_dim': 369.2772367621198,
#      'mf_pop_corr': 0.0013070092721258614,
#      'grc_dim': 329.18378057779324,
#      'pct_grc': 27.1,
#      'pct_mfs': 69.3,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.2: {'voi': 0.9478678174363454,
#      'binary_similarity': 0.7349051593864087,
#      'hamming_distance': 138.78466796875,
#      'normalized_mse': 0.3581354974420674,
#      'grc_pop_corr': 0.0031513180431061005,
#      'mf_dim': 370.14830918619117,
#      'mf_pop_corr': 0.0012772452696150213,
#      'grc_dim': 336.0195448958421,
#      'pct_grc': 27.7,
#      'pct_mfs': 70.7,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.225: {'voi': 1.0025476320281483,
#      'binary_similarity': 0.7090797145871345,
#      'hamming_distance': 152.022216796875,
#      'normalized_mse': 0.3922951506938351,
#      'grc_pop_corr': 0.0031183863020107774,
#      'mf_dim': 372.5916303655728,
#      'mf_pop_corr': 0.001301507889804279,
#      'grc_dim': 345.6058347757241,
#      'pct_grc': 28.5,
#      'pct_mfs': 72.7,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.25: {'voi': 1.0562428603082967,
#      'binary_similarity': 0.682375719947537,
#      'hamming_distance': 165.885009765625,
#      'normalized_mse': 0.4280682539368936,
#      'grc_pop_corr': 0.0030073814361182157,
#      'mf_dim': 374.25213537357894,
#      'mf_pop_corr': 0.0012484410788707473,
#      'grc_dim': 354.376801661654,
#      'pct_grc': 29.2,
#      'pct_mfs': 74.6,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.275: {'voi': 1.1027660389233618,
#      'binary_similarity': 0.6565057239393268,
#      'hamming_distance': 178.910400390625,
#      'normalized_mse': 0.4616804304052048,
#      'grc_pop_corr': 0.0029187066147817547,
#      'mf_dim': 374.97755470124486,
#      'mf_pop_corr': 0.0012531984890541336,
#      'grc_dim': 360.93412378560544,
#      'pct_grc': 29.8,
#      'pct_mfs': 75.9,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.3: {'voi': 1.1445267647967814,
#      'binary_similarity': 0.6322048215100393,
#      'hamming_distance': 191.09765625,
#      'normalized_mse': 0.4931297900753509,
#      'grc_pop_corr': 0.0028726527199463606,
#      'mf_dim': 376.75044951553645,
#      'mf_pop_corr': 0.0012492665082586966,
#      'grc_dim': 369.2898025990885,
#      'pct_grc': 30.4,
#      'pct_mfs': 77.7,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.325: {'voi': 1.18069539546537,
#      'binary_similarity': 0.6094739036838511,
#      'hamming_distance': 202.46728515625,
#      'normalized_mse': 0.5224692536030398,
#      'grc_pop_corr': 0.002826964624734646,
#      'mf_dim': 379.0621364177732,
#      'mf_pop_corr': 0.001189678233834808,
#      'grc_dim': 376.9684644489192,
#      'pct_grc': 31.1,
#      'pct_mfs': 79.3,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.35: {'voi': 1.2173068511497875,
#      'binary_similarity': 0.5877400419137786,
#      'hamming_distance': 214.545654296875,
#      'normalized_mse': 0.5536376297916882,
#      'grc_pop_corr': 0.0026806659099421317,
#      'mf_dim': 381.4591264192693,
#      'mf_pop_corr': 0.0011972728448501886,
#      'grc_dim': 385.20488080222236,
#      'pct_grc': 31.8,
#      'pct_mfs': 81.0,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.375: {'voi': 1.2467312605388916,
#      'binary_similarity': 0.5657629305428841,
#      'hamming_distance': 225.130126953125,
#      'normalized_mse': 0.5809509882151243,
#      'grc_pop_corr': 0.0026943904412938214,
#      'mf_dim': 382.7141663983569,
#      'mf_pop_corr': 0.001190353925851148,
#      'grc_dim': 390.6020942517352,
#      'pct_grc': 32.2,
#      'pct_mfs': 82.2,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.4: {'voi': 1.2760119935865748,
#      'binary_similarity': 0.543555934933849,
#      'hamming_distance': 236.25927734375,
#      'normalized_mse': 0.6096698940538552,
#      'grc_pop_corr': 0.0026554497685129692,
#      'mf_dim': 384.8694232229899,
#      'mf_pop_corr': 0.0011511920927821226,
#      'grc_dim': 397.7705079522607,
#      'pct_grc': 32.8,
#      'pct_mfs': 83.7,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.425: {'voi': 1.2977453223076172,
#      'binary_similarity': 0.5250974780451655,
#      'hamming_distance': 245.160888671875,
#      'normalized_mse': 0.6326406086701976,
#      'grc_pop_corr': 0.002662822552703333,
#      'mf_dim': 386.826940697509,
#      'mf_pop_corr': 0.0011392961779365708,
#      'grc_dim': 403.1972707375349,
#      'pct_grc': 33.2,
#      'pct_mfs': 84.8,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.45: {'voi': 1.3224608940309435,
#      'binary_similarity': 0.5062995409443437,
#      'hamming_distance': 255.467529296875,
#      'normalized_mse': 0.6592370182103503,
#      'grc_pop_corr': 0.0025865594599310832,
#      'mf_dim': 388.68455408437774,
#      'mf_pop_corr': 0.0011338588472417413,
#      'grc_dim': 410.04706404032976,
#      'pct_grc': 33.8,
#      'pct_mfs': 86.3,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.475: {'voi': 1.3435412571301721,
#      'binary_similarity': 0.48708638657618625,
#      'hamming_distance': 265.09912109375,
#      'normalized_mse': 0.6840914561667785,
#      'grc_pop_corr': 0.002564095575019183,
#      'mf_dim': 390.46388994247565,
#      'mf_pop_corr': 0.0011239919075240197,
#      'grc_dim': 415.91934017554865,
#      'pct_grc': 34.3,
#      'pct_mfs': 87.5,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.5: {'voi': 1.3614338371806627,
#      'binary_similarity': 0.46941292198905255,
#      'hamming_distance': 273.823486328125,
#      'normalized_mse': 0.7066047851159294,
#      'grc_pop_corr': 0.0024555946230994095,
#      'mf_dim': 392.88805075301315,
#      'mf_pop_corr': 0.001100281236157857,
#      'grc_dim': 421.9179058974047,
#      'pct_grc': 34.8,
#      'pct_mfs': 88.8,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.525: {'voi': 1.3785737772275481,
#      'binary_similarity': 0.4519550852531923,
#      'hamming_distance': 282.779052734375,
#      'normalized_mse': 0.7297147314574085,
#      'grc_pop_corr': 0.0024992691988742597,
#      'mf_dim': 394.9539916335253,
#      'mf_pop_corr': 0.0010682421298919545,
#      'grc_dim': 427.2538801215279,
#      'pct_grc': 35.2,
#      'pct_mfs': 89.9,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.55: {'voi': 1.3939399636791674,
#      'binary_similarity': 0.43623296361770164,
#      'hamming_distance': 291.14794921875,
#      'normalized_mse': 0.7513107690409526,
#      'grc_pop_corr': 0.002442865415377156,
#      'mf_dim': 396.8368059149362,
#      'mf_pop_corr': 0.0010451634745181335,
#      'grc_dim': 432.35758063970366,
#      'pct_grc': 35.7,
#      'pct_mfs': 91.0,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.575: {'voi': 1.4086121549314965,
#      'binary_similarity': 0.4201660156250002,
#      'hamming_distance': 299.6982421875,
#      'normalized_mse': 0.7733749024243909,
#      'grc_pop_corr': 0.0024140768095316945,
#      'mf_dim': 399.44483729497665,
#      'mf_pop_corr': 0.0010253179690611523,
#      'grc_dim': 437.2897758742991,
#      'pct_grc': 36.1,
#      'pct_mfs': 92.0,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.6: {'voi': 1.4184056049118143,
#      'binary_similarity': 0.40281688383895975,
#      'hamming_distance': 306.8681640625,
#      'normalized_mse': 0.7918769716724298,
#      'grc_pop_corr': 0.0023865456059414627,
#      'mf_dim': 401.24533642766806,
#      'mf_pop_corr': 0.0010053080411302285,
#      'grc_dim': 443.764875847425,
#      'pct_grc': 36.6,
#      'pct_mfs': 93.4,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.625: {'voi': 1.4295202087441958,
#      'binary_similarity': 0.3886549455406022,
#      'hamming_distance': 314.400634765625,
#      'normalized_mse': 0.8113146025124509,
#      'grc_pop_corr': 0.0023754383709321844,
#      'mf_dim': 402.91496211652316,
#      'mf_pop_corr': 0.0010014022386681445,
#      'grc_dim': 446.8307810488752,
#      'pct_grc': 36.8,
#      'pct_mfs': 94.0,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.65: {'voi': 1.4400780526335015,
#      'binary_similarity': 0.37366970090100315,
#      'hamming_distance': 322.16845703125,
#      'normalized_mse': 0.831359560877503,
#      'grc_pop_corr': 0.002392187949352789,
#      'mf_dim': 404.9923948137295,
#      'mf_pop_corr': 0.000979422617555968,
#      'grc_dim': 449.8956291523454,
#      'pct_grc': 37.1,
#      'pct_mfs': 94.7,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.675: {'voi': 1.448202938166503,
#      'binary_similarity': 0.35900076984489065,
#      'hamming_distance': 329.130615234375,
#      'normalized_mse': 0.8493254934825945,
#      'grc_pop_corr': 0.0023342292145920934,
#      'mf_dim': 407.53578257718846,
#      'mf_pop_corr': 0.0009510070024268937,
#      'grc_dim': 457.52543301898345,
#      'pct_grc': 37.7,
#      'pct_mfs': 96.3,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.7: {'voi': 1.4566501068779685,
#      'binary_similarity': 0.3444512360287406,
#      'hamming_distance': 336.693603515625,
#      'normalized_mse': 0.8688418752983715,
#      'grc_pop_corr': 0.0023289799084921766,
#      'mf_dim': 409.06472356580485,
#      'mf_pop_corr': 0.0009319221886033474,
#      'grc_dim': 458.49271375295496,
#      'pct_grc': 37.8,
#      'pct_mfs': 96.5,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.725: {'voi': 1.460816870607631,
#      'binary_similarity': 0.33248299925866853,
#      'hamming_distance': 341.827392578125,
#      'normalized_mse': 0.8820896794439642,
#      'grc_pop_corr': 0.0022914043285681006,
#      'mf_dim': 411.3815269314011,
#      'mf_pop_corr': 0.0009132317530813586,
#      'grc_dim': 464.48140839236714,
#      'pct_grc': 38.3,
#      'pct_mfs': 97.7,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.75: {'voi': 1.4672665038972001,
#      'binary_similarity': 0.3189171561359496,
#      'hamming_distance': 348.7978515625,
#      'normalized_mse': 0.900077032314461,
#      'grc_pop_corr': 0.002248345183248889,
#      'mf_dim': 413.0236111404848,
#      'mf_pop_corr': 0.0008871429913447101,
#      'grc_dim': 470.14802072421026,
#      'pct_grc': 38.8,
#      'pct_mfs': 98.9,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.775: {'voi': 1.4726691689293117,
#      'binary_similarity': 0.30508222371122207,
#      'hamming_distance': 355.70751953125,
#      'normalized_mse': 0.917907513241252,
#      'grc_pop_corr': 0.0022088367307579724,
#      'mf_dim': 415.1898737873095,
#      'mf_pop_corr': 0.0008778224004929303,
#      'grc_dim': 473.33157909409437,
#      'pct_grc': 39.0,
#      'pct_mfs': 99.6,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.8: {'voi': 1.4771078704348808,
#      'binary_similarity': 0.2923325587363143,
#      'hamming_distance': 361.966064453125,
#      'normalized_mse': 0.9340577633493109,
#      'grc_pop_corr': 0.002150200361352457,
#      'mf_dim': 416.9332618970576,
#      'mf_pop_corr': 0.0008560725099484379,
#      'grc_dim': 478.06196518481795,
#      'pct_grc': 39.4,
#      'pct_mfs': 100.6,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.825: {'voi': 1.4818652712804576,
#      'binary_similarity': 0.2817480825159676,
#      'hamming_distance': 368.092041015625,
#      'normalized_mse': 0.9498659192186854,
#      'grc_pop_corr': 0.0021657098612072943,
#      'mf_dim': 418.4632352715969,
#      'mf_pop_corr': 0.0008321875815439669,
#      'grc_dim': 478.92943734111753,
#      'pct_grc': 39.5,
#      'pct_mfs': 100.8,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.85: {'voi': 1.4841798120975582,
#      'binary_similarity': 0.26845489279197005,
#      'hamming_distance': 374.151611328125,
#      'normalized_mse': 0.9655027129648145,
#      'grc_pop_corr': 0.002135601319886145,
#      'mf_dim': 420.2740542713467,
#      'mf_pop_corr': 0.0008184605984430777,
#      'grc_dim': 483.7784142900919,
#      'pct_grc': 39.9,
#      'pct_mfs': 101.8,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.875: {'voi': 1.485642213217174,
#      'binary_similarity': 0.2567619824931574,
#      'hamming_distance': 379.620849609375,
#      'normalized_mse': 0.979616147835918,
#      'grc_pop_corr': 0.002135413653617824,
#      'mf_dim': 421.82204203439176,
#      'mf_pop_corr': 0.000817406772312895,
#      'grc_dim': 486.197044571864,
#      'pct_grc': 40.1,
#      'pct_mfs': 102.3,
#      'num_grcs': 1211,
#      'num_mfs': 475},
#     0.9: {'voi': 1.4874183591398653,
#      'binary_similarity': 0.24503343122718957,
#      'hamming_distance': 385.416015625,
#      'normalized_mse': 0.9945706431280965,
#      'grc_pop_corr': 0.002132303120203601,
#      'mf_dim': 422.8778543095658,
#      'mf_pop_corr': 0.0007730776673629816,
# ...
#      'grc_pop_corr': 0.003841075301981964,
#      'mf_dim': 358.0267734556521,
#      'mf_pop_corr': 0.001470021524353109,
#      'grc_dim': 259.9470580460767,
#      'pct_grc': 21.4,
#      'pct_mfs': 54.8,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.075: {'voi': 0.5008015855364247,
#      'binary_similarity': 0.8879422169811325,
#      'hamming_distance': 55.803466796875,
#      'normalized_mse': 0.14400151423636198,
#      'grc_pop_corr': 0.0037608543682593628,
#      'mf_dim': 361.5427308366986,
#      'mf_pop_corr': 0.001367713452393504,
#      'grc_dim': 269.16056936975286,
#      'pct_grc': 22.2,
#      'pct_mfs': 56.7,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.1: {'voi': 0.6073661132877688,
#      'binary_similarity': 0.8550762824292482,
#      'hamming_distance': 72.510986328125,
#      'normalized_mse': 0.18711546843550006,
#      'grc_pop_corr': 0.0035284243531689212,
#      'mf_dim': 363.85246606720307,
#      'mf_pop_corr': 0.0013365794350797913,
#      'grc_dim': 280.6069733130202,
#      'pct_grc': 23.1,
#      'pct_mfs': 59.1,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.125: {'voi': 0.7029434272349689,
#      'binary_similarity': 0.8229225014740601,
#      'hamming_distance': 89.1884765625,
#      'normalized_mse': 0.2301519316744942,
#      'grc_pop_corr': 0.003424263330399713,
#      'mf_dim': 364.3144473537159,
#      'mf_pop_corr': 0.001364747232677347,
#      'grc_dim': 290.978671666137,
#      'pct_grc': 24.0,
#      'pct_mfs': 61.3,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.15: {'voi': 0.784639970704986,
#      'binary_similarity': 0.7920575987617975,
#      'hamming_distance': 104.655029296875,
#      'normalized_mse': 0.27006355619548666,
#      'grc_pop_corr': 0.00322224963319538,
#      'mf_dim': 367.01898901148036,
#      'mf_pop_corr': 0.0013085167899233635,
#      'grc_dim': 302.1934369158563,
#      'pct_grc': 24.9,
#      'pct_mfs': 63.7,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.175: {'voi': 0.8583906963775088,
#      'binary_similarity': 0.7610038325471731,
#      'hamming_distance': 119.940673828125,
#      'normalized_mse': 0.30950834493219703,
#      'grc_pop_corr': 0.0031890527893426914,
#      'mf_dim': 367.6602954511459,
#      'mf_pop_corr': 0.0013108442881449656,
#      'grc_dim': 312.8551953251123,
#      'pct_grc': 25.8,
#      'pct_mfs': 66.0,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.2: {'voi': 0.9223053103133011,
#      'binary_similarity': 0.733497936320756,
#      'hamming_distance': 134.1298828125,
#      'normalized_mse': 0.3461237686119426,
#      'grc_pop_corr': 0.0031181421469407096,
#      'mf_dim': 369.6382850105587,
#      'mf_pop_corr': 0.0013055720523020532,
#      'grc_dim': 321.68793105211205,
#      'pct_grc': 26.5,
#      'pct_mfs': 67.8,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.225: {'voi': 0.9806804865182637,
#      'binary_similarity': 0.7060814047759433,
#      'hamming_distance': 148.02294921875,
#      'normalized_mse': 0.38197499282295105,
#      'grc_pop_corr': 0.003003253677150363,
#      'mf_dim': 371.89815773406235,
#      'mf_pop_corr': 0.0012457657074283555,
#      'grc_dim': 332.20579320519624,
#      'pct_grc': 27.4,
#      'pct_mfs': 70.0,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.25: {'voi': 1.0300507877642784,
#      'binary_similarity': 0.6804365050117932,
#      'hamming_distance': 160.6640625,
#      'normalized_mse': 0.4145955370045416,
#      'grc_pop_corr': 0.0028987997181756887,
#      'mf_dim': 373.42581671780545,
#      'mf_pop_corr': 0.0012327800475177713,
#      'grc_dim': 340.93222708943233,
#      'pct_grc': 28.1,
#      'pct_mfs': 71.9,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.275: {'voi': 1.0762020876439493,
#      'binary_similarity': 0.653532208136794,
#      'hamming_distance': 173.336181640625,
#      'normalized_mse': 0.4472960921775005,
#      'grc_pop_corr': 0.002853446657963526,
#      'mf_dim': 374.5839440672659,
#      'mf_pop_corr': 0.0012451130749552325,
#      'grc_dim': 349.21913359075563,
#      'pct_grc': 28.8,
#      'pct_mfs': 73.6,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.3: {'voi': 1.1175778415513782,
#      'binary_similarity': 0.6271217202240565,
#      'hamming_distance': 185.552734375,
#      'normalized_mse': 0.4788210527843723,
#      'grc_pop_corr': 0.0027895537250411094,
#      'mf_dim': 376.84404111853013,
#      'mf_pop_corr': 0.0012137054713991747,
#      'grc_dim': 357.10725131098,
#      'pct_grc': 29.4,
#      'pct_mfs': 75.3,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.325: {'voi': 1.1551544133861378,
#      'binary_similarity': 0.60547980542453,
#      'hamming_distance': 197.03125,
#      'normalized_mse': 0.508441499793559,
#      'grc_pop_corr': 0.002750732762765316,
#      'mf_dim': 378.9269084064904,
#      'mf_pop_corr': 0.0012127290162133656,
#      'grc_dim': 365.88909047990114,
#      'pct_grc': 30.2,
#      'pct_mfs': 77.1,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.35: {'voi': 1.1915043898112156,
#      'binary_similarity': 0.5820920548349063,
#      'hamming_distance': 208.9951171875,
#      'normalized_mse': 0.5393144023211704,
#      'grc_pop_corr': 0.0026426083746437764,
#      'mf_dim': 380.16730117991193,
#      'mf_pop_corr': 0.0011906055191143183,
#      'grc_dim': 373.0827486895445,
#      'pct_grc': 30.8,
#      'pct_mfs': 78.7,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.375: {'voi': 1.2216536653368761,
#      'binary_similarity': 0.5599397479363222,
#      'hamming_distance': 219.632568359375,
#      'normalized_mse': 0.5667644724385192,
#      'grc_pop_corr': 0.0026470543353699473,
#      'mf_dim': 381.6700185386301,
#      'mf_pop_corr': 0.001184172544013774,
#      'grc_dim': 381.06855566411815,
#      'pct_grc': 31.4,
#      'pct_mfs': 80.3,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.4: {'voi': 1.2481074438841149,
#      'binary_similarity': 0.5406839622641522,
#      'hamming_distance': 229.421875,
#      'normalized_mse': 0.5920258954376548,
#      'grc_pop_corr': 0.0025739595534672328,
#      'mf_dim': 384.73538435503474,
#      'mf_pop_corr': 0.0011534912463959498,
#      'grc_dim': 389.8051986868138,
#      'pct_grc': 32.1,
#      'pct_mfs': 82.2,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.425: {'voi': 1.2762567155106115,
#      'binary_similarity': 0.5195220371462264,
#      'hamming_distance': 240.527587890625,
#      'normalized_mse': 0.620684320527005,
#      'grc_pop_corr': 0.0025624083008637965,
#      'mf_dim': 385.4992664372923,
#      'mf_pop_corr': 0.0011576608598561392,
#      'grc_dim': 393.75071390803066,
#      'pct_grc': 32.5,
#      'pct_mfs': 83.0,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.45: {'voi': 1.2950174084569601,
#      'binary_similarity': 0.5019549675707545,
#      'hamming_distance': 248.614501953125,
#      'normalized_mse': 0.6415526990945628,
#      'grc_pop_corr': 0.002532589275975679,
#      'mf_dim': 388.24184958230643,
#      'mf_pop_corr': 0.0011657983539761227,
#      'grc_dim': 403.3583706669968,
#      'pct_grc': 33.3,
#      'pct_mfs': 85.0,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.475: {'voi': 1.3176659990528765,
#      'binary_similarity': 0.482353699882074,
#      'hamming_distance': 258.643310546875,
#      'normalized_mse': 0.6674321597514321,
#      'grc_pop_corr': 0.0025057608847418996,
#      'mf_dim': 389.71985966632747,
#      'mf_pop_corr': 0.0011372637602497962,
#      'grc_dim': 407.8098019966158,
#      'pct_grc': 33.6,
#      'pct_mfs': 86.0,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.5: {'voi': 1.3378111300609627,
#      'binary_similarity': 0.46482440300707567,
#      'hamming_distance': 268.003662109375,
#      'normalized_mse': 0.69158665903534,
#      'grc_pop_corr': 0.002425941314094213,
#      'mf_dim': 391.39647014985735,
#      'mf_pop_corr': 0.0010846216979391945,
#      'grc_dim': 414.9073502593472,
#      'pct_grc': 34.2,
#      'pct_mfs': 87.5,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.525: {'voi': 1.3538122401520778,
#      'binary_similarity': 0.4480993882665099,
#      'hamming_distance': 276.2685546875,
#      'normalized_mse': 0.7129143132935074,
#      'grc_pop_corr': 0.0023976436241625997,
#      'mf_dim': 394.02513852663617,
#      'mf_pop_corr': 0.0010545044563795658,
#      'grc_dim': 420.7260724249841,
#      'pct_grc': 34.7,
#      'pct_mfs': 88.7,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.55: {'voi': 1.370193081789431,
#      'binary_similarity': 0.43209297612028286,
#      'hamming_distance': 284.985595703125,
#      'normalized_mse': 0.7354087420084768,
#      'grc_pop_corr': 0.002423469144969897,
#      'mf_dim': 396.39027981650946,
#      'mf_pop_corr': 0.0010502840780146755,
#      'grc_dim': 426.8321066922391,
#      'pct_grc': 35.2,
#      'pct_mfs': 90.0,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.575: {'voi': 1.3834856429949436,
#      'binary_similarity': 0.41486770341981194,
#      'hamming_distance': 292.984375,
#      'normalized_mse': 0.756049687758051,
#      'grc_pop_corr': 0.0023724027208577637,
#      'mf_dim': 397.8735052438785,
#      'mf_pop_corr': 0.001036304531187994,
#      'grc_dim': 432.8631971696692,
#      'pct_grc': 35.7,
#      'pct_mfs': 91.3,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.6: {'voi': 1.3968551820938533,
#      'binary_similarity': 0.40112028301886654,
#      'hamming_distance': 300.88037109375,
#      'normalized_mse': 0.7764254002212787,
#      'grc_pop_corr': 0.0023582557560813074,
#      'mf_dim': 400.2548698660242,
#      'mf_pop_corr': 0.0010245092266030777,
#      'grc_dim': 437.9769321422891,
#      'pct_grc': 36.1,
#      'pct_mfs': 92.4,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.625: {'voi': 1.407862615250042,
#      'binary_similarity': 0.38634194428066,
#      'hamming_distance': 308.29052734375,
#      'normalized_mse': 0.7955473971504696,
#      'grc_pop_corr': 0.0023949710421826984,
#      'mf_dim': 402.50926703502773,
#      'mf_pop_corr': 0.000990006057078185,
#      'grc_dim': 440.7561350612878,
#      'pct_grc': 36.3,
#      'pct_mfs': 92.9,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.65: {'voi': 1.4180487291691295,
#      'binary_similarity': 0.3703521152712264,
#      'hamming_distance': 315.896484375,
#      'normalized_mse': 0.8151746603401114,
#      'grc_pop_corr': 0.002342379354094177,
#      'mf_dim': 404.43328845723227,
#      'mf_pop_corr': 0.0009805875286787802,
#      'grc_dim': 447.48360355413024,
#      'pct_grc': 36.9,
#      'pct_mfs': 94.4,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.675: {'voi': 1.4250544423463205,
#      'binary_similarity': 0.35589714770047215,
#      'hamming_distance': 322.2763671875,
#      'normalized_mse': 0.8316380243277766,
#      'grc_pop_corr': 0.00232176573131185,
#      'mf_dim': 406.4513118293371,
#      'mf_pop_corr': 0.000964858912344829,
#      'grc_dim': 454.003677312678,
#      'pct_grc': 37.4,
#      'pct_mfs': 95.7,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.7: {'voi': 1.4336669024008177,
#      'binary_similarity': 0.342220666273585,
#      'hamming_distance': 329.54248046875,
#      'normalized_mse': 0.8503883166513987,
#      'grc_pop_corr': 0.0023443730903101928,
#      'mf_dim': 408.5702942540169,
#      'mf_pop_corr': 0.0009160110972492103,
#      'grc_dim': 456.0012722432117,
#      'pct_grc': 37.6,
#      'pct_mfs': 96.2,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.725: {'voi': 1.4396754732446988,
#      'binary_similarity': 0.32782097582547093,
#      'hamming_distance': 335.922119140625,
#      'normalized_mse': 0.8668510506312577,
#      'grc_pop_corr': 0.00228517519719232,
#      'mf_dim': 410.4776255202564,
#      'mf_pop_corr': 0.0009154497995910704,
#      'grc_dim': 460.23557440741564,
#      'pct_grc': 38.0,
#      'pct_mfs': 97.0,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.75: {'voi': 1.447257930418896,
#      'binary_similarity': 0.31492942954009356,
#      'hamming_distance': 343.0087890625,
#      'normalized_mse': 0.8851382872174338,
#      'grc_pop_corr': 0.002199614635333143,
#      'mf_dim': 412.508721715074,
#      'mf_pop_corr': 0.0008995981944616554,
#      'grc_dim': 469.56604219687017,
#      'pct_grc': 38.7,
#      'pct_mfs': 99.0,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.775: {'voi': 1.4531165265569894,
#      'binary_similarity': 0.3033700619103773,
#      'hamming_distance': 349.257080078125,
#      'normalized_mse': 0.9012620769976388,
#      'grc_pop_corr': 0.0022290488064539353,
#      'mf_dim': 414.72104539543346,
#      'mf_pop_corr': 0.000861614347658037,
#      'grc_dim': 469.02831783828145,
#      'pct_grc': 38.7,
#      'pct_mfs': 98.9,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.8: {'voi': 1.457983389201093,
#      'binary_similarity': 0.29044258549528296,
#      'hamming_distance': 355.8994140625,
#      'normalized_mse': 0.9184026993768063,
#      'grc_pop_corr': 0.0022400596338635324,
#      'mf_dim': 416.4537488366979,
#      'mf_pop_corr': 0.000854875027686523,
#      'grc_dim': 473.36329346244565,
#      'pct_grc': 39.0,
#      'pct_mfs': 99.8,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.825: {'voi': 1.461446473247533,
#      'binary_similarity': 0.27808077830188627,
#      'hamming_distance': 361.837158203125,
#      'normalized_mse': 0.9337251192277172,
#      'grc_pop_corr': 0.0022367274780173167,
#      'mf_dim': 417.7876768685099,
#      'mf_pop_corr': 0.0008329097789273456,
#      'grc_dim': 477.31790608835877,
#      'pct_grc': 39.4,
#      'pct_mfs': 100.6,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.85: {'voi': 1.4657953663467282,
#      'binary_similarity': 0.26613999852594283,
#      'hamming_distance': 368.384765625,
#      'normalized_mse': 0.9506212985781377,
#      'grc_pop_corr': 0.0022398444350654086,
#      'mf_dim': 419.6643701572371,
#      'mf_pop_corr': 0.0008011336962572698,
#      'grc_dim': 477.9630464057736,
#      'pct_grc': 39.4,
#      'pct_mfs': 100.8,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.875: {'voi': 1.4690122083273713,
#      'binary_similarity': 0.25519236438679227,
#      'hamming_distance': 374.14892578125,
#      'normalized_mse': 0.9654957828789481,
#      'grc_pop_corr': 0.0021557729067656316,
#      'mf_dim': 420.8106787648394,
#      'mf_pop_corr': 0.0007991087564735478,
#      'grc_dim': 482.95117071789605,
#      'pct_grc': 39.8,
#      'pct_mfs': 101.8,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.9: {'voi': 1.4710353980384838,
#      'binary_similarity': 0.24379330041273595,
#      'hamming_distance': 379.873291015625,
#      'normalized_mse': 0.9802675759073726,
#      'grc_pop_corr': 0.0022182173742799544,
#      'mf_dim': 422.3019537687798,
#      'mf_pop_corr': 0.0007776273668836987,
#      'grc_dim': 483.6917309561288,
#      'pct_grc': 39.9,
#      'pct_mfs': 102.0,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.925: {'voi': 1.471072973240262,
#      'binary_similarity': 0.23196307488207504,
#      'hamming_distance': 385.041259765625,
#      'normalized_mse': 0.9936035811458118,
#      'grc_pop_corr': 0.0021655750796494557,
#      'mf_dim': 423.54922941451804,
#      'mf_pop_corr': 0.000763582118746836,
#      'grc_dim': 486.62763085282285,
#      'pct_grc': 40.1,
#      'pct_mfs': 102.6,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.95: {'voi': 1.4738025708958482,
#      'binary_similarity': 0.2215018794221696,
#      'hamming_distance': 391.34814453125,
#      'normalized_mse': 1.0098785727994684,
#      'grc_pop_corr': 0.0021565762645763113,
#      'mf_dim': 423.8753165610112,
#      'mf_pop_corr': 0.0007577837969170105,
#      'grc_dim': 485.74845363790325,
#      'pct_grc': 40.1,
#      'pct_mfs': 102.4,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     0.975: {'voi': 1.4732515048537418,
#      'binary_similarity': 0.2089005380306603,
#      'hamming_distance': 397.28759765625,
#      'normalized_mse': 1.0252054027050215,
#      'grc_pop_corr': 0.0022221088876890832,
#      'mf_dim': 424.4285822221165,
#      'mf_pop_corr': 0.000751646949577219,
#      'grc_dim': 485.3837512464997,
#      'pct_grc': 40.0,
#      'pct_mfs': 102.4,
#      'num_grcs': 1211,
#      'num_mfs': 474},
#     1.0: {'voi': 1.4744872371004412,
#      'binary_similarity': 0.20042102741745255,
#      'hamming_distance': 402.264404296875,
#      'normalized_mse': 1.0380481118313247,
#      'grc_pop_corr': 0.002177201667028464,
#      'mf_dim': 424.48245842334364,
#      'mf_pop_corr': 0.0007494883399520072,
#      'grc_dim': 486.906250714321,
#      'pct_grc': 40.2,
#      'pct_mfs': 102.7,
#      'num_grcs': 1211,
#      'num_mfs': 474}}}],)
